# %% [markdown]
# # Prepare corpus

# %%
# !wget https://s3.amazonaws.com/video.udacity-data.com/topher/2018/October/5bbe6499_text8/text8.zip
# !unzip text8.zip
# Out:
# --2025-04-18 09:27:45--  https://s3.amazonaws.com/video.udacity-data.com/topher/2018/October/5bbe6499_text8/text8.zip
# Resolving s3.amazonaws.com (s3.amazonaws.com)... 52.216.33.112, 52.217.43.70, 52.217.18.70, ...
# Connecting to s3.amazonaws.com (s3.amazonaws.com)|52.216.33.112|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 31344016 (30M) [application/zip]
# Saving to: ‘text8.zip.10’
#
# text8.zip.10        100%[===================>]  29.89M  6.86MB/s    in 5.2s
#
# 2025-04-18 09:27:51 (5.77 MB/s) - ‘text8.zip.10’ saved [31344016/31344016]
#
# Archive:  text8.zip
# replace text8? [y]es, [n]o, [A]ll, [N]one, [r]ename: y
#   inflating: text8

# %%
with open("text8", encoding="utf-8") as f:
    corpus = f.read()

# %%
len(corpus)
# Out:
# 100000000

# %%
# Print the first 1e6 letters
corpus = corpus[:100000]

# %% [markdown]
# # Global vector (GloVe)
# - GloVe was first introduced by [Pennington et al., 2014](https://nlp.stanford.edu/pubs/glove.pdf)
# - Previously, there were two main directions for learning distributed word representations:
#     1. Count-based methods such as Latent Semantic Analysis (LSA)
#     2. Direct prediction-based methods such as Word2Vec.
#
# Count-based methods make efficient use of statistical information about the corpus, but they do not capture the meaning of the words like word2vec and perform poorly on analogy tasks such as _**“king - queen = man - woman”**_. On the other hand, direct prediction-based methods capture the meaning of the word semantically and syntactically using local context but fail to consider the global count statistics. This is where GloVe comes into the picture and overcomes the drawbacks of both approaches by combining them. The author proposed a global log bilinear regression model to learn embeddings based on the co-occurrence of words.

# %% [markdown]
# ## Co-occurrence matrix
#
# Consider a corpus:
# - I like deep learning
# - I like NLP
# - I enjoy flying
#
# GloVe uses a co-occurrence matrix with a context window of fixed size $m$ to learn the word embeddings. The example co-occurrence matrix for the aforegiven corpus with a **context window of size $m=2$**:
# ![co-occurrence matrix example](data:image/jpeg;base64,...)

# %% [markdown]
# ## Mathematical foundation
#
# Denote:
# - $X$ as the word-word co-occurrence matrix
# - $X_{ij}$ as the number of times word $j$ occurs in the context of word $i$
# - $X_i$ = $\sum_{k}{X_{ik}}$ as the number of times any word $k$ appearing in context of word $i$ and $k$ represents the total number of distinct words that appear in context of word $i$)
# - $P_{ij} = P(j | i) = \frac{X_{ij}}{X_i}$ as the co-occurence probablity i.e. probability that word $j$ appears in the context of word $i$
#
# The denominator term in the co-occurrence probability accounts for global statistics, which word2vec does not uses. The main idea behind the GloVe is to encode meaning using the ratios of co-occurrence probabilities. Let's understand the above by deriving the linear meaning components for the following words based on co-occurrence probability.
#
#
#
# The matrix shows the co-occurrence probabilities for the words from the concept of the thermodynamic phases of water (i.e., $ice$ and $steam$). The first two rows represent the co-occurrence probabilities for the words $ice$ and $steam$, whereas the last row represents their ratios. We can observe the following:
# - ratio is not neural for closely related words such as $solid$ and $ice$ or $gas$ and $steam$
# - ratio is neutral for words relevant to $ice$ and $steam$ both or not completely irrelevant to both
#
# The ratio of co-occurrence proababilities is a good starting point for learning word embeddings. Let's start with the most general function $F$ parametrized by 3 word vectors ($w_i$, $w_j$ and $\tilde{w_k}$) given below:
#
# $$
# F(w_i, w_j, \tilde{w_k}) = \frac{P_{ik}}{P_{jk}}
# $$
#
# where $w, \tilde{w} \in \mathrm{R^d}$ and $\tilde{w}$ represent the separate context words.
#
# How do we choose $F$?
#
# There can be many possibilities for choosing $F$ but imposing some constraints allows us to restrict $F$ and select a unique choice. The goal is to learn word vectors (embeddings) that can be projected in the word vector space. These vector spaces are inherently linear, i.e., think of vectors as a line in $\mathrm{R^d}$ space, so the most intuitive way is to take vector differences which makes our function $F$ as follows:
#
# $$
# F(w_i - w_j, \tilde{w_k}) = \frac{P_{ik}}{P_{jk}}
# $$
#
# We see that the right-hand side of the above equation is a scalar. Choosing a complex function such as a neural network would introduce non-linearities since our primary goal is to capture the linear meaning components from word vector space. Here, we take dot product on the left-hand side to make it a scalar similar to the right-hand side.
#
# $$
# F((w_i - w_j)^T \tilde{w_k}) = \frac{P_{ik}}{P_{jk}}
# $$
#
# We also need to preserve symmetry for the distinction between a word and a context word which means that if $ice$ can be used as a context word for $water$, then $water$ can also be used as a context word for $ice$. In a simple, it can be expressed as $w \leftrightarrow \tilde{w}$. This is also evident from our co-occurrence matrix since $X \leftrightarrow X^T$. In order to restore the symmetry, we require that function $F$ is a homomorphism between groups $(\mathrm{R, +})$ and $(\mathrm{R, \times})$.
#
# > _Given two groups, $\small (G, ∗)$ and $\small (H, \cdot)$, a group homomorphism from $\small (G, ∗)$ to $\small (H, \cdot)$ is a function $\small h : G \rightarrow H$ such that for all $u$ and $v$ in $\small G$ it holds that $\small h(u * v) = h(u) \cdot h(v)$_
#
# $$
# \begin{align}
# F((w_i - w_j)^T \tilde{w_k}) &= F(w_i^T \tilde{w_k} + (-w_j^T \tilde{w_k})) \\
#                             &= F(w_i^T \tilde{w_k}) \times F(-w_j^T \tilde{w_k}) \\
#                             &= F(w_i^T \tilde{w_k}) \times F(w_j^T \tilde{w_k})^{-1} \\
#                             &= \frac{F(w_i^T \tilde{w_k})}{F(w_j^T \tilde{w_k})} \\
# \end{align}
# $$
#
# So if we recall the $F$ in terms of co-occurrence probabilities, we get the following:
#
# $$
# F(w_i^T \tilde{w_k}) = P_{ik} = \frac{X_{ik}}{X_i}
# $$
#
# Since we are expressing $F$ in terms of probability which is a non-negative term, so we apply exponential to dot product $w_i^T \tilde{w_k}$ and then take logarithm on both sides.
#
# $$
# w_i^T \tilde{w_k} = log(P_{ik}) = log(X_{ik}) - log(X_i)
# $$
#
# On the right hand, the term $log(X_i)$ is independent of $k$ so it can be absorbed into a bias $b_i$ for $w_i$. Finally, we add bias $\tilde{b_k}$ for $\tilde{w_k}$ to restore the symmetry.
#
# $$
# w_i^T \tilde{w_k} + b_i + \tilde{b_k} = log(X_{ik})
# $$
#
# The above equation leads to our objective function, a weighted least squares regression model where we use the weighting function $f(X_{ij})$ for word-word co-occurrences.
#
# $$
# J = \sum_{i,j = 1}^{V}f(X_{ij}) (w_i^T \tilde{w_k} + b_i + \tilde{b_k} - logX_{ik})^2
# $$
#
# where $V$ is the size of the vocabulary.
#
# Here, the weighting function is defined as follows:
#
# $$
# f(x) = \begin{cases}
#         (x / x_{max})^{\alpha} & \text{if}\ x < x_{max} \\
#         1 & \text{otherwise}
#        \end{cases}
# $$
#
# where $x_{max}$ is the cutoff of the weighting function and $\alpha$ is power scaling similar to Word2Vec.

# %% [markdown]
# ## Implementation

# %%
import numpy as np
import pandas as pd
from collections import Counter, defaultdict

import torch
from torch import nn

# %% [markdown]
# ### Model

# %%
class GloVeModel(nn.Module):
    def __init__(self,
                 vocab_size: int,
                 embed_dim: int,
                 x_max: int = 100,
                 alpha: int = 0.7) -> None:
        """
        Constructor

        Args:
        vocab_size (int) -- Number of words in the vocabulary set
        embed_dim (int) -- Embeddings of dimension to be mapped into
        x_max (int) -- Cut-off of the weighting function
        alpha (int) -- Parameter of the weighting function
        """

        super().__init__()

        # Initialize constructor variable
        self.vocab_size = vocab_size
        self.embed_dim = embed_dim
        self.x_max = x_max
        self.alpha = alpha

        # Construct embedding layer
        ### START YOUR CODE HERE ###
        """
        Your task is to config 4 embedding layers:
        input_embedding_layer -- Embedding layer with input features = vocab_size and output features = embed_dim
        input_bias_layer -- Embedding layer with input features = vocab_size and output features = 1

        output_embedding_layer-- Embedding layer with input features = vocab_size and output features = embed_dim
        output_bias_layer -- Embedding layer with input features = vocab_size and output features = 1
        """

        self.input_embedding_layer = nn.Embedding(vocab_size, embed_dim)
        self.input_bias_layer = nn.Embedding(vocab_size, 1)

        self.output_embedding_layer = nn.Embedding(vocab_size, embed_dim)
        self.output_bias_layer = nn.Embedding(vocab_size, 1)

        """
        Initialize input_embedding_layer and output_embedding_layer with xavier intialization method
        """
        nn.init.xavier_normal_(self.input_embedding_layer.weight)
        nn.init.xavier_normal_(self.output_embedding_layer.weight)

        # Initialize 2 bias layers with zero initialization
        self.input_bias_layer.weight.data.zero_()
        self.output_bias_layer.weight.data.zero_()

        ### END YOUR CODE HERE ###

    def forward(self,
                input_ids,
                output_ids,
                cooccurrence_counts) -> torch.Tensor:
        """
        Forward passing
        """

        input_embedding = self.input_embedding_layer(input_ids)
        input_bias = self.input_bias_layer(input_ids)

        output_embedding = self.output_embedding_layer(output_ids)
        output_bias = self.output_bias_layer(output_ids)

        # Avoid $log(0)$
        cooccurrence_counts += 1

        # Count weight factor
        weight_factor = torch.pow(cooccurrence_counts / self.x_max, self.alpha)

        # Calculate the distance between the input and output embeddings
        embedding_products = torch.sum(input_embedding * output_embedding, dim=1)
        log_cooccurrences = torch.log(cooccurrence_counts)
        distances = (embedding_products + input_bias + output_bias - log_cooccurrences) ** 2

        return torch.mean(weight_factor * distances)

# %% [markdown]
# ## Training

# %%
class GloVeDataset(object):
    def __init__(self,
                 corpus,
                 min_count=5,
                 window_size=5) -> None:
        """
        Prepares the training data for the glove model.

        Args:
        corpus (string): corpus of words
        min_count (int): words with minimum occurrence to consider
        window_size (int): context window size for generating co-occurrence matrix
        """
        self.window_size = window_size
        self.min_count = min_count

        tokens = corpus.split(" ")
        word_counts = Counter(tokens)

        # Only consider the words that occur more than 5 times in the corpus
        word_counts = Counter({word:count for word, count in word_counts.items() if count >= min_count})

        self.word2idx = {word: idx for idx, (word, _) in enumerate(word_counts.most_common())}
        self.idx2word = {idx: word for word, idx in self.word2idx.items()}

        # Create the training corpus
        self.token_ids = [self.word2idx[word] for word in tokens if word in self.word2idx]

        # Create the co-occurrence matrix for corpus
        self.create_cooccurrence_matrix()

    def create_cooccurrence_matrix(self):
        """
        Creates the co-occurence matrix of center and context words based on the context window size.
        """
        cooccurrence_counts = defaultdict(Counter)

        for current_idx, word in enumerate(self.token_ids):
            # Find the start and end of context window
            left_boundary = max(current_idx - self.window_size, 0)
            right_boundary = min(current_idx + self.window_size + 1, len(self.token_ids))

            # Obtain the context words and center words based on context window
            context_word_ids = self.token_ids[left_boundary:current_idx] + self.token_ids[current_idx + 1:right_boundary]
            center_word_id = self.token_ids[current_idx]

            # Đoạn code ban đầu
            #for idx, context_word_id in enumerate(context_word_ids):
                #if current_idx != idx:
                    #Add (1 / distance from center word) for this pair
                    #cooccurrence_counts[center_word_id][context_word_id] += 1 / abs(current_idx - idx)

            # Sửa lỗi cách thay đổi giá trị của cooccurrence_counts
            for i in range(left_boundary, right_boundary):
              if i != current_idx:  # Bỏ qua từ trung tâm
                  context_word_id = self.token_ids[i]
                  # Tính khoảng cách thực sự trong văn bản
                  distance = abs(current_idx - i)
                  cooccurrence_counts[center_word_id][context_word_id] += 1 / distance


        # Create tensors for input word ids, output word ids and their co-occurence count
        in_ids, out_ids, counts = [], [], []
        for center_word_id, counter in cooccurrence_counts.items():
            for context_word_id, count in counter.items():
                in_ids.append(center_word_id)
                out_ids.append(context_word_id)
                counts.append(count)

        self.in_ids = torch.tensor(in_ids, dtype=torch.long)
        self.out_ids = torch.tensor(out_ids, dtype=torch.long)
        self.cooccurrence_counts = torch.tensor(counts, dtype=torch.float)


    def get_batches(self, batch_size):
        """
        Creates the batches for training the network.

        Args:
        batch_size (int): size of the batch

        Returns:
        batch (torch tensor of shape (batch_size, 3)): tensor of word pair ids and co-occurence counts for a given batch
        """
        random_ids = torch.tensor(np.random.choice(len(self.in_ids), len(self.in_ids), replace=False), dtype=torch.long)

        for i in range(0, len(random_ids), batch_size):
            batch_ids = random_ids[i: i+batch_size]
            yield self.in_ids[batch_ids], self.out_ids[batch_ids], self.cooccurrence_counts[batch_ids]

# %%
device = 'cpu' if not torch.cuda.is_available() else 'cuda'

# %%
# Change corpus into the correct format for GloVe
dataset = GloVeDataset(corpus, window_size=10)

# %% [markdown]
# ### Counter demo

# %% [markdown]
# https://www.digitalocean.com/community/tutorials/python-counter-python-collections-counter
#
# - Python Counter là một phần của module Collections và là subclass của Dictionary. Chúng lưu trữ các phần tử và số lần xuất hiện dưới dạng một Dict với key là phần từ đó và value là số lần xuất hiện.
# - Một số method phổ biến như\
#   - elements()
#   - most_common()

# %%
# prompt: Generate a demonstration about Counter()

from collections import Counter

# Example data set
corpus_example = "anarchism originated as a term of abuse first used against early working class radicals including the diggers of the english revolution and the sans culottes of the french revolution whilst the term is still used in a pejorative way to describe any act that used violent means to destroy the organization of society it has also been taken up as a positive label by self defined anarchists the word anarchism is derived from the greek without archons ruler chief king anarchism as a political philosophy is the belief that rulers are unnecessary and should be abolished although there are differing interpretations of what this means anarchism also refers to related social movements that advocate the elimination of authoritarian institutions particularly the state the word anarchy as most anarchists use it does not imply chaos nihilism or anomie but rather a harmonious anti authoritarian society in place of what are regarded as authoritarian political structures and coercive economic"

# Example usage of Counter
word_counts = Counter(corpus_example.split(" "))

# Print the 10 most common words and their counts
print("10 most common words:", word_counts.most_common(10))

# Access the count of a specific word (e.g., the word with index 0)
if 0 in word_counts:
  print(f"Count of word with index 0: {word_counts[0]}")

# Get all unique words and their counts
print("All unique words and their counts:", word_counts)

# Check if a word exists in the counter
word_index_to_check = 5
if word_index_to_check in word_counts:
  print(f"Word with index {word_index_to_check} exists in the corpus.")
else:
  print(f"Word with index {word_index_to_check} does not exist in the corpus.")


# Example of incrementing the count of an existing word
word_index_to_increment = 1
if word_index_to_increment in word_counts:
  word_counts[word_index_to_increment] += 10
  print("Incremented the count of the word", word_index_to_increment)
else:
  print("Word not found")

print("Word counts after increment:", word_counts)

# Example of elements() method
print("All elements in Counter:", list(word_counts.elements()))
# Out:
# 10 most common words: [('the', 12), ('of', 7), ('as', 5), ('a', 5), ('anarchism', 4), ('used', 3), ('and', 3), ('is', 3), ('to', 3), ('that', 3)]
# All unique words and their counts: Counter({'the': 12, 'of': 7, 'as': 5, 'a': 5, 'anarchism': 4, 'used': 3, 'and': 3, 'is': 3, 'to': 3, 'that': 3, 'are': 3, 'authoritarian': 3, 'term': 2, 'revolution': 2, 'in': 2, 'means': 2, 'society': 2, 'it': 2, 'also': 2, 'anarchists': 2, 'word': 2, 'political': 2, 'what': 2, 'originated': 1, 'abuse': 1, 'first': 1, 'against': 1, 'early': 1, 'working': 1, 'class': 1, 'radicals': 1, 'including': 1, 'diggers': 1, 'english': 1, 'sans': 1, 'culottes': 1, 'french': 1, 'whilst': 1, 'still': 1, 'pejorative': 1, 'way': 1, 'describe': 1, 'any': 1, 'act': 1, 'violent': 1, 'destroy': 1, 'organization': 1, 'has': 1, 'been': 1, 'taken': 1, 'up': 1, 'positive': 1, 'label': 1, 'by': 1, 'self': 1, 'defined': 1, 'derived': 1, 'from': 1, 'greek': 1, 'without': 1, 'archons': 1, 'ruler': 1, 'chief': 1, 'king': 1, 'philosophy': 1, 'belief': 1, 'rulers': 1, 'unnecessary': 1, 'should': 1, 'be': 1, 'abolished': 1, 'although': 1, 'there': 1, 'differing': 1, 'interpretations': 1, 'this': 1, 'refers': 1, 'related': 1, 'social': 1, 'movements': 1, 'advocate': 1, 'elimination': 1, 'institutions': 1, 'particularly': 1, 'state': 1, 'anarchy': 1, 'most': 1, 'use': 1, 'does': 1, 'not': 1, 'imply': 1, 'chaos': 1, 'nihilism': 1, 'or': 1, 'anomie': 1, 'but': 1, 'rather': 1, 'harmonious': 1, 'anti': 1, 'place': 1, 'regarded': 1, 'structures': 1, 'coercive': 1, 'economic': 1})
# Word with index 5 does not exist in the corpus.
# Word not found
# Word counts after increment: Counter({'the': 12, 'of': 7, 'as': 5, 'a': 5, 'anarchism': 4, 'used': 3, 'and': 3, 'is': 3, 'to': 3, 'that': 3, 'are': 3, 'authoritarian': 3, 'term': 2, 'revolution': 2, 'in': 2, 'means': 2, 'society': 2, 'it': 2, 'also': 2, 'anarchists': 2, 'word': 2, 'political': 2, 'what': 2, 'originated': 1, 'abuse': 1, 'first': 1, 'against': 1, 'early': 1, 'working': 1, 'class': 1, 'radicals': 1, 'including': 1, 'diggers': 1, 'english': 1, 'sans': 1, 'culottes': 1, 'french': 1, 'whilst': 1, 'still': 1, 'pejorative': 1, 'way': 1, 'describe': 1, 'any': 1, 'act': 1, 'violent': 1, 'destroy': 1, 'organization': 1, 'has': 1, 'been': 1, 'taken': 1, 'up': 1, 'positive': 1, 'label': 1, 'by': 1, 'self': 1, 'defined': 1, 'derived': 1, 'from': 1, 'greek': 1, 'without': 1, 'archons': 1, 'ruler': 1, 'chief': 1, 'king': 1, 'philosophy': 1, 'belief': 1, 'rulers': 1, 'unnecessary': 1, 'should': 1, 'be': 1, 'abolished': 1, 'although': 1, 'there': 1, 'differing': 1, 'interpretations': 1, 'this': 1, 'refers': 1, 'related': 1, 'social': 1, 'movements': 1, 'advocate': 1, 'elimination': 1, 'institutions': 1, 'particularly': 1, 'state': 1, 'anarchy': 1, 'most': 1, 'use': 1, 'does': 1, 'not': 1, 'imply': 1, 'chaos': 1, 'nihilism': 1, 'or': 1, 'anomie': 1, 'but': 1, 'rather': 1, 'harmonious': 1, 'anti': 1, 'place': 1, 'regarded': 1, 'structures': 1, 'coercive': 1, 'economic': 1})
# All elements in Counter: ['anarchism', 'anarchism', 'anarchism', 'anarchism', 'originated', 'as', 'as', 'as', 'as', 'as', 'a', 'a', 'a', 'a', 'a', 'term', 'term', 'of', 'of', 'of', 'of', 'of', 'of', 'of', 'abuse', 'first', 'used', 'used', 'used', 'against', 'early', 'working', 'class', 'radicals', 'including', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'the', 'diggers', 'english', 'revolution', 'revolution', 'and', 'and', 'and', 'sans', 'culottes', 'french', 'whilst', 'is', 'is', 'is', 'still', 'in', 'in', 'pejorative', 'way', 'to', 'to', 'to', 'describe', 'any', 'act', 'that', 'that', 'that', 'violent', 'means', 'means', 'destroy', 'organization', 'society', 'society', 'it', 'it', 'has', 'also', 'also', 'been', 'taken', 'up', 'positive', 'label', 'by', 'self', 'defined', 'anarchists', 'anarchists', 'word', 'word', 'derived', 'from', 'greek', 'without', 'archons', 'ruler', 'chief', 'king', 'political', 'political', 'philosophy', 'belief', 'rulers', 'are', 'are', 'are', 'unnecessary', 'should', 'be', 'abolished', 'although', 'there', 'differing', 'interpretations', 'what', 'what', 'this', 'refers', 'related', 'social', 'movements', 'advocate', 'elimination', 'authoritarian', 'authoritarian', 'authoritarian', 'institutions', 'particularly', 'state', 'anarchy', 'most', 'use', 'does', 'not', 'imply', 'chaos', 'nihilism', 'or', 'anomie', 'but', 'rather', 'harmonious', 'anti', 'place', 'regarded', 'structures', 'coercive', 'economic']

# %% [markdown]
# #**Problem**

# %% [markdown]
# - Dựa vào một số thông tin trong bài báo về mô hình GLOVE, ta có một số thông tin sau:
#   - Symmetric context: A context window that extends to the left and right of a target word.
#   - Performance decreases with vectors larger than 200 dimensions.
#   - Small and asymmetric context windows show better performance on syntactic tasks because the syntactic information is mostly drawn from the neighboring local context and it also depends on the order.
#   - Larger window sizes show better performance on semantic tasks as the semantic information is more non-local.
#
# ![image](https://towardsdatascience.com/wp-content/uploads/2020/07/0FNb3ge5ldWQiEfSr-1024x392.png)
# [Towards Data Science Source](https://towardsdatascience.com/glove-research-paper-clearly-explained-7d2c3641b8a6/)

# %%
"""
Within this part, you would intialize hyperparameters for the training procedure.

You shall set up these following hyperparameters:
- Vocab size (int) -- You shall decide which vocab size is suitable based on the aforegiven dataset
- Embeddeding dimension (int) -- You shall test and point out which embedding dimension is best suit
- Learning rate (float) -- Learning rate for optimization algorithm
- Optimizer (torch.optim) -- Optimization algorithm for model training
- Number of epochs (int) -- Number of epochs for model to learn
- Batch size (int) -- Dataset batch size

"""

### START YOUR CODE HERE ###


vocab_size = len(dataset.word2idx)
embed_dim = 150
x_max = 5
alpha = 0.75
learning_rate = 0.001
num_epochs = 10
batch_size = 64
window_size = 10


model = GloVeModel(vocab_size, embed_dim)
model.to(device)

dataset = GloVeDataset(corpus, window_size=window_size)
optimizer = torch.optim.Adam(params=model.parameters(), lr=learning_rate)
### END YOUR CODE HERE ####

# %%
"""
Your task is to construct a training pipeline for GloVe model and the aforegiven DataLoader

The pipeline consists of several steps:
- Iterate through every epoch
- Within each epoch:
    - Query input word, target word and cooccurrence counts in the dataloader for each batch size -> In ra từ input, output, ma trận đồng xuất hiện
    - Load input word, target word, coocurrence counts into GPU device using .to(device) attribute
    - Forward passing data to model
    - Calculate loss
    - Clear optimizer accumulating gradient
    - Backpropagation
    - Upgrade model weight by optimization algorithm -> IN ra tiến trình thay đổi loss của mô hình
    #Epoch: 1
Loss: 0.000004
#Epoch: 2
Loss: 0.000004
#Epoch: 3
Loss: 0.000004
#Epoch: 4
Loss: 0.000004
#Epoch: 5
Loss: 0.000004
#Epoch: 6
Loss: 0.000004
#Epoch: 7
"""

loss_pd = pd.DataFrame(columns=["epoch", "loss"])

### START YOUR CODE HERE ###
for epoch in range(num_epochs):
    print(f"Epoch: {epoch}/{num_epochs}")

    total_loss = 0
    num_batches = 0
    for input_ids, output_ids, cooccurrence_counts in dataset.get_batches(batch_size):

        input_words = [dataset.idx2word[idx.item()] for idx in input_ids]
        output_words = [dataset.idx2word[idx.item()] for idx in output_ids]
        # Chỉ in ra 10 phần tử đầu tiên
        print("Input words: ", input_words[:10])
        print("Output words: ", output_words[:10])
        print("Co-occurrence values: ", cooccurrence_counts[:10])


        input_ids = input_ids.to(device)
        output_ids = output_ids.to(device)
        cooccurrence_counts = cooccurrence_counts.to(device)

        loss = model(input_ids, output_ids, cooccurrence_counts)
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()

        total_loss += loss
        num_batches += 1

    print(f"Loss: {total_loss / num_batches}")


### END YOUR CODE HERE ####
# Out:
# Streaming output truncated to the last 5000 lines.
#         2.9929])
# Input words:  ['authoritarian', 'earth', 'rothbard', 'way', 'this', 'government', 'there', 'a', 'tucker', 'partly']
# Output words:  ['idea', 'all', 'capitalism', 'still', 'her', 'example', 'right', 'found', 'institutions', 'of']
# Co-occurrence values:  tensor([0.1111, 0.1250, 1.2667, 0.2500, 0.1250, 0.1111, 0.1429, 0.3667, 0.5000,
#         2.3345])
# Input words:  ['man', 'syndrome', 'than', 'schools', 'delays', 'disorders', 'human', 'believe', 'states', 'what']
# Output words:  ['first', 'themselves', 'one', 'of', 'only', 'this', 'another', 'around', 'called', 'sovereignty']
# Co-occurrence values:  tensor([1.1000, 0.1667, 1.3107, 2.2456, 1.0000, 0.3111, 0.1429, 0.2000, 0.4167,
#         0.2500])
# Input words:  ['nine', 'lack', 'first', 'city', 'uae', 'now', 'world', 'his', 'them', 'study']
# Output words:  ['bolsheviks', 'self', 'libertarian', 'four', 'all', 'kanner', 'need', 'by', 'be', 'the']
# Co-occurrence values:  tensor([0.1111, 0.1250, 0.3500, 0.2500, 0.1250, 0.1111, 0.3333, 0.7222, 2.3262,
#         3.8833])
# Input words:  ['rights', 'before', 'later', 'self', 'criteria', 'in', 'anarcha', 'scale', 'may', 'different']
# Output words:  ['arab', 'there', 'during', 'however', 'statistical', 'theory', 'syndicalism', 'however', 't', 'warming']
# Co-occurrence values:  tensor([0.3429, 0.1667, 0.2500, 1.0000, 0.2500, 2.5833, 0.2000, 0.1111, 0.1250,
#         1.2000])
# Input words:  ['development', 'advocate', 'throughout', 'bakunin', 'mental', 'have', 'form', 'principles', 'after', 'views']
# Output words:  ['before', 'structures', 'autism', 'as', 'manual', 'structures', 'is', 'labour', 'are', 'or']
# Co-occurrence values:  tensor([1.0000, 0.3111, 0.3333, 2.5833, 2.0000, 0.2429, 2.8540, 0.1111, 0.5000,
#         0.6762])
# Input words:  ['government', 'revolution', 'dsm', 'people', 'are', 'that', 'warming', 'children', 'as', 'number']
# Output words:  ['than', 'william', 'see', 'upon', 'understand', 'complete', 'global', 'autistic', 'important', 'an']
# Co-occurrence values:  tensor([ 0.5333,  1.0000,  0.5000,  0.1667,  0.2500,  0.2429,  3.1000, 13.1429,
#          2.4333,  1.0000])
# Input words:  ['social', 'increase', 'into', 'during', 'within', 'zero', 'american', 'below', 'would', 'particular']
# Output words:  ['them', 'october', 'zero', 'one', 'treatment', 'age', 'civil', 'their', 'while', 'research']
# Co-occurrence values:  tensor([0.1250, 0.1429, 1.2290, 1.9429, 0.1000, 0.1429, 0.1000, 0.2500, 0.3111,
#         0.1000])
# Input words:  ['clouds', 'some', 's', 'following', 'life', 'example', 'an', 'when', 'child', 'where']
# Output words:  ['five', 'found', 'spanish', 'study', 'work', 'being', 'number', 'autistic', 'appear', 'had']
# Co-occurrence values:  tensor([0.1111, 0.1111, 0.3500, 1.0000, 1.0000, 0.2778, 1.0000, 0.7540, 0.1000,
#         0.1429])
# Input words:  ['at', 'popular', 'communities', 'black', 'seven', 'europe', 'revolution', 'in', 'associated', 'values']
# Output words:  ['when', 'its', 'are', 'was', 'five', 'four', 'within', 'generally', 'anarchy', 'warming']
# Co-occurrence values:  tensor([0.2500, 0.2500, 0.1667, 0.1000, 0.2429, 0.3667, 0.1000, 0.5111, 0.3929,
#         0.1429])
# Input words:  ['this', 'system', 'recent', 'due', 'general', 'to', 'communication', 'dhabi', 'without', 'became']
# Output words:  ['and', 'which', 'disorders', 'as', 'up', 'examples', 'or', 'due', 'autism', 'its']
# Co-occurrence values:  tensor([12.6738,  0.8929,  0.2000,  0.5333,  0.1429,  0.9444,  6.6278,  0.3333,
#          4.4901,  0.1429])
# Input words:  ['mutual', 'increase', 'activity', 'island', 'others', 'which', 'albedo', 'on', 'system', 't']
# Output words:  ['while', 'by', 'authoritarian', 'seven', 'least', 'based', 'significant', 'common', 'based', 'associated']
# Co-occurrence values:  tensor([0.3333, 1.3111, 0.1667, 0.3333, 0.2000, 0.5000, 0.2000, 0.1111, 0.1429,
#         0.3333])
# Input words:  ['t', 'published', 'non', 'dr', 'be', 'autistic', 'anarchist', 'more', 'british', 'disorders']
# Output words:  ['action', 'which', 'problems', 'term', 'understand', 'about', 'on', 'is', 'after', 'autistic']
# Co-occurrence values:  tensor([0.6667, 0.6250, 0.5000, 0.3333, 0.6167, 0.8540, 1.6944, 7.5897, 0.1250,
#         2.1028])
# Input words:  ['higher', 'values', 'with', 'cure', 'they', 'and', 't', 'mental', 'direct', 'united']
# Output words:  ['zero', 'in', 'radiation', 'groups', 'all', 'form', 'that', 'be', 'was', 'government']
# Co-occurrence values:  tensor([1.2500, 0.8929, 0.3611, 0.6790, 1.2833, 3.6401, 1.6111, 0.1000, 0.1111,
#         0.3750])
# Input words:  ['by', 'temperature', 'in', 'interests', 'at', 'themselves', 'capitalist', 'like', 'trees', 'uk']
# Output words:  ['difference', 'if', 'modern', 'state', 'new', 'feminist', 'others', 'if', 'zero', 'uk']
# Co-occurrence values:  tensor([0.5000, 1.1667, 3.8333, 0.1250, 0.1000, 0.4333, 0.1000, 0.5000, 0.1111,
#         0.4000])
# Input words:  ['their', 'after', 'others', 'specific', 'speech', 'and', 'would', 'interpretations', 'forests', 'authoritarian']
# Output words:  ['spanish', 'though', 'of', 'focus', 'from', 'great', 'but', 'label', 'g', 'see']
# Co-occurrence values:  tensor([0.1111, 0.1667, 5.4651, 0.5000, 0.1000, 0.7000, 0.2000, 0.1250, 0.2500,
#         0.1250])
# Input words:  ['at', 'examples', 'the', 'does', 'as', 'natural', 'that', 'had', 'another', 'a']
# Output words:  ['color', 'can', 'problems', 'other', 'often', 'autistic', 'time', 'libertarian', 'that', 'form']
# Co-occurrence values:  tensor([0.1250, 0.1429, 3.2278, 0.3750, 9.3718, 1.3333, 1.4667, 0.5000, 1.9667,
#         8.1857])
# Input words:  ['where', 'he', 'present', 'condition', 'might', 'against', 'over', 'at', 'and', 'views']
# Output words:  ['three', 'their', 'have', 'because', 'their', 'the', 'against', 'movement', 'may', 'within']
# Co-occurrence values:  tensor([ 1.1250,  0.5000,  0.6250,  1.0000,  0.8917,  9.6496,  0.4111,  0.4250,
#         10.8341,  0.1000])
# Input words:  ['his', 'they', 'to', 'ability', 'given', 'or', 'das', 'some', 'movements', 'the']
# Output words:  ['until', 'time', 'social', 'may', 'which', 'action', 'not', 'usually', 'other', 'goldman']
# Co-occurrence values:  tensor([0.3333, 1.1250, 8.1131, 0.3000, 0.5000, 0.3095, 0.1000, 0.1250, 2.0833,
#         1.8206])
# Input words:  ['social', 'society', 'significant', 'has', 'rise', 'five', 'zayed', 'area', 'own', 'from']
# Output words:  ['authority', 'way', 'four', 'number', 'in', 'fact', 'of', 'with', 'anarchism', 'has']
# Co-occurrence values:  tensor([0.1111, 0.1000, 0.1250, 0.8333, 3.2833, 0.1429, 0.7417, 1.4444, 0.1250,
#         2.1167])
# Input words:  ['most', 'communication', 'development', 'or', 'fact', 'of', 'called', 'early', 'an', 'list']
# Output words:  ['property', 'does', 'lack', 'problems', 'development', 'effect', 'sometimes', 'she', 'fascist', 'one']
# Co-occurrence values:  tensor([0.1429, 0.2000, 0.3333, 1.4540, 0.1429, 6.1607, 1.6250, 0.4361, 1.0000,
#         0.2429])
# Input words:  ['nine', 'spectrum', 'within', 'by', 'six', 'on', 'force', 'five', 'unusual', 'six']
# Output words:  ['before', 'spectrum', 'working', 'its', 'states', 'change', 'he', 'out', 'known', 'well']
# Co-occurrence values:  tensor([0.3429, 2.0000, 0.5000, 3.1429, 0.9111, 0.6250, 1.1429, 0.1111, 0.5000,
#         0.2000])
# Input words:  ['most', 'average', 'nature', 'english', 'six', 'means', 'org', 'led', 'some', 'large']
# Output words:  ['must', 'for', 'found', 'a', 'all', 'conflict', 'industrial', 'within', 'about', 'see']
# Co-occurrence values:  tensor([0.3500, 1.1111, 0.1667, 0.3500, 0.1111, 0.1250, 1.0000, 0.5000, 0.5028,
#         0.4762])
# Input words:  ['health', 'three', 'small', 'speak', 'rise', 'or', 'such', 'in', 'involved', 'without']
# Output words:  ['movement', 'sheikh', 'albedo', 'do', 'one', 'schools', 'view', 'appear', 's', 'they']
# Co-occurrence values:  tensor([0.1111, 0.5000, 0.3333, 1.0000, 0.1250, 0.5873, 0.8333, 0.1667, 0.4167,
#         0.4333])
# Input words:  ['s', 'six', 'working', 'effects', 'upon', 'communist', 'schools', 'much', 'anti', 'may']
# Output words:  ['between', 'revolution', 'difficulty', 'effects', 'true', 'i', 'much', 'by', 'tolstoy', 'communication']
# Co-occurrence values:  tensor([0.4929, 0.7540, 0.5000, 0.3333, 0.1250, 1.1000, 0.1111, 0.2500, 0.2429,
#         0.5000])
# Input words:  ['even', 'nine', 'every', 'sensory', 'have', 'autistic', 'revolution', 'only', 'he', 'have']
# Output words:  ['than', 'asperger', 'was', 'sensory', 'children', 'still', 'four', 'around', 'just', 'views']
# Co-occurrence values:  tensor([1.0000, 0.2222, 0.7679, 0.4857, 3.7917, 0.4000, 0.2500, 0.1111, 0.1429,
#         0.1250])
# Input words:  ['based', 'used', 'or', 'a', 'particularly', 'with', 'with', 'authoritarian', 'typical', 'usually']
# Output words:  ['capitalist', 'means', 'groups', 'tend', 'from', 'develop', 'like', 'individualist', 'criteria', 'development']
# Co-occurrence values:  tensor([0.1000, 0.6111, 1.5040, 1.2583, 0.1111, 0.1000, 0.7694, 0.1000, 0.1111,
#         0.1111])
# Input words:  ['revolution', 'be', 'the', 'be', 'anarchist', 'several', 'communist', 'europe', 'any', 'to']
# Output words:  ['a', 'from', 'kingdom', 'state', 'schools', 'sometimes', 'proudhon', 'bakunin', 'who', 'effect']
# Co-occurrence values:  tensor([1.3968, 2.2028, 4.2984, 0.3679, 1.0000, 0.2000, 0.1250, 0.1000, 0.6429,
#         1.6040])
# Input words:  ['autistic', 'particular', 'anarchism', 'diagnosis', 'set', 'many', 'than', 'referred', 'spectrum', 'three']
# Output words:  ['spectrum', 'action', 'workers', 'given', 'two', 'cnt', 'asperger', 'the', 'created', 'two']
# Co-occurrence values:  tensor([8.4167, 0.2540, 0.7778, 0.1429, 0.5000, 1.0000, 0.4611, 0.6790, 0.6250,
#         7.7694])
# Input words:  ['so', 'of', 'seven', 'black', 'same', 'anti', 'developmental', 'other', 'is', 'anarchism']
# Output words:  ['specific', 'liberty', 'environmental', 'related', 'as', 'need', 'because', 'two', 'understand', 'known']
# Co-occurrence values:  tensor([0.3333, 1.3000, 0.2000, 0.4762, 1.2000, 0.1000, 0.2000, 0.1111, 0.1429,
#         0.5000])
# Input words:  ['eight', 'american', 'his', 'have', 'this', 'found', 'de', 'self', 'living', 'every']
# Output words:  ['skills', 'one', 'are', 'their', 'able', 'anarchy', 'within', 'appear', 'people', 'international']
# Co-occurrence values:  tensor([0.2111, 0.6345, 1.6333, 1.6111, 0.4762, 0.1429, 0.1111, 0.1111, 0.2361,
#         0.2500])
# Input words:  ['resources', 'associated', 'dhabi', 'the', 'capitalism', 'what', 'they', 'principles', 'difficulties', 'dr']
# Output words:  ['when', 'reference', 'uae', 'system', 'since', 'syndicalism', 'many', 'believe', 'part', 'the']
# Co-occurrence values:  tensor([0.3333, 0.1250, 1.6167, 9.9274, 0.2000, 0.2500, 3.0540, 0.1429, 0.1429,
#         1.8833])
# Input words:  ['at', 'understand', 'will', 'american', 'like', 'they', 'is', 'need', 'be', 'appear']
# Output words:  ['article', 'them', 'symptoms', 'against', 'level', 'condition', 'change', 'not', 'generally', 'may']
# Co-occurrence values:  tensor([0.1111, 0.5833, 0.1250, 0.1250, 0.1111, 0.5000, 1.1111, 1.2000, 0.1111,
#         0.2361])
# Input words:  ['in', 'autism', 'many', 'autism', 'from', 'different', 'warren', 'state', 'uk', 'those']
# Output words:  ['structures', 'fact', 'fascism', 'a', 'appear', 'diagnosed', 'lack', 'difficult', 'information', 'general']
# Co-occurrence values:  tensor([ 1.2063,  0.4917,  0.2500, 21.6655,  0.1000,  0.1429,  0.6111,  0.2500,
#          0.8333,  0.1111])
# Input words:  ['had', 'autism', 'form', 'use', 'understand', 's', 'number', 'natural', 'number', 'man']
# Output words:  ['social', 'about', 'may', 'institutions', 'delays', 'there', 'and', 'people', 'spectrum', 'is']
# Co-occurrence values:  tensor([0.2500, 8.8595, 0.2500, 0.3222, 0.1667, 0.3750, 2.4679, 0.4762, 0.3333,
#         1.4778])
# Input words:  ['do', 'more', 'leo', 'nature', 'with', 'bolsheviks', 'anarchy', 'not', 'criteria', 'liberty']
# Output words:  ['seem', 'org', 'nine', 'or', 'individual', 'as', 'movements', 'other', 'few', 'mutual']
# Co-occurrence values:  tensor([0.1429, 0.3333, 0.5179, 0.5333, 2.2000, 0.3111, 0.6000, 1.7690, 0.1667,
#         0.1000])
# Input words:  ['society', 'institute', 'autistic', 'autism', 'communities', 'was', 'bakunin', 'them', 'individuals', 'is']
# Output words:  ['several', 'four', 'into', 'in', 'and', 'well', 'century', 'communicate', 'generally', 'violence']
# Co-occurrence values:  tensor([ 0.1667,  0.1667,  0.5833, 30.8373,  2.1194,  0.2000,  0.2000,  0.6111,
#          0.3333,  0.9524])
# Input words:  ['see', 'argue', 'labour', 'they', 'thought', 'with', 'an', 'of', 'national', 'major']
# Output words:  ['was', 'and', 'wealth', 'disorders', 'anarchists', 'popular', 'anarchist', 'all', 'child', 'workers']
# Co-occurrence values:  tensor([ 0.6250,  2.4869,  1.0000,  0.4583,  0.3429,  1.9167, 11.0964,  8.3246,
#          0.4762,  0.1667])
# Input words:  ['information', 'green', 'might', 'so', 'us', 'individual', 'or', 'he', 'from', 'for']
# Output words:  ['on', 'industrial', 'may', 'take', 'one', 'movement', 'daily', 'this', 'also', 'force']
# Co-occurrence values:  tensor([0.6774, 0.5000, 0.3667, 0.1250, 1.2778, 0.1429, 0.5000, 1.0000, 1.5179,
#         0.1250])
# Input words:  ['it', 'communist', 'later', 'iv', 'all', 'autistic', 'class', 'when', 'they', 'involved']
# Output words:  ['anarcha', 'cgt', 'others', 'most', 'further', 'similar', 'anarchism', 'them', 'still', 'over']
# Co-occurrence values:  tensor([0.2250, 0.1250, 0.4444, 0.5000, 0.2500, 0.5333, 0.9250, 0.2500, 1.0000,
#         0.3333])
# Input words:  ['criteria', 'given', 'autism', 'language', 'by', 'recent', 'what', 'labor', 'a', 'being']
# Output words:  ['stereotyped', 'with', 'involved', 'difficulties', 'large', 'in', 'movements', 'would', 'mental', 'anarchy']
# Co-occurrence values:  tensor([0.3000, 0.5833, 0.5000, 0.3429, 0.2361, 3.7000, 0.1250, 0.7262, 2.0750,
#         0.5000])
# Input words:  ['benjamin', 'some', 'than', 'fascist', 'who', 'de', 'movement', 'same', 'of', 'conditions']
# Output words:  ['zero', 'if', 'first', 'after', 'state', 'capitalist', 'time', 'people', 'dr', 'related']
# Co-occurrence values:  tensor([0.8333, 0.1000, 0.2250, 0.2500, 0.2500, 0.2000, 0.3333, 0.3333, 1.9651,
#         0.1250])
# Input words:  ['stirner', 'difficult', 'of', 'however', 'in', 'property', 'at', 'that', 'can', 'normal']
# Output words:  ['ideas', 'autism', 'labels', 'seven', 'schools', 'one', 'violence', 'interests', 'number', 'mental']
# Co-occurrence values:  tensor([0.3611, 0.3333, 0.9000, 0.2000, 1.2917, 0.6000, 0.2222, 0.3361, 0.5000,
#         0.2000])
# Input words:  ['just', 'interests', 'form', 'current', 'direct', 'will', 'students', 'had', 'some', 'general']
# Output words:  ['autism', 'lack', 'time', 'things', 'day', 'help', 'out', 'also', 'adults', 'com']
# Co-occurrence values:  tensor([0.8024, 0.5694, 0.1429, 0.1250, 0.1000, 1.0000, 0.2000, 0.1429, 0.9000,
#         0.1111])
# Input words:  ['need', 'war', 'property', 'is', 'however', 'an', 'rise', 'law', 'five', 'it']
# Output words:  ['increase', 'movements', 'property', 'i', 'institute', 'anarcho', 'with', 'history', 'been', 'asperger']
# Co-occurrence values:  tensor([0.3750, 0.5833, 1.3556, 1.3762, 0.3333, 1.6762, 0.1667, 0.1429, 0.2500,
#         0.3000])
# Input words:  ['while', 'this', 'global', 'man', 'are', 'even', 'social', 'it', 'also', 'great']
# Output words:  ['same', 'world', 'this', 'and', 'the', 'with', 'or', 'difficult', 'dhabi', 'areas']
# Co-occurrence values:  tensor([ 0.3333,  1.4583,  0.2667,  0.6429, 23.9726,  1.1667,  8.1218,  0.7000,
#          0.8750,  0.2679])
# Input words:  ['to', 'individual', 'level', 'be', 'seven', 'views', 'found', 'have', 'on', 'zero']
# Output words:  ['and', 'based', 'a', 'cure', 'due', 'as', 'are', 'school', 'specific', 'das']
# Co-occurrence values:  tensor([77.0825,  0.1667,  2.3790,  0.1429,  0.2000,  1.3929,  0.1000,  0.1250,
#          0.4167,  1.4611])
# Input words:  ['an', 'after', 'much', 'has', 'even', 'abu', 'by', 'his', 'two', 'from']
# Output words:  ['different', 'org', 'criteria', 'those', 'time', 'amount', 'called', 'its', 'mean', 'set']
# Co-occurrence values:  tensor([1.1167, 0.3333, 0.2500, 0.4679, 0.1000, 0.2111, 2.0000, 0.3333, 0.3429,
#         0.5000])
# Input words:  ['found', 'idea', 'general', 'that', 'with', 'anarcho', 'two', 'often', 'labour', 'libertarian']
# Output words:  ['those', 'even', 'anarcho', 'individual', 'were', 'what', 'mental', 'over', 'law', 'has']
# Co-occurrence values:  tensor([1.0000, 0.1250, 0.8611, 1.8250, 2.0889, 0.3333, 0.1667, 0.1250, 0.4333,
#         0.1667])
# Input words:  ['a', 'zero', 'word', 'might', 'nature', 'an', 'years', 'emma', 'in', 'civil']
# Output words:  ['behaviors', 'effects', 'this', 'behaviors', 'at', 'had', 'called', 'who', 'difficult', 'black']
# Co-occurrence values:  tensor([0.3778, 0.1000, 0.1667, 1.0000, 0.1429, 1.1250, 0.1667, 0.1429, 0.8667,
#         0.2000])
# Input words:  ['modern', 'throughout', 'used', 'terms', 'are', 'criteria', 'list', 'large', 'us', 'its']
# Output words:  ['for', 'day', 'often', 'theory', 'eight', 'age', 'and', 'is', 'cgt', 'tolstoy']
# Co-occurrence values:  tensor([0.7778, 0.5000, 1.1000, 0.2000, 1.2345, 0.1429, 1.1262, 0.1429, 0.1111,
#         0.5000])
# Input words:  ['four', 'reference', 'individual', 'were', 'should', 'high', 'this', 'may', 'repetitive', 'into']
# Output words:  ['prior', 'increase', 'revolutionary', 'believe', 'anti', 'student', 'referred', 'working', 'can', 'like']
# Co-occurrence values:  tensor([0.2000, 0.1000, 0.2500, 0.7500, 0.5000, 0.1000, 0.5000, 0.5000, 0.5000,
#         0.1000])
# Input words:  ['with', 'trees', 'also', 'about', 'new', 'up', 'before', 'level', 'that', 'development']
# Output words:  ['interest', 'effect', 'become', 'take', 'five', 'one', 'which', 'than', 'language', 'and']
# Co-occurrence values:  tensor([0.3929, 0.1250, 2.1000, 0.2000, 0.2540, 0.2111, 0.5000, 0.2000, 0.1000,
#         4.4528])
# Input words:  ['often', 'class', 'war', 'skills', 'us', 'cultural', 'better', 'childhood', 'emirates', 'uae']
# Output words:  ['believe', 'that', 'is', 'can', 'and', 'the', 'being', 'as', 'three', 't']
# Co-occurrence values:  tensor([0.1250, 0.1429, 1.3540, 0.1667, 2.7357, 1.5417, 0.4583, 0.5833, 1.3333,
#         0.2000])
# Input words:  ['low', 'difficult', 'to', 'see', 'disorders', 'social', 'significant', 'their', 'had', 'students']
# Output words:  ['terms', 'who', 'prior', 'capitalism', 'these', 'some', 'a', 'opposed', 'made', 'need']
# Co-occurrence values:  tensor([1.0000, 0.4583, 6.5333, 0.7500, 1.3333, 1.0333, 3.4524, 0.2500, 0.5000,
#         0.1000])
# Input words:  ['of', 'speak', 'five', 'state', 'rett', 'know', 'believe', 'for', 'some', 'and']
# Output words:  ['higher', 'skills', 'though', 'first', 'from', 'for', 'an', 'sensory', 'often', 'include']
# Co-occurrence values:  tensor([1.5179, 1.0000, 1.2500, 0.1000, 1.2361, 0.4583, 0.7250, 0.5540, 1.3095,
#         5.4635])
# Input words:  ['article', 'working', 'or', 'parents', 'number', 'free', 'before', 'by', 'before', 'is']
# Output words:  ['mental', 'trade', 'children', 'may', 'including', 'intellectual', 'emma', 'diagnosis', 'anarchist', 'from']
# Co-occurrence values:  tensor([ 0.1000,  0.1000,  1.5540,  0.1111,  0.2500,  0.1000,  0.3333,  1.0000,
#          0.1667, 11.3774])
# Input words:  ['with', 'related', 'by', 'more', 'current', 'f', 'true', 'for', 'often', 'being']
# Output words:  ['island', 'interaction', 'years', 'do', 'from', 'albedo', 'popular', 'kropotkin', 'found', 'based']
# Co-occurrence values:  tensor([0.1250, 0.2000, 0.1429, 1.1000, 0.2500, 0.1000, 0.3333, 1.2000, 0.5000,
#         0.1000])
# Input words:  ['by', 'would', 'several', 'complete', 'warming', 'high', 'dhabi', 'body', 'cnt', 'social']
# Output words:  ['eight', 'earth', 'with', 'individuals', 'of', 's', 'british', 'after', 'many', 'kropotkin']
# Co-occurrence values:  tensor([1.1357, 0.3790, 0.7917, 0.2000, 3.5302, 0.8762, 0.4500, 0.1429, 1.0000,
#         0.1250])
# Input words:  ['labels', 'without', 'syndicalism', 'economic', 'one', 'called', 'about', 'than', 'many', 'than']
# Output words:  ['others', 'has', 'eight', 'groups', 'considered', 'been', 'with', 'low', 'due', 'system']
# Co-occurrence values:  tensor([0.1250, 0.1111, 0.2500, 0.1111, 0.4345, 1.0000, 3.3595, 0.2000, 1.0095,
#         0.2111])
# Input words:  ['difficult', 'published', 'term', 'people', 'more', 'believe', 'civil', 'class', 'year', 'workers']
# Output words:  ['of', 'five', 'point', 'year', 'cure', 'and', 'of', 'french', 'can', 'world']
# Co-occurrence values:  tensor([1.7968, 0.3333, 0.1667, 0.2000, 0.1667, 1.2679, 1.2194, 0.5000, 1.2000,
#         1.0000])
# Input words:  ['for', 'popular', 'age', 'states', 'examples', 'sensory', 'social', 'and', 'as', 'different']
# Output words:  ['high', 'that', 'see', 'based', 'not', 'and', 'interest', 'tolstoy', 'theorists', 'much']
# Co-occurrence values:  tensor([0.1667, 2.0000, 0.6111, 1.0000, 0.5000, 1.5500, 0.3333, 1.7500, 0.8333,
#         0.2500])
# Input words:  ['of', 'great', 'behavior', 'autistic', 'institute', 'first', 'its', 'voting', 'being', 'as']
# Output words:  ['like', 'when', 'form', 'national', 'on', 'history', 'may', 'schools', 'be', 'states']
# Co-occurrence values:  tensor([2.1790, 0.3333, 0.2000, 1.0000, 0.2000, 0.7500, 0.5000, 0.1000, 0.1667,
#         1.5333])
# Input words:  ['other', 'more', 'least', 'work', 'activity', 'system', 'movement', 'of', 'to', 'iv']
# Output words:  ['develop', 'autistic', 'age', 'or', 'on', 's', 'within', 'certain', 'against', 'part']
# Co-occurrence values:  tensor([0.6111, 0.9429, 0.2222, 0.1250, 1.0000, 0.2111, 0.8333, 4.1528, 1.1429,
#         0.2500])
# Input words:  ['state', 'property', 'particularly', 'who', 'human', 'delays', 'should', 'tend', 'means', 'on']
# Output words:  ['scale', 'published', 'movement', 'culture', 'of', 'must', 'political', 'to', 'are', 'on']
# Co-occurrence values:  tensor([0.3333, 0.3333, 2.0000, 0.3333, 4.5440, 1.0000, 0.1250, 5.5968, 0.2000,
#         3.4857])
# Input words:  ['also', 'anarchy', 'very', 'surface', 'however', 'was', 'culture', 'against', 'zero', 'power']
# Output words:  ['ideas', 'term', 'human', 'covered', 'developmental', 'g', 'zero', 'an', 'autism', 'against']
# Co-occurrence values:  tensor([0.2429, 0.5000, 0.1250, 0.2500, 0.1429, 0.1667, 0.3333, 0.6833, 5.6909,
#         0.1000])
# Input words:  ['international', 'examples', 'three', 'at', 'not', 'of', 'th', 'these', 'communication', 'been']
# Output words:  ['often', 'or', 'french', 'because', 'few', 'warren', 'considered', 'other', 'found', 'have']
# Co-occurrence values:  tensor([0.1111, 0.1429, 0.2000, 1.5040, 0.1111, 1.4512, 0.2000, 0.1250, 0.2000,
#         7.6429])
# Input words:  ['described', 'theory', 'view', 'on', 'five', 'fact', 'this', 'by', 'authority', 't']
# Output words:  ['autistic', 'however', 'which', 'day', 'society', 'a', 'natural', 'states', 'often', 'these']
# Co-occurrence values:  tensor([0.1429, 0.1111, 1.0000, 0.3333, 0.2000, 0.1667, 1.0179, 0.5778, 0.1250,
#         0.1667])
# Input words:  ['work', 'light', 'with', 'manual', 'anarchism', 'can', 'generally', 'months', 'this', 'list']
# Output words:  ['autistic', 'functioning', 'self', 'years', 'supported', 'control', 'them', 'can', 'level', 'syndicalism']
# Co-occurrence values:  tensor([1.2000, 0.1429, 0.7389, 0.1667, 0.1250, 0.1429, 0.1667, 0.1429, 0.1667,
#         0.1250])
# Input words:  ['developmental', 'has', 'be', 'autistic', 'many', 'an', 'has', 'g', 'british', 'kropotkin']
# Output words:  ['believe', 'difference', 'use', 'autistics', 'led', 'war', 'normal', 'there', 'led', 'liberty']
# Co-occurrence values:  tensor([0.1667, 0.1111, 0.1111, 1.6040, 0.1111, 1.9250, 0.1000, 1.0000, 0.3333,
#         0.1667])
# Input words:  ['individuals', 'was', 'abu', 'related', 'every', 'which', 'than', 'being', 'months', 'true']
# Output words:  ['develop', 'sometimes', 'generally', 'information', 'day', 'action', 'social', 'people', 'during', 't']
# Co-occurrence values:  tensor([0.1250, 1.0000, 0.1429, 1.2111, 1.0000, 0.1667, 1.2500, 0.3750, 1.0833,
#         0.1667])
# Input words:  ['fascism', 'able', 'seven', 'individuals', 'as', 'high', 'anarcha', 'are', 'conflict', 'six']
# Output words:  ['s', 'have', 'about', 'groups', 'reason', 'zero', 'post', 'public', 'on', 'would']
# Co-occurrence values:  tensor([0.1000, 0.4762, 2.1111, 1.1000, 0.3929, 1.9167, 0.1000, 0.3611, 0.2000,
#         0.3929])
# Input words:  ['better', 'to', 'often', 'work', 'a', 'for', 'in', 'rett', 'class', 'links']
# Output words:  ['as', 'argue', 'feminist', 'kropotkin', 'communist', 'described', 'even', 'this', 'war', 'spectrum']
# Co-occurrence values:  tensor([1.1333, 1.5179, 1.5524, 0.3333, 1.0000, 0.3111, 6.1079, 0.1429, 0.1429,
#         0.1250])
# Input words:  ['high', 'large', 'marx', 'it', 'work', 'intellectual', 'more', 'states', 'however', 'iv']
# Output words:  ['g', 'seem', 'was', 'terms', 'example', 'when', 'proudhon', 'awareness', 'because', 'pdd']
# Co-occurrence values:  tensor([0.6111, 0.2000, 1.3540, 0.1250, 0.1429, 0.3333, 0.1111, 0.1111, 0.1000,
#         0.1000])
# Input words:  ['some', 'must', 'similar', 'thought', 'school', 'based', 'the', 'individual', 'which', 'anarchists']
# Output words:  ['anarchists', 'its', 'social', 'associated', 'working', 'may', 'might', 'conflict', 'asperger', 'several']
# Co-occurrence values:  tensor([11.7746,  0.3095,  0.1667,  0.1667,  0.1429,  0.2222,  1.0333,  0.1111,
#          0.2361,  0.7500])
# Input words:  ['economic', 'like', 'are', 'links', 'before', 'economic', 'considered', 'from', 'what', 'was']
# Output words:  ['with', 'development', 'most', 'the', 'where', 'such', 'time', 'things', 'others', 'most']
# Co-occurrence values:  tensor([1.6000, 0.2250, 2.1345, 5.3083, 0.2000, 0.3611, 0.1250, 1.1429, 0.1429,
#         5.0833])
# Input words:  ['further', 'manual', 'libertarian', 'they', 'right', 'spectrum', 'mental', 'does', 'society', 'about']
# Output words:  ['it', 'criteria', 'being', 'interest', 'that', 'able', 'asperger', 'and', 'history', 'october']
# Co-occurrence values:  tensor([1.0000, 0.3333, 0.2000, 0.5000, 1.1929, 0.1000, 0.1000, 0.7262, 0.5000,
#         0.1250])
# Input words:  ['green', 'communists', 'as', 'links', 'books', 'one', 'year', 'in', 'fascist', 'work']
# Output words:  ['anarcha', 'all', 'non', 'with', 'to', 'low', 'generally', 'also', 'also', 'structures']
# Co-occurrence values:  tensor([0.7500, 1.0000, 2.4417, 1.0000, 0.1429, 0.2000, 0.2000, 5.9020, 0.2000,
#         0.4583])
# Input words:  ['and', 'become', 'war', 'not', 'world', 'anarcha', 'what', 'from', 'effects', 'a']
# Output words:  ['institutions', 'environment', 'long', 'godwin', 'people', 'five', 'social', 'international', 'five', 'own']
# Co-occurrence values:  tensor([2.2179, 0.2500, 0.1667, 1.1667, 0.2500, 0.3333, 0.1429, 0.8429, 0.1000,
#         0.9500])
# Input words:  ['the', 'cause', 's', 'disorder', 'must', 'both', 'cause', 'thought', 'than', 'at']
# Output words:  ['nine', 'childhood', 'early', 'kanner', 'fact', 'opposed', 'that', 'present', 'out', 'society']
# Co-occurrence values:  tensor([39.0952,  0.3333,  1.7917,  1.0000,  0.5000,  2.0000,  0.2679,  0.5000,
#          0.1111,  0.1111])
# Input words:  ['difficult', 'treatment', 'specific', 'become', 'there', 'that', 'can', 'against', 'ruler', 'just']
# Output words:  ['body', 'list', 'for', 'as', 'of', 'least', 'into', 's', 'zayed', 'two']
# Co-occurrence values:  tensor([0.1250, 1.2000, 2.7000, 0.3429, 7.6024, 0.6250, 1.4762, 0.5000, 1.0333,
#         1.0000])
# Input words:  ['also', 'war', 'had', 'other', 'individual', 'groups', 'ideas', 'wealth', 'anarchism', 'she']
# Output words:  ['individuals', 'thought', 'communism', 'complete', 'are', 'this', 'believe', 'certain', 'property', 'is']
# Co-occurrence values:  tensor([0.1111, 0.1429, 0.4333, 0.4000, 0.2679, 0.5833, 0.1429, 0.4762, 0.4206,
#         1.6206])
# Input words:  ['communists', 'abu', 'because', 'light', 'system', 'more', 'arab', 'its', 's', 'is']
# Output words:  ['economic', 'links', 'one', 'also', 'free', 'research', 'is', 'sovereignty', 'after', 'color']
# Co-occurrence values:  tensor([0.2500, 0.4861, 0.1250, 0.5000, 1.5000, 0.6667, 0.1000, 0.2500, 0.9028,
#         0.2000])
# Input words:  ['has', 'area', 'post', 'individual', 'reference', 'what', 'are', 'large', 'warren', 'time']
# Output words:  ['themselves', 'at', 'post', 'modern', 'article', 'know', 'against', 'autism', 'on', 'their']
# Co-occurrence values:  tensor([0.1000, 0.1429, 4.3333, 0.3333, 0.3333, 4.4250, 1.1667, 0.2500, 1.0833,
#         1.4583])
# Input words:  ['author', 'today', 'he', 'the', 'oil', 'rothbard', 'years', 'five', 'been', 'famous']
# Output words:  ['social', 'all', 'benjamin', 'health', 'was', 'one', 'cultural', 'anarchism', 'any', 'he']
# Co-occurrence values:  tensor([1.0000, 0.3111, 0.1111, 3.9417, 1.3111, 1.2000, 0.2500, 0.2857, 0.2000,
#         0.1667])
# Input words:  ['revolutionary', 'disorders', 'number', 'problems', 'in', 'its', 'often', 'history', 'have', 'every']
# Output words:  ['small', 'not', 'autistic', 'that', 'communication', 'anarchy', 'like', 'might', 'difficulties', 'daily']
# Co-occurrence values:  tensor([0.1111, 0.1000, 0.2500, 1.3333, 5.3135, 0.8540, 0.2429, 0.1000, 0.1667,
#         0.1000])
# Input words:  ['both', 'rather', 'later', 'feminism', 'has', 'association', 'made', 'parents', 'will', 'by']
# Output words:  ['iq', 's', 'people', 'a', 'reference', 'communism', 'day', 'awareness', 'should', 'few']
# Co-occurrence values:  tensor([0.1000, 0.5000, 0.1667, 2.2417, 0.2000, 0.1111, 0.2000, 0.1667, 0.1667,
#         0.1667])
# Input words:  ['new', 'focus', 'same', 'in', 'stereotyped', 'belief', 'on', 'difference', 'own', 'tend']
# Output words:  ['generally', 'well', 'city', 'controversial', 'a', 'of', 'famous', 'disorder', 'to', 'has']
# Co-occurrence values:  tensor([0.3333, 0.2500, 0.3333, 0.3333, 0.3333, 0.5167, 0.6250, 0.3333, 1.9250,
#         0.1111])
# Input words:  ['see', 'without', 'can', 'fact', 'communism', 'important', 'tend', 'and', 'months', 'and']
# Output words:  ['or', 'anarchism', 'or', 'cause', 'for', 'action', 'since', 'group', 'with', 'tend']
# Co-occurrence values:  tensor([2.1500, 2.5750, 4.6206, 0.1250, 0.3929, 0.2500, 0.1667, 0.9500, 0.4500,
#         0.7262])
# Input words:  ['even', 'individuals', 'on', 'condition', 'of', 'anarchist', 't', 'to', 'similar', 'awareness']
# Output words:  ['about', 'what', 'postal', 'children', 'covered', 'principles', 'any', 'complete', 'autistics', 'include']
# Co-occurrence values:  tensor([0.5000, 0.4444, 0.3667, 0.1667, 1.8417, 2.3500, 0.2000, 0.5000, 0.1429,
#         0.1250])
# Input words:  ['not', 'many', 'new', 'described', 'every', 'group', 'the', 'on', 'average', 'civil']
# Output words:  ['means', 'further', 'it', 'current', 'sensory', 'asperger', 'light', 'views', 'nine', 'american']
# Co-occurrence values:  tensor([0.2250, 0.2429, 0.2250, 0.1667, 0.1667, 0.2000, 7.9512, 0.1000, 0.3111,
#         0.1000])
# Input words:  ['see', 'would', 'physical', 'principles', 'intellectual', 'liberty', 'system', 'movements', 'individual', 'at']
# Output words:  ['different', 'tend', 'rather', 'association', 'all', 'institutions', 'developmental', 'at', 'its', 'great']
# Co-occurrence values:  tensor([0.3333, 1.1429, 0.5000, 0.5000, 0.1250, 0.3333, 0.6667, 0.4345, 0.1000,
#         1.0000])
# Input words:  ['who', 'in', 'anarchists', 'disorder', 'national', 'of', 'authoritarian', 'by', 't', 'just']
# Output words:  ['there', 'earth', 'daily', 'need', 'autism', 'particularly', 'many', 'created', 'spanish', 'example']
# Co-occurrence values:  tensor([1.0000, 0.7694, 0.1667, 0.1429, 1.8317, 1.3929, 0.3333, 2.2000, 0.3750,
#         0.5000])
# Input words:  ['also', 'after', 'behaviors', 'long', 'social', 'but', 'leo', 'of', 'idea', 'following']
# Output words:  ['feminism', 'das', 'following', 'only', 'created', 'individuals', 'famous', 'three', 'groups', 'interest']
# Co-occurrence values:  tensor([ 0.1111,  0.7000,  0.2000,  0.1667,  0.1250,  0.1667,  0.1667, 13.3234,
#          0.2000,  0.1111])
# Input words:  ['how', 'spectrum', 'one', 'six', 'become', 'how', 'many', 'states', 'the', 'such']
# Output words:  ['might', 'members', 'which', 'by', 'them', 'through', 'opposed', 'five', 'authoritarian', 'two']
# Co-occurrence values:  tensor([1.6250, 0.2000, 3.5528, 0.4750, 0.1111, 0.5000, 0.5000, 0.1667, 8.8718,
#         0.2778])
# Input words:  ['british', 'structures', 'these', 'modern', 'is', 'syndicalism', 'they', 'important', 'bakunin', 'within']
# Output words:  ['abu', 'in', 'well', 'other', 'anarchist', 'particularly', 'his', 'complete', 'activity', 'against']
# Co-occurrence values:  tensor([0.5833, 1.2063, 0.1250, 0.1111, 6.4643, 0.4167, 0.1000, 0.5000, 1.0000,
#         0.2500])
# Input words:  ['thought', 'year', 'autistics', 'ability', 'number', 'conflict', 'and', 'associated', 'on', 'individualist']
# Output words:  ['green', 'an', 'more', 'and', 'child', 'lack', 'focus', 'f', 'american', 'that']
# Co-occurrence values:  tensor([0.4333, 0.4250, 0.3667, 0.6429, 0.2361, 0.1429, 1.2417, 0.1429, 0.1111,
#         0.5000])
# Input words:  ['relatively', 'fascists', 'uk', 'author', 's', 'became', 'autistic', 'view', 'had', 'one']
# Output words:  ['children', 'zero', 'org', 'm', 'activity', 'with', 'unusual', 'disorders', 'where', 'international']
# Co-occurrence values:  tensor([0.7000, 0.1000, 1.1667, 1.0000, 0.4333, 0.4762, 0.1000, 0.3333, 0.1429,
#         1.5373])
# Input words:  ['values', 'partly', 'states', 'intellectual', 'small', 'one', 'anarchists', 'forests', 'he', 'is']
# Output words:  ['nine', 'diagnosis', 'fascism', 'these', 'c', 'institute', 'group', 'albedo', 'liberty', 'statistical']
# Co-occurrence values:  tensor([0.1667, 0.1429, 0.2500, 0.1250, 0.1111, 1.7540, 0.7000, 1.8667, 0.3333,
#         0.1429])
# Input words:  ['modern', 'low', 'anti', 'without', 'person', 'can', 'to', 'change', 'emirates', 'more']
# Output words:  ['reference', 'all', 'living', 'the', 'may', 'found', 'anti', 'found', 'made', 'would']
# Co-occurrence values:  tensor([0.1667, 0.1250, 0.2500, 4.3306, 2.2262, 0.8333, 5.4802, 0.1429, 0.1000,
#         1.0000])
# Input words:  ['great', 'stirner', 'autistic', 'not', 'such', 'albedo', 'called', 'certain', 'kropotkin', 'rise']
# Output words:  ['behaviors', 'most', 'services', 'of', 'self', 'known', 'eight', 'such', 'most', 'increase']
# Co-occurrence values:  tensor([ 0.3667,  0.6000,  1.1444, 12.0710,  0.1000,  1.0000,  0.3500,  1.2667,
#          1.2500,  0.2500])
# Input words:  ['sometimes', 'label', 'also', 'resources', 'that', 'social', 'mental', 'abu', 'rather', 'anarchism']
# Output words:  ['be', 'up', 'members', 'oil', 'any', 'this', 'services', 'human', 'members', 'book']
# Co-occurrence values:  tensor([0.7083, 0.3333, 0.2000, 1.0000, 1.6667, 0.8333, 0.1000, 0.1667, 0.1111,
#         1.1667])
# Input words:  ['temperature', 'diagnosis', 'who', 'can', 'today', 'nature', 'became', 's', 'during', 'that']
# Output words:  ['snow', 'due', 'other', 'albedo', 'diagnosis', 's', 'new', 'sovereignty', 'five', 'two']
# Co-occurrence values:  tensor([1.7440, 1.2000, 0.4444, 0.5556, 0.2679, 0.1429, 0.5000, 0.1667, 0.5833,
#         1.8500])
# Input words:  ['them', 'for', 'it', 'autism', 'there', 'rather', 'up', 'communism', 'american', 's']
# Output words:  ['their', 'bakunin', 'others', 'resources', 'students', 'can', 'general', 'bakunin', 'three', 'published']
# Co-occurrence values:  tensor([0.8619, 1.0000, 1.0000, 3.4734, 0.1111, 0.2500, 0.1429, 0.9167, 0.2000,
#         0.2000])
# Input words:  ['radiation', 'argue', 'light', 'anarchists', 'there', 'common', 'list', 'them', 'appear', 'early']
# Output words:  ['snow', 'might', 'which', 'property', 'label', 'reason', 'labels', 'students', 'control', 'due']
# Co-occurrence values:  tensor([0.5000, 0.1429, 1.9167, 0.7778, 0.1250, 0.1000, 0.1000, 1.0000, 0.2500,
#         0.1667])
# Input words:  ['covered', 'tend', 'may', 'study', 'states', 'in', 'way', 'advocate', 'early', 'problems']
# Output words:  ['than', 'autistics', 'with', 'institute', 'spain', 'all', 'able', 'groups', 'development', 'are']
# Co-occurrence values:  tensor([0.2667, 0.2500, 3.5579, 0.3667, 0.2000, 5.7190, 0.2500, 0.3333, 1.2667,
#         0.2000])
# Input words:  ['that', 'be', 'help', 'people', 'very', 'have', 'out', 'autism', 'bakunin', 'law']
# Output words:  ['adults', 'communist', 'speech', 'black', 'has', 'benjamin', 'on', 'popular', 'tolstoy', 'including']
# Co-occurrence values:  tensor([0.3333, 0.3679, 0.6667, 0.1000, 0.3333, 0.1429, 0.5000, 1.6123, 0.1000,
#         0.1250])
# Input words:  ['later', 'early', 'free', 'person', 'form', 'development', 'libertarian', 'autism', 'than', 'and']
# Output words:  ['s', 'the', 'modern', 'can', 'at', 'terms', 'major', 'similar', 'and', 'with']
# Co-occurrence values:  tensor([ 0.8250, 10.1123,  0.1111,  0.4583,  0.4333,  0.1111,  0.1111,  0.5000,
#          2.8206, 27.4405])
# Input words:  ['property', 'proudhon', 'autism', 'individualist', 'are', 'fact', 'a', 'anarchist', 'of', 'that']
# Output words:  ['including', 'what', 'condition', 'was', 'information', 'due', 'age', 'theorists', 'now', 'though']
# Co-occurrence values:  tensor([0.2500, 2.5694, 0.3111, 0.2000, 0.2500, 0.3333, 0.7500, 0.3333, 1.0333,
#         0.5750])
# Input words:  ['however', 'there', 'on', 'right', 'one', 'time', 'what', 'an', 'and', 'libertarian']
# Output words:  ['force', 'will', 'capitalist', 'as', 'production', 'months', 'term', 'own', 'revolutionary', 'by']
# Co-occurrence values:  tensor([0.3333, 0.1000, 0.1429, 1.0444, 1.2500, 0.1111, 0.1000, 0.1667, 2.3500,
#         0.3500])
# Input words:  ['as', 'daily', 'over', 'before', 'for', 'the', 'difficulty', 'th', 'those', 'being']
# Output words:  ['recent', 'also', 'two', 'history', 'means', 'benjamin', 'activity', 'others', 'were', 'which']
# Co-occurrence values:  tensor([0.1250, 0.1250, 1.0000, 1.0000, 1.0000, 0.6500, 0.1111, 0.1250, 1.0000,
#         0.4429])
# Input words:  ['research', 'about', 'light', 'capitalism', 'it', 'much', 'mean', 'in', 'means', 'interests']
# Output words:  ['typical', 'temperature', 'of', 'class', 'in', 'symptoms', 'with', 'global', 'way', 'as']
# Co-occurrence values:  tensor([ 0.5000,  0.1000,  4.1984,  0.3333, 11.9968,  1.0000,  0.3333,  0.1111,
#          0.1667,  0.9000])
# Input words:  ['skills', 'nine', 'is', 'values', 'iq', 'appear', 'may', 'just', 'and', 'amount']
# Output words:  ['adults', 'set', 'associated', 'british', 'both', 'see', 'around', 'are', 'mean', 'usually']
# Co-occurrence values:  tensor([0.2500, 0.3611, 1.0333, 0.1000, 0.1000, 0.1250, 0.1250, 1.1000, 1.1667,
#         0.2500])
# Input words:  ['most', 'developmental', 'interests', 'who', 'this', 'advocate', 'well', 'anarchism', 'philosophy', 'between']
# Output words:  ['them', 'often', 'autistics', 'parents', 'work', 'mutual', 'word', 'recent', 'history', 'their']
# Co-occurrence values:  tensor([0.2500, 0.2500, 0.4762, 1.1000, 1.1429, 0.1429, 0.7500, 1.0000, 0.3333,
#         0.3333])
# Input words:  ['as', 'take', 's', 'effect', 'feminist', 'pervasive', 'book', 'six', 'at', 'capitalism']
# Output words:  ['generally', 'first', 'both', 'regions', 'nine', 'children', 'cnt', 'with', 'who', 'these']
# Co-occurrence values:  tensor([0.9667, 0.1429, 0.5500, 0.2000, 0.4111, 0.1667, 0.1667, 2.8774, 1.2452,
#         0.2500])
# Input words:  ['would', 'their', 'who', 'bakunin', 'an', 'anarchist', 'would', 'out', 'behavior', 'early']
# Output words:  ['mental', 'the', 'those', 'sometimes', 'as', 'involved', 'those', 'students', 'today', 'it']
# Co-occurrence values:  tensor([ 0.1429, 11.9778,  6.6667,  0.3111,  9.5675,  0.1667,  0.1667,  0.2000,
#          0.5000,  0.1429])
# Input words:  ['work', 'should', 'philosophy', 'argue', 'an', 'philosophy', 'anarchism', 'state', 'dhabi', 'information']
# Output words:  ['is', 'if', 'war', 'been', 'low', 'form', 'communist', 'anarchy', 'time', 'well']
# Co-occurrence values:  tensor([0.8262, 0.1250, 0.2000, 0.2500, 0.2429, 0.2000, 1.9167, 0.7000, 2.2333,
#         0.5000])
# Input words:  ['century', 'skills', 'workers', 'from', 'f', 'examples', 'nature', 'part', 'activity', 'snow']
# Output words:  ['many', 'argue', 'control', 'where', 'c', 'is', 'idea', 'dsm', 'research', 'because']
# Co-occurrence values:  tensor([0.1111, 0.1429, 0.3333, 0.2000, 2.0000, 0.1000, 0.2500, 0.3333, 0.1250,
#         1.6250])
# Input words:  ['not', 'in', 'where', 'as', 'rights', 'if', 'these', 'normal', 'must', 'who']
# Output words:  ['diagnosed', 'trees', 'this', 'mental', 'anti', 'eight', 'thought', 'are', 'to', 'often']
# Co-occurrence values:  tensor([0.3333, 1.1302, 0.1250, 1.0944, 0.5000, 0.6000, 0.1250, 0.9611, 0.2500,
#         0.5000])
# Input words:  ['france', 'free', 'intellectual', 'see', 'anarcho', 'from', 'two', 'much', 'in', 'repetitive']
# Output words:  ['was', 'movement', 'some', 'more', 'just', 'no', 'these', 'this', 'behaviors', 'delays']
# Co-occurrence values:  tensor([0.1250, 1.0000, 0.1000, 1.9444, 0.1000, 0.7833, 2.2500, 0.5000, 0.7500,
#         0.1000])
# Input words:  ['functioning', 'has', 'were', 'anarchists', 'disorder', 'behaviors', 'different', 'and', 'a', 'later']
# Output words:  ['further', 'both', 'early', 'while', 'speech', 'also', 'disorders', 'famous', 'many', 'power']
# Co-occurrence values:  tensor([0.1111, 0.1429, 0.6429, 0.9222, 0.2500, 0.5000, 0.1000, 0.4345, 6.8579,
#         0.5000])
# Input words:  ['communism', 'now', 'different', 'right', 'few', 'at', 'from', 'during', 'their', 'anarcha']
# Output words:  ['major', 'liberty', 'can', 'of', 'at', 'while', 'zayed', 'when', 'also', 'authoritarian']
# Co-occurrence values:  tensor([0.1000, 0.2500, 1.0167, 3.4028, 0.6667, 1.0000, 0.2222, 0.4167, 1.2250,
#         0.1667])
# Input words:  ['a', 'sensory', 'until', 'regions', 'from', 'is', 'five', 'examples', 'must', 'throughout']
# Output words:  ['color', 'those', 'work', 'earth', 'environmental', 'principles', 'health', 'author', 'as', 'people']
# Co-occurrence values:  tensor([1.3250, 0.4333, 0.5000, 0.6000, 0.5000, 0.1111, 0.3679, 0.1429, 0.1667,
#         0.4000])
# Input words:  ['speech', 'are', 'rothbard', 'able', 'significant', 'treatment', 'them', 'action', 'that', 'only']
# Output words:  ['institute', 'time', 'including', 'be', 'for', 'do', 'at', 'believe', 'tend', 'over']
# Co-occurrence values:  tensor([0.2500, 0.1429, 0.2000, 1.6000, 0.1429, 1.0929, 0.5000, 0.1111, 0.1429,
#         0.2917])
# Input words:  ['philosophy', 'mental', 'information', 'more', 'will', 'theory', 'two', 'n', 'other', 'would']
# Output words:  ['only', 'example', 'this', 'iv', 'which', 'term', 'found', 'cnt', 'natural', 'symptoms']
# Co-occurrence values:  tensor([0.2000, 0.3000, 0.2500, 0.1667, 0.1111, 0.1250, 0.1429, 0.5000, 0.3000,
#         0.3333])
# Input words:  ['certain', 'where', 'within', 'have', 'black', 'than', 'a', 'considered', 'culture', 'spanish']
# Output words:  ['with', 'was', 'have', 'also', 'life', 'however', 'who', 'six', 'just', 'that']
# Co-occurrence values:  tensor([1.7901, 0.1250, 0.1429, 2.3111, 0.2000, 0.1000, 7.6575, 0.1667, 1.0000,
#         0.2679])
# Input words:  ['and', 'government', 'for', 'functioning', 'warren', 'if', 'be', 'supported', 'functioning', 'children']
# Output words:  ['leo', 'his', 'n', 'there', 'through', 'by', 'late', 'opposed', 'following', 'is']
# Co-occurrence values:  tensor([1.5333, 0.1429, 0.1250, 0.1000, 1.0000, 0.4095, 0.3333, 0.1667, 0.2857,
#         1.6952])
# Input words:  ['abu', 'person', 'was', 'students', 'anarchists', 'focus', 'often', 'further', 'several', 'including']
# Output words:  ['within', 'out', 'as', 'behavior', 'by', 'who', 'referred', 'in', 'must', 'over']
# Co-occurrence values:  tensor([1.1111, 0.1667, 4.9964, 0.1111, 5.9817, 0.1250, 1.1111, 0.9583, 0.1429,
#         0.2500])
# Input words:  ['long', 'was', 'an', 'syndrome', 'by', 'first', 'be', 'working', 'form', 'spectrum']
# Output words:  ['use', 'spectrum', 'time', 'four', 'they', 'who', 'regions', 'early', 'would', 'view']
# Co-occurrence values:  tensor([0.1111, 0.2000, 1.2000, 0.1000, 2.6194, 0.3429, 0.3333, 1.2000, 0.4000,
#         0.3333])
# Input words:  ['behaviors', 'children', 'three', 'symptoms', 'environment', 'though', 'society', 'at', 'rather', 'different']
# Output words:  ['well', 'not', 'on', 'who', 'seven', 'some', 'however', 'communism', 'oil', 'economic']
# Co-occurrence values:  tensor([0.1429, 1.1901, 2.9929, 0.3429, 0.1667, 0.4762, 1.1667, 1.1250, 0.3111,
#         0.2917])
# Input words:  ['within', 'kanner', 'used', 'rather', 'free', 'within', 'he', 'for', 'group', 'known']
# Output words:  ['within', 'autism', 'al', 'as', 'system', 'view', 'child', 'parents', 'civil', 'some']
# Co-occurrence values:  tensor([0.4000, 0.7500, 0.1429, 1.1667, 1.5000, 0.1111, 0.6429, 1.2500, 0.2000,
#         0.1000])
# Input words:  ['were', 'list', 'non', 'states', 'working', 'sensory', 'other', 'color', 'rights', 'uk']
# Output words:  ['also', 'in', 'common', 'trucial', 'th', 'autism', 'several', 'was', 'work', 'the']
# Co-occurrence values:  tensor([0.1667, 0.7889, 0.2540, 6.1111, 0.5000, 0.7889, 0.1111, 1.0000, 0.1000,
#         5.6524])
# Input words:  ['were', 'movement', 'ability', 'to', 'only', 'city', 'anarchist', 'where', 'cnt', 'term']
# Output words:  ['s', 'take', 'people', 'own', 'interpretations', 'international', 'after', 'major', 'anarcho', 'it']
# Co-occurrence values:  tensor([1.1968, 0.2000, 0.2000, 1.9250, 0.1000, 0.6111, 0.1250, 0.1111, 0.1250,
#         1.6667])
# Input words:  ['was', 'means', 'an', 'it', 'snow', 'nine', 'often', 'government', 'to', 'form']
# Output words:  ['theorists', 'such', 'western', 'anarcho', 'tend', 'within', 'interests', 'for', 'marx', 'cnt']
# Co-occurrence values:  tensor([0.1429, 0.6667, 1.0000, 0.9222, 0.1111, 0.4095, 0.3611, 0.2250, 1.4722,
#         0.1429])
# Input words:  ['increase', 'such', 'this', 'statistical', 'prior', 'communication', 'where', 'age', 'other', 'a']
# Output words:  ['has', 'age', 'was', 'are', 'statistical', 'is', 'but', 'following', 'links', 'arab']
# Co-occurrence values:  tensor([0.2361, 0.1667, 3.2040, 0.1667, 0.1111, 0.6706, 0.5000, 0.4000, 0.2000,
#         0.1667])
# Input words:  ['terms', 'law', 'should', 'asperger', 'five', 'an', 'individual', 'trade', 'speech', 'late']
# Output words:  ['public', 'its', 'to', 'intellectual', 'on', 'cultural', 'high', 'one', 'no', 'this']
# Co-occurrence values:  tensor([0.5000, 0.1429, 0.5417, 0.5000, 0.9762, 0.1000, 0.1111, 0.4722, 2.0000,
#         0.2000])
# Input words:  ['people', 'view', 'structures', 'those', 'ability', 'or', 'which', 'are', 'common', 'than']
# Output words:  ['diagnosed', 'group', 'individuals', 'against', 'of', 'effect', 'sensory', 'than', 'interests', 'autistic']
# Co-occurrence values:  tensor([1.0000, 0.2000, 0.2500, 0.2361, 2.3778, 0.1429, 1.9000, 2.0635, 0.5000,
#         1.4333])
# Input words:  ['use', 'surface', 'government', 'most', 'are', 'behavior', 'by', 'with', 'another', 'spanish']
# Output words:  ['later', 'before', 's', 'nine', 'referred', 'them', 'including', 'if', 'these', 'four']
# Co-occurrence values:  tensor([0.2000, 0.2000, 0.2429, 1.5444, 1.2000, 0.1000, 0.6667, 0.2500, 0.3333,
#         0.3540])
# Input words:  ['capitalism', 'anti', 'specific', 'english', 'communicate', 'different', 'light', 'means', 'higher', 'stereotyped']
# Output words:  ['does', 'anarcha', 'also', 'used', 'language', 'described', 'three', 'power', 'no', 'few']
# Co-occurrence values:  tensor([0.6444, 0.2000, 0.2500, 0.4444, 0.3333, 0.5000, 0.1250, 0.1111, 1.0000,
#         0.2500])
# Input words:  ['snow', 'one', 'much', 's', 'front', 'different', 'europe', 'albedo', 'lack', 'anarchy']
# Output words:  ['tropical', 'conflict', 'dsm', 'many', 'state', 'there', 'later', 'structures', 'the', 'was']
# Co-occurrence values:  tensor([0.1667, 0.7278, 0.1667, 2.8579, 0.1667, 0.4444, 0.1250, 0.2667, 2.1056,
#         0.2500])
# Input words:  ['syndrome', 'communist', 'dsm', 'stirner', 'parents', 'these', 'four', 'as', 'rights', 'institutions']
# Output words:  ['areas', 'should', 'criteria', 'theory', 'are', 'used', 'usually', 'capitalist', 'how', 'most']
# Co-occurrence values:  tensor([0.3000, 0.1667, 1.4333, 0.2000, 0.3333, 0.4250, 0.2540, 0.7667, 0.1111,
#         0.6250])
# Input words:  ['english', 'their', 'workers', 'examples', 'list', 'behaviors', 'typical', 'eight', 'up', 'called']
# Output words:  ['they', 'from', 'to', 'this', 'this', 'use', 'he', 'spanish', 'violent', 'on']
# Co-occurrence values:  tensor([0.1111, 0.5000, 2.5651, 0.1000, 0.4750, 0.5000, 0.8111, 0.4345, 0.1000,
#         0.6333])
# Input words:  ['some', 'sensory', 'normal', 'bakunin', 'autism', 'authority', 'living', 'was', 'to', 'temperature']
# ...
#         1.5833])
# Input words:  ['no', 'are', 'has', 'are', 'temperature', 'rothbard', 'many', 'usually', 'only', 'tucker']
# Output words:  ['which', 'violence', 'movement', 'about', 'about', 'including', 'groups', 'autism', 'and', 'two']
# Co-occurrence values:  tensor([0.5000, 0.1111, 2.0000, 0.6111, 0.1000, 0.2000, 1.4583, 1.2000, 1.3790,
#         0.2500])
# Input words:  ['health', 'often', 'these', 'throughout', 'because', 'stereotyped', 'communication', 'schools', 'communities', 'life']
# Output words:  ['health', 'international', 'she', 'argue', 'based', 'e', 'childhood', 'problems', 'people', 'few']
# Co-occurrence values:  tensor([1.6667, 0.1111, 0.5179, 0.3333, 0.1250, 0.3333, 0.5000, 0.5000, 0.2917,
#         0.6667])
# Input words:  ['most', 'color', 'in', 'over', 'increase', 'better', 't', 'government', 'people', 'revolutionary']
# Output words:  ['before', 'non', 'cause', 'anarcha', 'different', 'diagnostic', 'work', 'two', 'considered', 'for']
# Co-occurrence values:  tensor([0.1250, 0.6111, 1.2111, 1.0000, 0.1429, 0.1000, 1.2667, 0.1111, 0.3333,
#         0.5444])
# Input words:  ['in', 'm', 'those', 'that', 'by', 'should', 'natural', 'dhabi', 'current', 'with']
# Output words:  ['direct', 'british', 'capitalism', 'temperature', 'europe', 't', 'green', 'modern', 'adults', 'every']
# Co-occurrence values:  tensor([1.2194, 0.1000, 0.1000, 0.1429, 0.3778, 0.5000, 0.2500, 0.5000, 0.3667,
#         1.9500])
# Input words:  ['play', 'of', 'point', 'dhabi', 'france', 'information', 'n', 'point', 'early', 'use']
# Output words:  ['into', 'also', 'godwin', 'view', 'was', 'anarchism', 'most', 'anarchy', 'de', 'they']
# Co-occurrence values:  tensor([ 1.0000, 14.0655,  0.1250,  0.5000,  0.1250,  0.3111,  0.3333,  0.2500,
#          0.3333,  0.6361])
# Input words:  ['man', 'nine', 'due', 'effect', 'including', 'that', 'schools', 'the', 'themselves', 'six']
# Output words:  ['every', 'g', 'an', 'autism', 'form', 'play', 'much', 'term', 'of', 'national']
# Co-occurrence values:  tensor([ 0.2500,  0.2667,  0.9444,  0.1250,  0.1000,  1.0000,  0.1111, 17.8135,
#          2.0429,  0.5833])
# Input words:  ['a', 'autism', 'zero', 'around', 'what', 'man', 'and', 'known', 'or', 'zero']
# Output words:  ['be', 'british', 'first', 'uae', 'every', 'now', 'global', 'nine', 'statistical', 'most']
# Co-occurrence values:  tensor([10.8357,  0.2857,  0.3750,  0.1250,  0.1429,  0.2500,  0.2429,  0.8873,
#          0.1667,  2.2012])
# Input words:  ['an', 'these', 'four', 'anarchism', 'created', 'specific', 'iv', 'believe', 'autism', 'single']
# Output words:  ['others', 'conflict', 'to', 'environment', 's', 'anarchism', 'few', 'although', 'throughout', 'human']
# Co-occurrence values:  tensor([0.4444, 0.1250, 2.6067, 0.4762, 0.2500, 0.8250, 0.2000, 0.1000, 0.3333,
#         0.1111])
# Input words:  ['considered', 'behaviors', 'much', 'with', 'single', 'she', 'syndicalist', 'or', 'earth', 'bakunin']
# Output words:  ['school', 'about', 'by', 'language', 'movements', 'another', 'cnt', 'diagnostic', 'average', 'leo']
# Co-occurrence values:  tensor([0.1250, 0.1000, 0.2500, 3.3456, 0.5000, 0.1111, 0.1111, 0.7944, 0.3333,
#         0.1111])
# Input words:  ['supported', 'four', 'functioning', 'such', 'relatively', 'criteria', 'treatment', 'use', 'europe', 'advocate']
# Output words:  ['an', 'many', 'labels', 'anarchists', 'in', 'autistic', 'often', 'certain', 'century', 'means']
# Co-occurrence values:  tensor([0.1667, 0.1667, 1.1250, 2.1040, 1.0218, 0.5000, 0.1429, 0.3333, 2.0000,
#         0.1250])
# Input words:  ['may', 'snow', 'most', 'anarchists', 'for', 'who', 'months', 'its', 'abu', 'years']
# Output words:  ['appear', 'increase', 'known', 'major', 'all', 'five', 'development', 'kingdom', 'be', 'must']
# Co-occurrence values:  tensor([0.2361, 0.4540, 0.2000, 0.3929, 0.9083, 0.1250, 0.1667, 0.2000, 0.4762,
#         0.1667])
# Input words:  ['them', 'the', 'a', 'and', 'relatively', 'number', 'means', 'its', 'two', 'kanner']
# Output words:  ['students', 'power', 'right', 'treatment', 'man', 'people', 'the', 'some', 'reference', 'significant']
# Co-occurrence values:  tensor([1.0000, 1.9040, 3.8111, 0.8111, 0.3333, 0.5000, 7.7762, 0.4333, 0.1250,
#         0.2000])
# Input words:  ['government', 'by', 'fascists', 'do', 'advocate', 'popular', 'thought', 'on', 'made', 'of']
# Output words:  ['anarchism', 'see', 'anarchists', 'two', 'based', 'common', 'adults', 'condition', 'if', 'usually']
# Co-occurrence values:  tensor([0.7000, 0.9028, 0.5679, 0.1000, 0.5000, 0.1429, 0.1111, 0.1000, 0.2500,
#         0.4861])
# Input words:  ['m', 'united', 'structures', 'later', 'individuals', 'so', 'dhabi', 'it', 'later', 'his']
# Output words:  ['study', 'sometimes', 'syndicalism', 'zero', 'any', 'tend', 'same', 'groups', 'parents', 'three']
# Co-occurrence values:  tensor([0.3333, 0.2000, 0.5000, 0.3333, 0.1667, 0.1429, 0.1429, 0.6250, 0.1667,
#         0.4500])
# Input words:  ['learning', 'popular', 'word', 'disorders', 'by', 'to', 'normal', 'early', 'that', 'specific']
# Output words:  ['autistic', 'asperger', 'until', 'functioning', 'more', 'regions', 'as', 'william', 'areas', 'see']
# Co-occurrence values:  tensor([0.1250, 0.5000, 0.1250, 0.1111, 2.7889, 0.1000, 0.1429, 0.1667, 0.1667,
#         1.1667])
# Input words:  ['spanish', 'certain', 'being', 'certain', 'have', 'although', 'in', 'recent', 'a', 'school']
# Output words:  ['and', 'focus', 'there', 'to', 'word', 'now', 'scale', 'has', 'with', 'difference']
# Co-occurrence values:  tensor([ 2.7429,  0.1111,  0.2679,  2.6734,  0.2000,  0.1000,  0.4583,  0.5000,
#         24.2825,  0.3333])
# Input words:  ['forests', 'albedo', 'over', 'an', 'so', 'his', 'childhood', 'current', 'anarchist', 's']
# Output words:  ['themselves', 'when', 'there', 'from', 'throughout', 'time', 'that', 'autistic', 'can', 'had']
# Co-occurrence values:  tensor([0.1429, 0.1667, 0.6012, 2.9774, 0.3333, 0.3333, 1.3333, 0.3333, 0.1429,
#         0.2500])
# Input words:  ['al', 'for', 'states', 'international', 'with', 'does', 'called', 'the', 'in', 'eight']
# Output words:  ['six', 'principles', 'trucial', 'of', 'all', 'anarchy', 'warren', 'communication', 'she', 'as']
# Co-occurrence values:  tensor([0.6250, 0.2000, 6.1111, 0.5417, 1.2833, 0.1667, 0.4540, 1.0218, 0.3250,
#         1.7591])
# Input words:  ['but', 'study', 'there', 'cnt', 'as', 'that', 'the', 'living', 'class', 'how']
# Output words:  ['because', 'cure', 'because', 'six', 'institute', 'but', 'large', 'some', 'state', 'has']
# Co-occurrence values:  tensor([0.8333, 0.1667, 0.8095, 1.2167, 0.2540, 2.6857, 2.9579, 0.1429, 0.1667,
#         0.3333])
# Input words:  ['and', 'one', 'workers', 'developmental', 'part', 'form', 'libertarian', 'three', 'were', 'so']
# Output words:  ['how', 'rise', 'system', 'or', 'nine', 'but', 'some', 'although', 'its', 'set']
# Co-occurrence values:  tensor([1.0425, 0.1250, 0.1000, 1.6452, 0.5167, 0.1000, 0.9000, 0.1429, 0.3917,
#         0.1111])
# Input words:  ['an', 'but', 'these', 'covered', 'zero', 'believe', 'just', 'up', 'things', 'year']
# Output words:  ['political', 'months', 'set', 'famous', 'must', 'has', 'other', 'that', 'lack', 'idea']
# Co-occurrence values:  tensor([1.2500, 0.3333, 1.1667, 0.1111, 0.2500, 0.1667, 0.3111, 0.1429, 0.1429,
#         0.1667])
# Input words:  ['upon', 'groups', 'mental', 'october', 'christian', 'new', 'one', 'may', 'by', 'three']
# Output words:  ['in', 'adults', 'present', 'workers', 'is', 'culture', 'abu', 'around', 'health', 'united']
# Co-occurrence values:  tensor([0.1000, 0.1111, 0.1667, 0.1000, 0.4667, 0.3095, 2.8194, 0.1250, 0.7667,
#         0.3111])
# Input words:  ['need', 'long', 'fact', 'person', 'it', 'right', 'opposed', 'have', 'autistic', 'own']
# Output words:  ['a', 'led', 'must', 'themselves', 'leo', 'goldman', 'adults', 'made', 'what', 'language']
# Co-occurrence values:  tensor([0.8278, 0.1429, 0.5000, 0.1250, 0.3333, 0.1000, 0.1000, 1.1250, 1.1857,
#         0.3333])
# Input words:  ['albedo', 'social', 'power', 'into', 'them', 'be', 'such', 'idea', 'that', 'class']
# Output words:  ['temperature', 'most', 'months', 'often', 'even', 'speech', 'principles', 'his', 'war', 'ideas']
# Co-occurrence values:  tensor([1.5000, 1.3333, 1.0000, 1.0000, 1.5000, 0.3333, 0.1250, 0.2000, 1.8472,
#         0.2000])
# Input words:  ['further', 'modern', 'cgt', 'development', 's', 'many', 'of', 'example', 'when', 'have']
# Output words:  ['belief', 'mean', 'trade', 'because', 'capitalism', 'in', 'interests', 'might', 'her', 'four']
# Co-occurrence values:  tensor([ 0.2000,  0.1250,  0.1000,  0.1111,  0.4762, 14.1821,  5.2774,  0.3333,
#          1.3095,  0.3929])
# Input words:  ['known', 'violent', 'so', 'four', 'at', 'environment', 'europe', 'and', 'able', 'often']
# Output words:  ['repetitive', 'government', 'problems', 'through', 'better', 'focus', 'led', 'interpretations', 'much', 'conflict']
# Co-occurrence values:  tensor([1.0000, 0.3333, 0.3333, 0.2000, 0.2778, 0.3333, 1.0000, 1.7500, 0.1250,
#         0.2000])
# Input words:  ['an', 'no', 'theory', 'all', 'in', 't', 'from', 'most', 'certain', 'also']
# Output words:  ['ideas', 'would', 'use', 'great', 'great', 'what', 'functioning', 'common', 'much', 'small']
# Co-occurrence values:  tensor([1.0262, 1.5000, 0.2000, 0.2000, 4.8361, 0.2500, 1.1111, 1.0000, 1.0000,
#         0.7000])
# Input words:  ['their', 'repetitive', 'modern', 'anarchism', 'american', 'not', 'must', 'area', 'behavior', 'see']
# Output words:  ['those', 'conditions', 'also', 'referred', 'where', 'development', 'disorder', 'would', 'important', 'emma']
# Co-occurrence values:  tensor([1.2778, 0.1000, 0.2500, 1.5111, 0.2500, 0.3333, 0.5000, 0.3333, 0.3333,
#         0.1111])
# Input words:  ['the', 'most', 'mental', 'anarchists', 'was', 'left', 'anarchy', 'color', 'children', 'take']
# Output words:  ['self', 'surface', 'group', 'at', 'called', 'nine', 'include', 'theorists', 'which', 'feminism']
# Co-occurrence values:  tensor([9.0746, 1.0000, 0.4762, 0.2500, 0.1111, 0.1429, 1.5000, 0.3333, 0.2000,
#         0.5000])
# Input words:  ['of', 'e', 'must', 't', 'iq', 'against', 'since', 'a', 'have', 'described']
# Output words:  ['individual', 'areas', 'conditions', 'world', 'in', 'six', 'speech', 'children', 'had', 'society']
# Co-occurrence values:  tensor([5.1833, 0.1667, 0.1667, 0.1111, 0.3667, 0.3333, 0.1429, 2.1365, 0.1667,
#         0.3333])
# Input words:  ['feminism', 'emirates', 'all', 'anarchist', 'use', 'an', 'libertarian', 'high', 'speech', 'by']
# Output words:  ['human', 'emirates', 'major', 'list', 'authoritarian', 'now', 'early', 'being', 'still', 'better']
# Co-occurrence values:  tensor([0.1429, 2.0667, 1.0000, 3.6972, 0.1111, 0.5000, 0.1111, 0.1429, 0.1000,
#         0.5000])
# Input words:  ['with', 'zero', 'on', 'complete', 'behaviors', 'ideas', 'work', 'effect', 'true', 'who']
# Output words:  ['pervasive', 'f', 'should', 'important', 'might', 'movement', 'argue', 'late', 'bakunin', 'used']
# Co-occurrence values:  tensor([0.5873, 2.4000, 0.1111, 0.5000, 1.0000, 0.7679, 0.1000, 0.1000, 0.1429,
#         0.3929])
# Input words:  ['both', 'in', 'just', 'related', 'any', 'problems', 'within', 'spanish', 'october', 'europe']
# Output words:  ['until', 'kingdom', 'those', 'with', 'social', 'those', 'both', 'four', 'org', 'in']
# Co-occurrence values:  tensor([0.1667, 1.2389, 0.1250, 0.2917, 1.1111, 0.1667, 0.3333, 0.3540, 0.2500,
#         4.7468])
# Input words:  ['state', 'modern', 'be', 'which', 'health', 'been', 'although', 'is', 'part', 'although']
# Output words:  ['fascism', 'first', 'which', 'nature', 'american', 'over', 'three', 'self', 'relatively', 'godwin']
# Co-occurrence values:  tensor([0.1667, 0.6667, 0.7500, 0.3333, 0.2000, 0.3000, 0.1429, 1.8052, 0.2000,
#         1.3611])
# Input words:  ['human', 'include', 'syndicalism', 'four', 'one', 'language', 'two', 'links', 'new', 'during']
# Output words:  ['much', 'structures', 'the', 'year', 'society', 'single', 'living', 'links', 'themselves', 'nine']
# Co-occurrence values:  tensor([1.0000, 0.4444, 3.1234, 1.1250, 0.9444, 0.1000, 0.1000, 0.6857, 0.2000,
#         0.7778])
# Input words:  ['capitalist', 'british', 'light', 'how', 'godwin', 'fascism', 'of', 'able', 'eight', 'because']
# Output words:  ['of', 'zayed', 'five', 's', 'published', 'anarcho', 'he', 'may', 'anarchists', 'voting']
# Co-occurrence values:  tensor([1.5218, 0.5000, 0.1111, 0.1429, 1.2500, 0.2000, 4.6663, 0.2000, 1.8944,
#         1.5000])
# Input words:  ['revolutionary', 'most', 'who', 'by', 'language', 'of', 'typical', 'much', 'as', 'at']
# Output words:  ['cnt', 'of', 'first', 'what', 'functioning', 'well', 'her', 'few', 'between', 'term']
# Co-occurrence values:  tensor([ 0.1667, 12.5869,  0.3429,  2.6012,  1.0000,  2.9833,  0.1429,  0.5000,
#          0.7611,  0.2679])
# Input words:  ['of', 'power', 'number', 'be', 'arab', 'to', 'children', 'form', 'four', 'fascist']
# Output words:  ['left', 'to', 'is', 'city', 'six', 'liberty', 'will', 'communities', 'was', 'fascism']
# Co-occurrence values:  tensor([1.8306, 3.4540, 0.8540, 0.5000, 0.7857, 0.3095, 1.5833, 2.5000, 0.5095,
#         0.5762])
# Input words:  ['in', 'their', 'are', 'about', 'institute', 'their', 'the', 'mutual', 'abu', 'communism']
# Output words:  ['particular', 'many', 'dsm', 'oil', 'two', 'throughout', 'anarchist', 'other', 'often', 'movements']
# Co-occurrence values:  tensor([ 3.4361,  1.1667,  0.3111,  0.1667,  0.3250,  3.0000, 29.0083,  0.5000,
#          0.1667,  0.2500])
# Input words:  ['was', 'has', 'like', 'although', 'two', 'been', 'behavior', 'workers', 'disorders', 'cure']
# Output words:  ['arab', 'body', 'n', 'dsm', 'language', 'post', 'communication', 'us', 'referred', 'cure']
# Co-occurrence values:  tensor([0.5833, 0.2667, 1.0000, 0.1111, 2.1429, 0.7000, 0.2361, 1.1111, 0.4167,
#         1.8056])
# Input words:  ['violence', 'revolutionary', 'work', 'difficult', 'kanner', 'focus', 'so', 'all', 'learning', 'not']
# Output words:  ['theory', 'spanish', 'might', 'against', 'nine', 'that', 'however', 'since', 'another', 'anarchist']
# Co-occurrence values:  tensor([0.1111, 0.1429, 1.0000, 0.1111, 0.3429, 0.3750, 0.1111, 0.5000, 0.1250,
#         2.3833])
# Input words:  ['a', 'its', 'delays', 'in', 'same', 'because', 'six', 'have', 'both', 'amount']
# Output words:  ['godwin', 'other', 'skills', 'ability', 'to', 'all', 'united', 'often', 'some', 'to']
# Co-occurrence values:  tensor([0.2500, 0.2500, 0.4500, 1.5833, 0.4444, 1.0000, 0.8694, 1.3750, 0.1429,
#         0.6111])
# Input words:  ['different', 'as', 'more', 'years', 'oil', 'such', 'form', 'such', 'syndicalism', 'been']
# Output words:  ['learning', 'means', 'anarcha', 'disorder', 'island', 'anti', 'some', 'liberty', 'that', 'symptoms']
# Co-occurrence values:  tensor([0.1111, 0.8500, 0.1667, 0.1111, 0.2500, 0.6111, 0.1111, 0.2917, 0.2500,
#         0.4333])
# Input words:  ['social', 'anarchy', 'daily', 'often', 'time', 'upon', 'general', 'relatively', 'cure', 'one']
# Output words:  ['within', 'nature', 'industrial', 'autism', 'children', 'association', 'because', 'their', 'the', 'low']
# Co-occurrence values:  tensor([0.1111, 0.2778, 0.2500, 5.4230, 0.3429, 1.0000, 0.1667, 0.3500, 2.8917,
#         0.2000])
# Input words:  ['at', 'the', 'level', 'kropotkin', 'public', 'around', 'city', 'any', 'it', 'environment']
# Output words:  ['eight', 'problems', 'individuals', 'books', 'are', 'on', 'spain', 'need', 'al', 'anarchism']
# Co-occurrence values:  tensor([1.3667, 3.2278, 0.2500, 0.1111, 0.3611, 0.3750, 0.1429, 0.1250, 0.2000,
#         0.4762])
# Input words:  ['because', 'six', 'health', 'although', 'author', 'authoritarian', 'involved', 'are', 'nature', 'values']
# Output words:  ['pdd', 'two', 'activity', 'kanner', 'created', 'was', 'over', 'communities', 'anarchists', 'albedo']
# Co-occurrence values:  tensor([0.1429, 5.0024, 0.1429, 1.0000, 0.2667, 0.3333, 0.3333, 0.1667, 0.1667,
#         1.5000])
# Input words:  ['anarchism', 'structures', 'age', 'of', 'a', 'terms', 'such', 'use', 'f', 'anti']
# Output words:  ['including', 'they', 'anarchists', 'often', 'became', 'high', 'right', 'rather', 'a', 'political']
# Co-occurrence values:  tensor([1.1429, 0.1250, 0.2429, 6.0353, 0.4667, 0.3333, 0.5000, 0.1667, 0.8222,
#         0.1111])
# Loss: 0.0007993144681677222

# %% [markdown]
# -> Giá trị loss sau cùng là: 0.0007993144681677222

# %%
dataset.word2idx.keys()
# Out:
# dict_keys(['the', 'of', 'and', 'in', 'to', 'a', 'one', 'is', 'as', 'autism', 'that', 'zero', 'with', 'or', 'for', 'nine', 's', 'anarchism', 'are', 'autistic', 'by', 'anarchists', 'on', 'be', 'two', 'an', 'it', 'from', 'not', 'anarchist', 'this', 'was', 'have', 'some', 'they', 'people', 'many', 'eight', 'at', 'three', 'also', 'which', 'six', 'social', 'such', 'other', 'their', 'can', 'has', 'abu', 'dhabi', 'more', 'most', 'see', 'often', 'may', 'five', 'who', 'about', 'seven', 'there', 'four', 'anarcho', 'first', 'but', 'movement', 'albedo', 'were', 'his', 'disorder', 'state', 'its', 'children', 'all', 'than', 'these', 'society', 'what', 'language', 'disorders', 'syndrome', 'spectrum', 'use', 'he', 'groups', 'early', 'anti', 'would', 'them', 'child', 'asperger', 'movements', 'however', 'so', 'those', 'term', 'used', 'property', 'form', 'when', 'do', 'united', 'post', 'high', 'been', 'although', 'ideas', 'within', 'person', 'different', 'developmental', 'autistics', 'individuals', 'others', 'war', 'general', 'even', 'against', 'authoritarian', 'anarchy', 'will', 'no', 'proudhon', 'due', 'example', 'non', 'because', 'self', 'workers', 'over', 'capitalism', 'if', 'communication', 'while', 'had', 'called', 'new', 'cnt', 'violence', 'like', 'development', 'out', 'diagnosis', 'increase', 'functioning', 'snow', 'history', 'century', 'being', 'bakunin', 'both', 'world', 'another', 'information', 'part', 'pervasive', 'revolution', 'means', 'work', 'sometimes', 'during', 'number', 'much', 'lack', 'system', 'after', 'into', 'national', 'states', 'areas', 'certain', 'feminist', 'age', 'mental', 'effect', 'class', 'including', 'believe', 'human', 'individual', 'since', 'time', 'years', 'include', 'spanish', 'left', 'common', 'culture', 'interaction', 'least', 'behavior', 'normal', 'emirates', 'island', 'oil', 'up', 'without', 'political', 'philosophy', 'should', 'related', 'th', 'modern', 'major', 'through', 'community', 'international', 'around', 'must', 'syndicalism', 'group', 'city', 'feminism', 'list', 'cure', 'body', 'area', 'al', 'way', 'based', 'kropotkin', 'resources', 'found', 'considered', 'communism', 'civil', 't', 'own', 'right', 'only', 'i', 'thought', 'links', 'between', 'need', 'nature', 'industrial', 'action', 'life', 'popular', 'government', 'months', 'well', 'anarcha', 'she', 'health', 'symptoms', 'adults', 'able', 'dsm', 'sensory', 'rett', 'average', 'trees', 'das', 'working', 'any', 'does', 'rather', 'structures', 'economic', 'might', 'argue', 'before', 'true', 'known', 'until', 'labor', 'individualist', 'her', 'revolutionary', 'communists', 'important', 'late', 'further', 'christian', 'institute', 'g', 'spain', 'just', 'environment', 'earth', 'interests', 'specific', 'treatment', 'following', 'conditions', 'diagnostic', 'skills', 'generally', 'research', 'childhood', 'problems', 'level', 'radiation', 'arab', 'postal', 'french', 'word', 'institutions', 'association', 'free', 'how', 'similar', 'every', 'where', 'described', 'american', 'libertarian', 'published', 'later', 'point', 'theory', 'famous', 'set', 'natural', 'very', 'tucker', 'warren', 'now', 'became', 'activity', 'communist', 'us', 'goldman', 'force', 'leo', 'black', 'associated', 'n', 'members', 'today', 'led', 'themselves', 'rise', 'fascist', 'authority', 'large', 'views', 'particular', 'usually', 'schools', 'org', 'created', 'view', 'criteria', 'play', 'typical', 'repetitive', 'parents', 'year', 'speech', 'little', 'student', 'help', 'students', 'light', 'uae', 'stamps', 'english', 'still', 'violent', 'ruler', 'advocate', 'particularly', 'principles', 'labour', 'europe', 'religious', 'man', 'de', 'opposed', 'rights', 'supported', 'production', 'interest', 'take', 'long', 'few', 'conflict', 'communities', 'liberty', 'difference', 'same', 'tolstoy', 'though', 'significant', 'prior', 'largest', 'uk', 'october', 'control', 'fascism', 'difficult', 'tend', 'focus', 'school', 'day', 'present', 'single', 'f', 'reference', 'small', 'm', 'article', 'global', 'intellec ...

# %%
author_embed = model.input_embedding_layer(torch.tensor([dataset.word2idx["author"]]).to(device))
book_embed = model.input_embedding_layer(torch.tensor([dataset.word2idx["book"]]).to(device))
october_embed = model.input_embedding_layer(torch.tensor([dataset.word2idx["october"]]).to(device))
month_embed = model.input_embedding_layer(torch.tensor([dataset.word2idx["months"]]).to(device))

# %%
print(f"Dot product between author_embed và book_embedd: {torch.matmul(author_embed, book_embed.T)}")
print(f"Dot product between october_embed và book_embedd: {torch.matmul(october_embed, book_embed.T)}")
print(f"Dot product between october_embed và month_embed: {torch.matmul(october_embed, month_embed.T)}")
# Out:
# Dot product between author_embed và book_embedd: tensor([[0.1680]], device='cuda:0', grad_fn=<MmBackward0>)
# Dot product between october_embed và book_embedd: tensor([[0.0932]], device='cuda:0', grad_fn=<MmBackward0>)
# Dot product between october_embed và month_embed: tensor([[0.3649]], device='cuda:0', grad_fn=<MmBackward0>)

# %% [markdown]
# -> Bằng cách kiểm tra các cặp từ ví dụ ở trên, ta thấy từ "book" liên quan đến từ "author" hơn so với từ "october". Từ "october" liên quan đến từ "month" hơn so với từ "book"
