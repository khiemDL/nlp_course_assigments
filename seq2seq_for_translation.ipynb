# %%
# !pip install datasets
# !pip install torch
# !pip install torchtext
# !pip install torch==2.0.1 torchtext==0.15.2
# Out:
# Collecting datasets
#   Downloading datasets-3.5.0-py3-none-any.whl.metadata (19 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from datasets) (3.18.0)
# Requirement already satisfied: numpy>=1.17 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.0.2)
# Requirement already satisfied: pyarrow>=15.0.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (18.1.0)
# Collecting dill<0.3.9,>=0.3.0 (from datasets)
#   Downloading dill-0.3.8-py3-none-any.whl.metadata (10 kB)
# Requirement already satisfied: pandas in /usr/local/lib/python3.11/dist-packages (from datasets) (2.2.2)
# Requirement already satisfied: requests>=2.32.2 in /usr/local/lib/python3.11/dist-packages (from datasets) (2.32.3)
# Requirement already satisfied: tqdm>=4.66.3 in /usr/local/lib/python3.11/dist-packages (from datasets) (4.67.1)
# Collecting xxhash (from datasets)
#   Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (12 kB)
# Collecting multiprocess<0.70.17 (from datasets)
#   Downloading multiprocess-0.70.16-py311-none-any.whl.metadata (7.2 kB)
# Collecting fsspec<=2024.12.0,>=2023.1.0 (from fsspec[http]<=2024.12.0,>=2023.1.0->datasets)
#   Downloading fsspec-2024.12.0-py3-none-any.whl.metadata (11 kB)
# Requirement already satisfied: aiohttp in /usr/local/lib/python3.11/dist-packages (from datasets) (3.11.15)
# Requirement already satisfied: huggingface-hub>=0.24.0 in /usr/local/lib/python3.11/dist-packages (from datasets) (0.30.2)
# Requirement already satisfied: packaging in /usr/local/lib/python3.11/dist-packages (from datasets) (24.2)
# Requirement already satisfied: pyyaml>=5.1 in /usr/local/lib/python3.11/dist-packages (from datasets) (6.0.2)
# Requirement already satisfied: aiohappyeyeballs>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (2.6.1)
# Requirement already satisfied: aiosignal>=1.1.2 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.3.2)
# Requirement already satisfied: attrs>=17.3.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (25.3.0)
# Requirement already satisfied: frozenlist>=1.1.1 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.6.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (6.4.3)
# Requirement already satisfied: propcache>=0.2.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (0.3.1)
# Requirement already satisfied: yarl<2.0,>=1.17.0 in /usr/local/lib/python3.11/dist-packages (from aiohttp->datasets) (1.20.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /usr/local/lib/python3.11/dist-packages (from huggingface-hub>=0.24.0->datasets) (4.13.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests>=2.32.2->datasets) (2025.1.31)
# Requirement already satisfied: python-dateutil>=2.8.2 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in /usr/local/lib/python3.11/dist-packages (from pandas->datasets) (2025.2)
# Requirement already satisfied: six>=1.5 in /usr/local/lib/python3.11/dist-packages (from python-dateutil>=2.8.2->pandas->datasets) (1.17.0)
# Downloading datasets-3.5.0-py3-none-any.whl (491 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 491.2/491.2 kB 9.9 MB/s eta 0:00:00
# Downloading dill-0.3.8-py3-none-any.whl (116 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 116.3/116.3 kB 8.7 MB/s eta 0:00:00
# Downloading fsspec-2024.12.0-py3-none-any.whl (183 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 183.9/183.9 kB 11.1 MB/s eta 0:00:00
# Downloading multiprocess-0.70.16-py311-none-any.whl (143 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 143.5/143.5 kB 9.0 MB/s eta 0:00:00
# Downloading xxhash-3.5.0-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (194 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 194.8/194.8 kB 10.9 MB/s eta 0:00:00
# Installing collected packages: xxhash, fsspec, dill, multiprocess, datasets
#   Attempting uninstall: fsspec
#     Found existing installation: fsspec 2025.3.2
#     Uninstalling fsspec-2025.3.2:
#       Successfully uninstalled fsspec-2025.3.2
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# gcsfs 2025.3.2 requires fsspec==2025.3.2, but you have fsspec 2024.12.0 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cublas-cu12==12.4.5.8; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cublas-cu12 12.5.3.2 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-cupti-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-cupti-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-nvrtc-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-nvrtc-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cuda-runtime-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cuda-runtime-cu12 12.5.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cudnn-cu12==9.1.0.70; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cudnn-cu12 9.3.0.75 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cufft-cu12==11.2.1.3; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cufft-cu12 11.2.3.61 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-curand-cu12==10.3.5.147; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-curand-cu12 10.3.6.82 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusolver-cu12==11.6.1.9; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusolver-cu12 11.6.3.83 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-cusparse-cu12==12.3.1.170; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-cusparse-cu12 12.5.1.3 which is incompatible.
# torch 2.6.0+cu124 requires nvidia-nvjitlink-cu12==12.4.127; platform_system == "Linux" and platform_machine == "x86_64", but you have nvidia-nvjitlink-cu12 12.5.82 which is incompatible.
# Successfully installed datasets-3.5.0 dill-0.3.8 fsspec-2024.12.0 multiprocess-0.70.16 xxhash-3.5.0
# Requirement already satisfied: torch in /usr/local/lib/python3.11/dist-packages (2.6.0+cu124)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch) (2024.12.0)
# Collecting nvidia-cuda-nvrtc-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-cupti-cu12==12.4.127 (from torch)
#   Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu12==9.1.0.70 (from torch)
#   Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu12==12.4.5.8 (from torch)
#   Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cufft-cu12==11.2.1.3 (from torch)
#   Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu12==10.3.5.147 (from torch)
#   Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cusolver-cu12==11.6.1.9 (from torch)
#   Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu12==12.3.1.170 (from torch)
#   Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl.metadata (1.6 kB)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch) (12.4.127)
# Collecting nvidia-nvjitlink-cu12==12.4.127 (from torch)
#   Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch) (1.3.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch) (3.0.2)
# Downloading nvidia_cublas_cu12-12.4.5.8-py3-none-manylinux2014_x86_64.whl (363.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 363.4/363.4 MB 3.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (13.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 13.8/13.8 MB 76.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (24.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 24.6/24.6 MB 62.5 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (883 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 883.7/883.7 kB 45.8 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu12-9.1.0.70-py3-none-manylinux2014_x86_64.whl (664.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 664.8/664.8 MB 1.3 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu12-11.2.1.3-py3-none-manylinux2014_x86_64.whl (211.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 211.5/211.5 MB 6.0 MB/s eta 0:00:00
# Downloading nvidia_curand_cu12-10.3.5.147-py3-none-manylinux2014_x86_64.whl (56.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 56.3/56.3 MB 12.6 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu12-11.6.1.9-py3-none-manylinux2014_x86_64.whl (127.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 127.9/127.9 MB 7.7 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu12-12.3.1.170-py3-none-manylinux2014_x86_64.whl (207.5 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 207.5/207.5 MB 6.2 MB/s eta 0:00:00
# Downloading nvidia_nvjitlink_cu12-12.4.127-py3-none-manylinux2014_x86_64.whl (21.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.1/21.1 MB 83.7 MB/s eta 0:00:00
# Installing collected packages: nvidia-nvjitlink-cu12, nvidia-curand-cu12, nvidia-cufft-cu12, nvidia-cuda-runtime-cu12, nvidia-cuda-nvrtc-cu12, nvidia-cuda-cupti-cu12, nvidia-cublas-cu12, nvidia-cusparse-cu12, nvidia-cudnn-cu12, nvidia-cusolver-cu12
#   Attempting uninstall: nvidia-nvjitlink-cu12
#     Found existing installation: nvidia-nvjitlink-cu12 12.5.82
#     Uninstalling nvidia-nvjitlink-cu12-12.5.82:
#       Successfully uninstalled nvidia-nvjitlink-cu12-12.5.82
#   Attempting uninstall: nvidia-curand-cu12
#     Found existing installation: nvidia-curand-cu12 10.3.6.82
#     Uninstalling nvidia-curand-cu12-10.3.6.82:
#       Successfully uninstalled nvidia-curand-cu12-10.3.6.82
#   Attempting uninstall: nvidia-cufft-cu12
#     Found existing installation: nvidia-cufft-cu12 11.2.3.61
#     Uninstalling nvidia-cufft-cu12-11.2.3.61:
#       Successfully uninstalled nvidia-cufft-cu12-11.2.3.61
#   Attempting uninstall: nvidia-cuda-runtime-cu12
#     Found existing installation: nvidia-cuda-runtime-cu12 12.5.82
#     Uninstalling nvidia-cuda-runtime-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-runtime-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-nvrtc-cu12
#     Found existing installation: nvidia-cuda-nvrtc-cu12 12.5.82
#     Uninstalling nvidia-cuda-nvrtc-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-nvrtc-cu12-12.5.82
#   Attempting uninstall: nvidia-cuda-cupti-cu12
#     Found existing installation: nvidia-cuda-cupti-cu12 12.5.82
#     Uninstalling nvidia-cuda-cupti-cu12-12.5.82:
#       Successfully uninstalled nvidia-cuda-cupti-cu12-12.5.82
#   Attempting uninstall: nvidia-cublas-cu12
#     Found existing installation: nvidia-cublas-cu12 12.5.3.2
#     Uninstalling nvidia-cublas-cu12-12.5.3.2:
#       Successfully uninstalled nvidia-cublas-cu12-12.5.3.2
#   Attempting uninstall: nvidia-cusparse-cu12
#     Found existing installation: nvidia-cusparse-cu12 12.5.1.3
#     Uninstalling nvidia-cusparse-cu12-12.5.1.3:
#       Successfully uninstalled nvidia-cusparse-cu12-12.5.1.3
#   Attempting uninstall: nvidia-cudnn-cu12
#     Found existing installation: nvidia-cudnn-cu12 9.3.0.75
#     Uninstalling nvidia-cudnn-cu12-9.3.0.75:
#       Successfully uninstalled nvidia-cudnn-cu12-9.3.0.75
#   Attempting uninstall: nvidia-cusolver-cu12
#     Found existing installation: nvidia-cusolver-cu12 11.6.3.83
#     Uninstalling nvidia-cusolver-cu12-11.6.3.83:
#       Successfully uninstalled nvidia-cusolver-cu12-11.6.3.83
# Successfully installed nvidia-cublas-cu12-12.4.5.8 nvidia-cuda-cupti-cu12-12.4.127 nvidia-cuda-nvrtc-cu12-12.4.127 nvidia-cuda-runtime-cu12-12.4.127 nvidia-cudnn-cu12-9.1.0.70 nvidia-cufft-cu12-11.2.1.3 nvidia-curand-cu12-10.3.5.147 nvidia-cusolver-cu12-11.6.1.9 nvidia-cusparse-cu12-12.3.1.170 nvidia-nvjitlink-cu12-12.4.127
# Collecting torchtext
#   Downloading torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl.metadata (7.9 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext) (2.32.3)
# Requirement already satisfied: torch>=2.3.0 in /usr/local/lib/python3.11/dist-packages (from torchtext) (2.6.0+cu124)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext) (2.0.2)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (3.18.0)
# Requirement already satisfied: typing-extensions>=4.10.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (4.13.2)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (3.1.6)
# Requirement already satisfied: fsspec in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (2024.12.0)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: nvidia-cuda-runtime-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: nvidia-cuda-cupti-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: nvidia-cudnn-cu12==9.1.0.70 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (9.1.0.70)
# Requirement already satisfied: nvidia-cublas-cu12==12.4.5.8 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.5.8)
# Requirement already satisfied: nvidia-cufft-cu12==11.2.1.3 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (11.2.1.3)
# Requirement already satisfied: nvidia-curand-cu12==10.3.5.147 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (10.3.5.147)
# Requirement already satisfied: nvidia-cusolver-cu12==11.6.1.9 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (11.6.1.9)
# Requirement already satisfied: nvidia-cusparse-cu12==12.3.1.170 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.3.1.170)
# Requirement already satisfied: nvidia-cusparselt-cu12==0.6.2 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (0.6.2)
# Requirement already satisfied: nvidia-nccl-cu12==2.21.5 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (2.21.5)
# Requirement already satisfied: nvidia-nvtx-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: nvidia-nvjitlink-cu12==12.4.127 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (12.4.127)
# Requirement already satisfied: triton==3.2.0 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (3.2.0)
# Requirement already satisfied: sympy==1.13.1 in /usr/local/lib/python3.11/dist-packages (from torch>=2.3.0->torchtext) (1.13.1)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy==1.13.1->torch>=2.3.0->torchtext) (1.3.0)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext) (3.10)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext) (2.3.0)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext) (2025.1.31)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch>=2.3.0->torchtext) (3.0.2)
# Downloading torchtext-0.18.0-cp311-cp311-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 26.9 MB/s eta 0:00:00
# Installing collected packages: torchtext
# Successfully installed torchtext-0.18.0
# Collecting torch==2.0.1
#   Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl.metadata (24 kB)
# Collecting torchtext==0.15.2
#   Downloading torchtext-0.15.2-cp311-cp311-manylinux1_x86_64.whl.metadata (7.4 kB)
# Requirement already satisfied: filelock in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.18.0)
# Requirement already satisfied: typing-extensions in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (4.13.2)
# Requirement already satisfied: sympy in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (1.13.1)
# Requirement already satisfied: networkx in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.4.2)
# Requirement already satisfied: jinja2 in /usr/local/lib/python3.11/dist-packages (from torch==2.0.1) (3.1.6)
# Collecting nvidia-cuda-nvrtc-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-cuda-runtime-cu11==11.7.99 (from torch==2.0.1)
#   Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cuda-cupti-cu11==11.7.101 (from torch==2.0.1)
#   Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cudnn-cu11==8.5.0.96 (from torch==2.0.1)
#   Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cublas-cu11==11.10.3.66 (from torch==2.0.1)
#   Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cufft-cu11==10.9.0.58 (from torch==2.0.1)
#   Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl.metadata (1.5 kB)
# Collecting nvidia-curand-cu11==10.2.10.91 (from torch==2.0.1)
#   Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusolver-cu11==11.4.0.1 (from torch==2.0.1)
#   Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-cusparse-cu11==11.7.4.91 (from torch==2.0.1)
#   Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl.metadata (1.6 kB)
# Collecting nvidia-nccl-cu11==2.14.3 (from torch==2.0.1)
#   Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl.metadata (1.8 kB)
# Collecting nvidia-nvtx-cu11==11.7.91 (from torch==2.0.1)
#   Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl.metadata (1.7 kB)
# Collecting triton==2.0.0 (from torch==2.0.1)
#   Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl.metadata (1.0 kB)
# Requirement already satisfied: tqdm in /usr/local/lib/python3.11/dist-packages (from torchtext==0.15.2) (4.67.1)
# Requirement already satisfied: requests in /usr/local/lib/python3.11/dist-packages (from torchtext==0.15.2) (2.32.3)
# Requirement already satisfied: numpy in /usr/local/lib/python3.11/dist-packages (from torchtext==0.15.2) (2.0.2)
# Collecting torchdata==0.6.1 (from torchtext==0.15.2)
#   Downloading torchdata-0.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl.metadata (13 kB)
# Requirement already satisfied: setuptools in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (75.2.0)
# Requirement already satisfied: wheel in /usr/local/lib/python3.11/dist-packages (from nvidia-cublas-cu11==11.10.3.66->torch==2.0.1) (0.45.1)
# Requirement already satisfied: urllib3>=1.25 in /usr/local/lib/python3.11/dist-packages (from torchdata==0.6.1->torchtext==0.15.2) (2.3.0)
# Requirement already satisfied: cmake in /usr/local/lib/python3.11/dist-packages (from triton==2.0.0->torch==2.0.1) (3.31.6)
# Collecting lit (from triton==2.0.0->torch==2.0.1)
#   Downloading lit-18.1.8-py3-none-any.whl.metadata (2.5 kB)
# Requirement already satisfied: MarkupSafe>=2.0 in /usr/local/lib/python3.11/dist-packages (from jinja2->torch==2.0.1) (3.0.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.15.2) (3.4.1)
# Requirement already satisfied: idna<4,>=2.5 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.15.2) (3.10)
# Requirement already satisfied: certifi>=2017.4.17 in /usr/local/lib/python3.11/dist-packages (from requests->torchtext==0.15.2) (2025.1.31)
# Requirement already satisfied: mpmath<1.4,>=1.1.0 in /usr/local/lib/python3.11/dist-packages (from sympy->torch==2.0.1) (1.3.0)
# Downloading torch-2.0.1-cp311-cp311-manylinux1_x86_64.whl (619.9 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 619.9/619.9 MB 2.1 MB/s eta 0:00:00
# Downloading torchtext-0.15.2-cp311-cp311-manylinux1_x86_64.whl (2.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 2.0/2.0 MB 33.3 MB/s eta 0:00:00
# Downloading nvidia_cublas_cu11-11.10.3.66-py3-none-manylinux1_x86_64.whl (317.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 317.1/317.1 MB 5.9 MB/s eta 0:00:00
# Downloading nvidia_cuda_cupti_cu11-11.7.101-py3-none-manylinux1_x86_64.whl (11.8 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 11.8/11.8 MB 104.3 MB/s eta 0:00:00
# Downloading nvidia_cuda_nvrtc_cu11-11.7.99-2-py3-none-manylinux1_x86_64.whl (21.0 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 21.0/21.0 MB 95.7 MB/s eta 0:00:00
# Downloading nvidia_cuda_runtime_cu11-11.7.99-py3-none-manylinux1_x86_64.whl (849 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 849.3/849.3 kB 55.1 MB/s eta 0:00:00
# Downloading nvidia_cudnn_cu11-8.5.0.96-2-py3-none-manylinux1_x86_64.whl (557.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 557.1/557.1 MB 2.6 MB/s eta 0:00:00
# Downloading nvidia_cufft_cu11-10.9.0.58-py3-none-manylinux2014_x86_64.whl (168.4 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 168.4/168.4 MB 7.1 MB/s eta 0:00:00
# Downloading nvidia_curand_cu11-10.2.10.91-py3-none-manylinux1_x86_64.whl (54.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 54.6/54.6 MB 11.7 MB/s eta 0:00:00
# Downloading nvidia_cusolver_cu11-11.4.0.1-2-py3-none-manylinux1_x86_64.whl (102.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 102.6/102.6 MB 9.0 MB/s eta 0:00:00
# Downloading nvidia_cusparse_cu11-11.7.4.91-py3-none-manylinux1_x86_64.whl (173.2 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 173.2/173.2 MB 6.7 MB/s eta 0:00:00
# Downloading nvidia_nccl_cu11-2.14.3-py3-none-manylinux1_x86_64.whl (177.1 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 177.1/177.1 MB 6.8 MB/s eta 0:00:00
# Downloading nvidia_nvtx_cu11-11.7.91-py3-none-manylinux1_x86_64.whl (98 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 98.6/98.6 kB 9.4 MB/s eta 0:00:00
# Downloading torchdata-0.6.1-cp311-cp311-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (4.6 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 4.6/4.6 MB 81.6 MB/s eta 0:00:00
# Downloading triton-2.0.0-1-cp311-cp311-manylinux2014_x86_64.manylinux_2_17_x86_64.whl (63.3 MB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 63.3/63.3 MB 12.3 MB/s eta 0:00:00
# Downloading lit-18.1.8-py3-none-any.whl (96 kB)
#    ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 96.4/96.4 kB 8.8 MB/s eta 0:00:00
# Installing collected packages: lit, nvidia-nvtx-cu11, nvidia-nccl-cu11, nvidia-cusparse-cu11, nvidia-curand-cu11, nvidia-cufft-cu11, nvidia-cuda-runtime-cu11, nvidia-cuda-nvrtc-cu11, nvidia-cuda-cupti-cu11, nvidia-cublas-cu11, nvidia-cusolver-cu11, nvidia-cudnn-cu11, triton, torch, torchdata, torchtext
#   Attempting uninstall: triton
#     Found existing installation: triton 3.2.0
#     Uninstalling triton-3.2.0:
#       Successfully uninstalled triton-3.2.0
#   Attempting uninstall: torch
#     Found existing installation: torch 2.6.0+cu124
#     Uninstalling torch-2.6.0+cu124:
#       Successfully uninstalled torch-2.6.0+cu124
#   Attempting uninstall: torchtext
#     Found existing installation: torchtext 0.18.0
#     Uninstalling torchtext-0.18.0:
#       Successfully uninstalled torchtext-0.18.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# torchaudio 2.6.0+cu124 requires torch==2.6.0, but you have torch 2.0.1 which is incompatible.
# torchvision 0.21.0+cu124 requires torch==2.6.0, but you have torch 2.0.1 which is incompatible.
# Successfully installed lit-18.1.8 nvidia-cublas-cu11-11.10.3.66 nvidia-cuda-cupti-cu11-11.7.101 nvidia-cuda-nvrtc-cu11-11.7.99 nvidia-cuda-runtime-cu11-11.7.99 nvidia-cudnn-cu11-8.5.0.96 nvidia-cufft-cu11-10.9.0.58 nvidia-curand-cu11-10.2.10.91 nvidia-cusolver-cu11-11.4.0.1 nvidia-cusparse-cu11-11.7.4.91 nvidia-nccl-cu11-2.14.3 nvidia-nvtx-cu11-11.7.91 torch-2.0.1 torchdata-0.6.1 torchtext-0.15.2 triton-2.0.0

# %% [markdown]
# # Prepare dataset

# %%
import numpy as np
import random, spacy, datasets

import torch
from torch import nn
import torchtext

# %% [markdown]
# ### Dataset
#
# Next, we'll load our dataset using the `datasets` library. When using the `load_dataset` function we pass the name of the dataset, `bentrevett/multi30k`.
#
# The dataset we'll be using is a subset of the [Multi30k dataset](https://github.com/multi30k/dataset), which is hosted [here](https://huggingface.co/datasets/bentrevett/multi30k) on the HuggingFace dataset hub. This subset has ~30,000 parallel English and German sentences obtained using the task 1 raw data from [here](https://github.com/multi30k/dataset/tree/master/data/task1/raw). We use the "2016" versions of the test sets.

# %%
dataset = datasets.load_dataset("bentrevett/multi30k")
# Out:
# /usr/local/lib/python3.11/dist-packages/huggingface_hub/utils/_auth.py:94: UserWarning:
# The secret `HF_TOKEN` does not exist in your Colab secrets.
# To authenticate with the Hugging Face Hub, create a token in your settings tab (https://huggingface.co/settings/tokens), set it as secret in your Google Colab and restart your session.
# You will be able to reuse this secret in all of your notebooks.
# Please note that authentication is recommended but still optional to access public models or datasets.
#   warnings.warn(
# README.md:   0%|          | 0.00/1.15k [00:00<?, ?B/s]
# train.jsonl:   0%|          | 0.00/4.60M [00:00<?, ?B/s]
# val.jsonl:   0%|          | 0.00/164k [00:00<?, ?B/s]
# test.jsonl:   0%|          | 0.00/156k [00:00<?, ?B/s]
# Generating train split:   0%|          | 0/29000 [00:00<?, ? examples/s]
# Generating validation split:   0%|          | 0/1014 [00:00<?, ? examples/s]
# Generating test split:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %% [markdown]
# We can see the `dataset` object (a `DatasetDict`) contains the train, validation and test splits, the amount of examples in each split, and the features in each split ("en" and "de").

# %%
dataset
# Out:
# DatasetDict({
#     train: Dataset({
#         features: ['en', 'de'],
#         num_rows: 29000
#     })
#     validation: Dataset({
#         features: ['en', 'de'],
#         num_rows: 1014
#     })
#     test: Dataset({
#         features: ['en', 'de'],
#         num_rows: 1000
#     })
# })

# %% [markdown]
# For convenience, we create a variable for each split. Each being a `Dataset` object.

# %%
train_data, valid_data, test_data = (
    dataset["train"],
    dataset["validation"],
    dataset["test"],
)

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %% [markdown]
# We can index into each `Dataset` to view an individual example. Each example has two features: "en" and "de", which are the parallel English and German sentences.

# %%
train_data[0]
# Out:
# {'en': 'Two young, White males are outside near many bushes.',
#  'de': 'Zwei junge weiße Männer sind im Freien in der Nähe vieler Büsche.'}

# %% [markdown]
# ### Tokenizers
#
# Next, we'll load the spaCy models that contain the tokenizers.
#
# A tokenizer is used to turn a string into a list of tokens that make up that string, e.g. "good morning!" becomes ["good", "morning", "!"]. We'll start talking about the sentences being a sequence of tokens from now, instead of saying they're a sequence of words. What's the difference? Well, "good" and "morning" are both words and tokens, but "!" is not a word. We could say "!" is punctuation, but the term token is more general and covers: words, punctuation, numbers and any special symbols.
#
# spaCy has model for each language ("de_core_news_sm" for German and "en_core_web_sm" for English) which need to be loaded so we can access the tokenizer of each model.
#
#
# We load the models as such:

# %%
# !python -m spacy download en_core_web_sm
# !python -m spacy download de_core_news_sm
# Out:
# Collecting en-core-web-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/en_core_web_sm-3.8.0/en_core_web_sm-3.8.0-py3-none-any.whl (12.8 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 12.8/12.8 MB 115.4 MB/s eta 0:00:00
# ✔ Download and installation successful
# You can now load the package via spacy.load('en_core_web_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.
# Collecting de-core-news-sm==3.8.0
#   Downloading https://github.com/explosion/spacy-models/releases/download/de_core_news_sm-3.8.0/de_core_news_sm-3.8.0-py3-none-any.whl (14.6 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 14.6/14.6 MB 105.5 MB/s eta 0:00:00
# Installing collected packages: de-core-news-sm
# Successfully installed de-core-news-sm-3.8.0
# ✔ Download and installation successful
# You can now load the package via spacy.load('de_core_news_sm')
# ⚠ Restart to reload dependencies
# If you are in a Jupyter or Colab notebook, you may need to restart Python in
# order to load all the package's dependencies. You can do this by selecting the
# 'Restart kernel' or 'Restart runtime' option.

# %%
en_nlp = spacy.load("en_core_web_sm")
de_nlp = spacy.load("de_core_news_sm")

# %%
[tokenizer.text for tokenizer in en_nlp.tokenizer(train_data[0]['de'])]
# Out:
# ['Zwei',
#  'junge',
#  'weiße',
#  'Männer',
#  'sind',
#  'i',
#  'm',
#  'Freien',
#  'in',
#  'der',
#  'Nähe',
#  'vieler',
#  'Büsche',
#  '.']

# %%
[tokenizer.text for tokenizer in de_nlp.tokenizer(train_data[0]['de'])]
# Out:
# ['Zwei',
#  'junge',
#  'weiße',
#  'Männer',
#  'sind',
#  'im',
#  'Freien',
#  'in',
#  'der',
#  'Nähe',
#  'vieler',
#  'Büsche',
#  '.']

# %% [markdown]
# We can call the tokenizer for each spaCy model using the `.tokenizer` method, which accepts a string and returns a sequence of `Token` objects. We can get the string from the token object using the `text` attribute.

# %%
string = "What a lovely day it is today!"

[token.text for token in en_nlp.tokenizer(string)]
# Out:
# ['What', 'a', 'lovely', 'day', 'it', 'is', 'today', '!']

# %% [markdown]
# Next, we'll write a function used to apply the tokenizer to all of the examples in each data split, as well as apply some other processing.
#
# This function takes in an example from the `Dataset` object, applies the tokenizers English and German spaCy models, trims the list of tokens to a maximum length, optionally converts each token to lowercase, and then appends the start of sequence and end of sequence tokens to the beginning and end of the list of tokens.
#
# This function will be used with the `map` method from a `Dataset`, which needs to return a dictionary containing the names of the features in each example where the outputs are stored. As the output feature names "en_tokens" and "de_tokens" are not already contained in the example (where we only have "en" and "de" features), this will create two new features in each example.

# %%
def tokenize_example(example, en_nlp, de_nlp, max_length, lower, sos_token, eos_token):
    en_tokens = [token.text for token in en_nlp.tokenizer(example["en"])][:max_length]
    de_tokens = [token.text for token in de_nlp.tokenizer(example["de"])][:max_length]
    if lower:
        en_tokens = [token.lower() for token in en_tokens]
        de_tokens = [token.lower() for token in de_tokens]
    en_tokens = [sos_token] + en_tokens + [eos_token]
    de_tokens = [sos_token] + de_tokens + [eos_token]
    return {"en_tokens": en_tokens, "de_tokens": de_tokens}

# %% [markdown]
# We apply the `tokenize_example` function using the `map` method as below.
#
# The `example` argument is implied, however all additional arguments to the `tokenize_example` function need to be stored in a dictionary and passed to the `fn_kwargs` argument of `map`.
#
# Here, we're trimming all sequences to a maximum length of 1000 tokens, converting each token to lower case, and using `<sos>` and `<eos>` as the start and end of sequence tokens, respectively.

# %%
# max_length = 1_000
# lower = True
# sos_token = "<sos>"
# eos_token = "<eos>"

# fn_kwargs = {
#     "en_nlp": en_nlp,
#     "de_nlp": de_nlp,
#     "max_length": max_length,
#     "lower": lower,
#     "sos_token": sos_token,
#     "eos_token": eos_token,
# }

# train_data = train_data.map(tokenize_example, fn_kwargs=fn_kwargs)
# valid_data = valid_data.map(tokenize_example, fn_kwargs=fn_kwargs)
# test_data = test_data.map(tokenize_example, fn_kwargs=fn_kwargs)

# %% [markdown]
# We can now look at an example, confirming the two new features have been added; both of which are lowercased list of strings with the start/end of sequence tokens appended.

# %%
train_data[0]
# Out:
# {'en': 'Two young, White males are outside near many bushes.',
#  'de': 'Zwei junge weiße Männer sind im Freien in der Nähe vieler Büsche.'}

# %% [markdown]
# ### Vocabularies
#
# Next, we'll build the _vocabulary_ for the source and target languages. The vocabulary is used to associate each unique token in our dataset with an index (an integer), e.g. "hello" = 1, "world" = 2, "bye" = 3, "hates" = 4, etc. When feeding text data to our model, we convert the string into tokens and then the tokens into numbers using the vocabulary as a look up table, e.g. "hello world" becomes `["hello", "world"]` which becomes `[1, 2]` using the example indices given. We do this as neural networks cannot operate on strings, only numerical values.
#
# We create the vocabulary (one for each language) from our datasets using the `build_vocab_from_iterator` function, provided by `torchtext`, which accepts an iterator where each item is a list of tokens. It then counts up the number of unique tokens and assigns each a numerical value.
#
# In theory, our vocabulary can be large enough to have an index for every unique token in our dataset. However, what happens if a token exists in our validation and test set, but not in our training set? In that case, we replace the token with an "unknown token", denoted by `<unk>`, which is given its own index (usually index zero). All unknown tokens are replaced by `<unk>`, even if the tokens are different, i.e. if the tokens "gilgamesh" and "enkidu" were both not within our vocabulary, then the string "gilgamesh hates enkidu" gets tokenized to `["gilgamesh", "hates", "enkidu"]` and then becomes `[0, 24, 0]` (where "hates" has the index 24).
#
# Ideally, we want our model to be able to handle unknown tokens by learning to use the context around them to make translations. The only way it can learn that is if we also have unknown tokens in the training set. Hence, when creating our vocabularies with `build_vocab_from_iterator`, we use the `min_freq` argument to not create an index for tokens which appear less than `min_freq` times in our training set. In other words, when using the vocabulary, any token which does not appear at least twice in our training set will get replaced by the unknown token index when converting tokens to indices.
#
# It is important to note that a vocabulary should only be built from the training set and never the validation or test set. This prevents "information leakage" into our model, giving us artifically inflated validation/test scores.
#
# We also use the `specials` argument of `build_vocab_from_iterator` to pass _special tokens_. These are tokens which we want to add to the vocabulary but do not necessarily appear in our tokenized examples. These special tokens will appear first in the vocabulary. We've already discussed the `unk_token`, `sos_token`, and `eos_token`. The final special token is the `pad_token`, denoted by `<pad>`.
#
# When inputting sentences into our model, it is more efficient to pass multiple sentences at once (known as a batch), instead of one at a time. The requirement for sentences to be batched together is that they all have to be the same length (in terms of the number of tokens). The majority of our sentences are not the same length, but we can solve this by "padding" (adding `<pad>` tokens) the tokenized version of each sentence in a batch until they all have equal tokens to the longest sentence in the batch. For example, if we had two sentences: "I love pizza" and "I hate music videos". They would be tokenized to something like: `["i", "love", "pizza"]` and `["i", "hate", "music", "videos"]`. The first sequence of tokens would then be padded to `["i", "love", "pizza", "<pad>"]`. Both sequences could then be converted to indexes using the vocabulary.
#
# That was a lot of information, but luckily `torchtext` handles all the fuss of building the vocabulary. We'll handle the padding and batching later.

# %%
# min_freq = 2
# unk_token = "<unk>"
# pad_token = "<pad>"
# sos_token = "<sos>"
# eos_token = "<eos>"

# special_tokens = [
#     unk_token,
#     pad_token,
#     sos_token,
#     eos_token,
# ]

# en_vocab = torchtext.vocab.build_vocab_from_iterator(
#     train_data["en_tokens"],
#     min_freq=min_freq,
#     specials=special_tokens,
# )

# de_vocab = torchtext.vocab.build_vocab_from_iterator(
#     train_data["de_tokens"],
#     min_freq=min_freq,
#     specials=special_tokens,
# )

# %% [markdown]
# Now we have our vocabularies, we can check what's actually in them.
#
# We can get the first ten tokens in our vocabulary (indices 0 to 9) using the `get_itos` method, where itos = "**i**nt **to** **s**tring", which returns a list of tokens.

# %%
en_vocab.get_itos()[:10]
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-f52cd1162c85> in <cell line: 0>()
# ----> 1 en_vocab.get_itos()[:10]
#
# NameError: name 'en_vocab' is not defined

# %%
en_vocab.get_itos()[9]

# %% [markdown]
# We can do the same for the German vocabulary. Notice how the special tokens are the same and in the same order (indices 0 to 3), however the rest are different. This is because the vocabularies were effectively created from different data (one English and one German) even though they were from the same examples. The indices given to tokens that are not special tokens are ordered from most frequent to least frequent (though still appearing at least `min_freq` times).

# %%
de_vocab.get_itos()[:10]

# %% [markdown]
# We can get the index from a given token using the `get_stoi` (stoi = " **s**tring **to** **i**nt) method.

# %%
en_vocab.get_stoi()["the"]

# %% [markdown]
# As a shorthand, we can just use the vocabulary as a dictionary and pass the token to get the index. Note that this doesn't work the other way around, i.e. `en_vocab[7]` does not work.

# %%
en_vocab["the"]

# %% [markdown]
# The `len` of each vocabulary gives us the number of unique tokens in each one. We can see that our training data had around 2000 more German tokens (that appeared at least twice) than the English data.

# %%
len(en_vocab), len(de_vocab)

# %% [markdown]
# We can also use the `in` keyword to get a boolean indicating if a token is in the vocabulary.

# %%
"the" in en_vocab

# %% [markdown]
# Remember how we converted all of our tokens to lowercase? This means that no tokens containing any uppercase characters appear in our vocabulary.

# %%
"The" in en_vocab

# %% [markdown]
# What happens if you try and get the index of a token that isn't in the vocabulary? You get index zero for the `<unk>` (unknown) token, right?
#
# Well, no. One quirk of the `torchtext` vocabulary class is that you have to manually set what value you want your vocabulary to return when you try and get the index of an out-of-vocabulary token. If you have not set this value, then you will receive an error! This is so you can set your vocabulary to return any value when trying to get the index of a token not in the vocabulary, even something like `-100`.

# %% [markdown]
# We already know the index of our `<unk>` token is zero as it's the first element in our `special_tokens` list, and we've also manually inspected it using `get_itos`.
#
# However, here we'll programmatically get it and also check that both our vocabularies have the same index for the unknown and padding tokens as this simplifies some code later on.
#
# We also get the index of our `<pad>` token, as we'll use it later

# %%
unk_index = en_vocab[unk_token]
pad_index = en_vocab[pad_token]

# %%
unk_index = de_vocab[unk_token]
print(unk_index)

# %% [markdown]
# Using the `set_default_index` method we can set what value is returned when we try and get the index of a token outside of our vocabulary. In this case, the index of the unknown token, `<unk>`.

# %%
en_vocab.set_default_index(unk_index)
de_vocab.set_default_index(unk_index)

# %% [markdown]
# Now, we can happily get indexes of out of vocabulary tokens until our heart is content!

# %%
en_vocab["The"]

# %% [markdown]
# And we can get the token corresponding to that index to prove it's the `<unk>` token.

# %%
en_vocab.get_itos()[0]

# %% [markdown]
# Another useful feature of the vocabulary is the `lookup_indices` method. This takes in a list of tokens and returns a list of indices. In the below example we can see the token "crime" does not exist in our vocabulary so is coverted to the index of the `<unk>` token, zero, which we passed to the `set_default_index` method.

# %%
tokens = ["i", "love", "watching", "crime", "shows"]

# %%
en_vocab.lookup_indices(tokens)

# %% [markdown]
# Conversely, we can use the `lookup_tokens` method to convert a list of indices back into tokens using the vocabulary. Notice how the original "crime" token is now an `<unk>` token. There is no way to tell what the original sequence of tokens was.

# %%
en_vocab.lookup_tokens(en_vocab.lookup_indices(tokens))

# %% [markdown]
# Hopefully we've now got the gist of how the `torchtext.Vocab` class works. Time to put it into action!
#
# Just like our `tokenize_example`, we create a `numericalize_example` function which we'll use with the `map` method of our dataset. This will "numericalize" (a fancy way of saying convert tokens to indices) our tokens in each example using the vocabularies and return the result into new "en_ids" and "de_ids" features.

# %%
def numericalize_example(example, en_vocab, de_vocab):
    en_ids = en_vocab.lookup_indices(example["en_tokens"])
    de_ids = de_vocab.lookup_indices(example["de_tokens"])
    return {"en_ids": en_ids, "de_ids": de_ids}

# %% [markdown]
# We apply the `numericalize_example` function, passing our vocabularies in the `fn_kwargs` dictionary to the `fn_kwargs` argument.

# %%
# fn_kwargs = {"en_vocab": en_vocab, "de_vocab": de_vocab}
# #
# train_data = train_data.map(numericalize_example, fn_kwargs=fn_kwargs)
# valid_data = valid_data.map(numericalize_example, fn_kwargs=fn_kwargs)
# test_data = test_data.map(numericalize_example, fn_kwargs=fn_kwargs)

# %% [markdown]
# Checking an example, we can see that it has the two new features: "en_ids" and "de_ids", both a list of integers representing their indices in the respective vocabulary.

# %%
train_data[0]

# %% [markdown]
# We can confirm the indices are correct by using the `lookup_tokens` method with the corresponding vocabulary on the list of indices.

# %%
en_vocab.lookup_tokens(train_data[0]["en_ids"])

# %% [markdown]
# One other thing that the `datasets` library handles for us with the `Dataset` class is converting features to the correct type. Our indices in each example are currently basic Python integers. However, they need to be converted to PyTorch tensors in order to use them with PyTorch. We could convert them just before we pass them into the model, however it is more convenient to do it now.
#
# The `with_format` method converts features indicated by the `columns` argument to a given `type`. Here, we specify the type as "torch" (for PyTorch) and the columns to be "en_ids" and "de_ids" (the features which we want to convert to PyTorch tensors). By default, `with_format` will remove any features not in the list of features passed to `columns`. We want to keep those features, which we can do with `output_all_columns=True`.

# %%
data_type = "torch"
format_columns = ["en_ids", "de_ids"]

train_data = train_data.with_format(
    type=data_type, columns=format_columns, output_all_columns=True
)

valid_data = valid_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)

test_data = test_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-8-63b148e7aaa9> in <cell line: 0>()
#       2 format_columns = ["en_ids", "de_ids"]
#       3
# ----> 4 train_data = train_data.with_format(
#       5     type=data_type, columns=format_columns, output_all_columns=True
#       6 )
#
# NameError: name 'train_data' is not defined

# %% [markdown]
# We can confirm this worked by checking an example and seeing the "en_ids" and "de_ids" features are listed as `tensor([...])`.

# %%
train_data[0]

# %% [markdown]
# We can also check this using the `type` built-in function on one of the features.

# %% [markdown]
# ## Vocabulary

# %% [markdown]
# ## Preprocessing function

# %%
train_data, valid_data, test_data = (
    dataset["train"],
    dataset["validation"],
    dataset["test"],
)

# %%
import string

max_length = 30
lower = True
sos_token = "<sos>"
eos_token = "<eos>"
pad_token = "<pad>"
unk_token = "<unk>"
min_freq = 5

en_nlp = spacy.load("en_core_web_sm")
de_nlp = spacy.load("de_core_news_sm")

fn_kwargs = {
    "en_nlp": en_nlp,
    "de_nlp": de_nlp,
    "max_length": max_length,
    "lower": lower,
    "sos_token": sos_token,
    "eos_token": eos_token,
    "pad_token": pad_token
}



def tokenizer(data, en_nlp, de_nlp, max_length=50, lower=True, sos_token="<sos>", eos_token="<eos>", pad_token="<pad>"):

  en_tokens = [token.text for token in en_nlp.tokenizer(data['en'])][:max_length]
  de_tokens = [token.text for token in de_nlp.tokenizer(data['de'])][:max_length]

  # Xóa dấu câu
  en_tokens = [token for token in en_tokens if token not in string.punctuation]
  de_tokens = [token for token in de_tokens if token not in string.punctuation]

  if lower:
    en_tokens = [token.lower() for token in en_tokens]
    de_tokens = [token.lower() for token in de_tokens]

  en_tokens = [sos_token] + en_tokens + [eos_token]
  de_tokens = [sos_token] + de_tokens + [eos_token]


  return {"en_tokens": en_tokens, "de_tokens": de_tokens}

# %%
train_data = train_data.map(tokenizer, fn_kwargs=fn_kwargs)
valid_data = valid_data.map(tokenizer, fn_kwargs=fn_kwargs)
test_data = test_data.map(tokenizer, fn_kwargs=fn_kwargs)
# Out:
# Map:   0%|          | 0/29000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1014 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
special_tokens = [
    unk_token,
    pad_token,
    sos_token,
    eos_token,
]

en_vocab = torchtext.vocab.build_vocab_from_iterator(
    train_data["en_tokens"],
    min_freq=min_freq,
    specials=special_tokens
)
en_vocab.set_default_index(en_vocab.get_stoi()[unk_token])

de_vocab = torchtext.vocab.build_vocab_from_iterator(
    train_data["de_tokens"],
    min_freq=min_freq,
    specials=special_tokens)
de_vocab.set_default_index(de_vocab.get_stoi()[unk_token])

# %%
def numericalizer(data, en_vocab, de_vocab):
    en_ids = en_vocab.lookup_indices(data["en_tokens"])
    de_ids = de_vocab.lookup_indices(data["de_tokens"])
    return {"en_ids": en_ids, "de_ids": de_ids}

# %%
fn_kwargs = {"en_vocab": en_vocab, "de_vocab": de_vocab}

train_data = train_data.map(numericalizer, fn_kwargs=fn_kwargs)
valid_data = valid_data.map(numericalizer, fn_kwargs=fn_kwargs)
test_data = test_data.map(numericalizer, fn_kwargs=fn_kwargs)
# Out:
# Map:   0%|          | 0/29000 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1014 [00:00<?, ? examples/s]
# Map:   0%|          | 0/1000 [00:00<?, ? examples/s]

# %%
data_type = "torch"
format_columns = ["en_ids", "de_ids"]

train_data = train_data.with_format(
    type=data_type, columns=format_columns, output_all_columns=True
)

valid_data = valid_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)

test_data = test_data.with_format(
    type=data_type,
    columns=format_columns,
    output_all_columns=True,
)

# %% [markdown]
# # Seq2seq model
# The seq2seq model normally has an encoder-decoder architecture, composed of:
#
# - An encoder processes the input sequence and compresses the information into a context vector (also known as sentence embedding or “thought” vector) of a fixed length. This representation is expected to be a good summary of the meaning of the whole source sequence.
# - A decoder is initialized with the context vector to emit the transformed output. The early work only used the last state of the encoder network as the decoder initial state.
# - Both the encoder and decoder are recurrent neural networks, i.e. using LSTM or GRU units.
#
#
# ![](https://lilianweng.github.io/posts/2018-06-24-attention/encoder-decoder-example.png)
#
# - 2 limitations of seq2seq models:
#     - Information loss due to fixed-size feature embeddings
#     - Vanishing gradients
#
# ![](https://raw.githubusercontent.com/bentrevett/pytorch-seq2seq/b3cd54c72cd6e4e63f672d334c795b4fe744ef92//assets/seq2seq1.png)

# %% [markdown]
# ## Model build-up
#
# We'll be building our model in three parts:
# 1. The encoder
# 2. The decoder
# 3. A seq2seq model that encapsulates the encoder and decoder and will provide a way to interface with each.
#
#
# For a multi-layer RNN, the input sentence, $X$, after being embedded goes into the first (bottom) layer of the RNN and hidden states, $H=\{h_1, h_2, ..., h_T\}$, output by this layer are used as inputs to the RNN in the layer above. Thus, representing each layer with a superscript, the hidden states in the first layer are given by:
#
# $$h_t^1 = \text{EncoderRNN}^1(e(x_t), h_{t-1}^1)$$
#
# The hidden states in the second layer are given by:
#
# $$h_t^2 = \text{EncoderRNN}^2(h_t^1, h_{t-1}^2)$$
#
# Using a multi-layer RNN also means we'll also need an initial hidden state as input per layer, $h_0^l$, and we will also output a context vector per layer, $z^l$.
#
# LSTM is a type of RNN which instead of just taking in a hidden state and returning a new hidden state per time-step, also take in and return a _cell state_, $c_t$, per time-step.
#
# $$
# \begin{align*}
# h_t &= \text{RNN}(e(x_t), h_{t-1})\\
# (h_t, c_t) &= \text{LSTM}(e(x_t), h_{t-1}, c_{t-1})
# \end{align*}
# $$
#
# We can just think of $c_t$ as another type of hidden state. Similar to $h_0^l$, $c_0^l$ will be initialized to a tensor of all zeros. Also, our context vector will now be both the final hidden state and the final cell state, i.e. $z^l = (h_T^l, c_T^l)$.
#
# Extending our multi-layer equations to LSTMs, we get:
#
# $$
# \begin{align*}
# (h_t^1, c_t^1) &= \text{EncoderLSTM}^1(e(x_t), (h_{t-1}^1, c_{t-1}^1))\\
# (h_t^2, c_t^2) &= \text{EncoderLSTM}^2(h_t^1, (h_{t-1}^2, c_{t-1}^2))
# \end{align*}
# $$
#
# Note how only our hidden state from the first layer is passed as input to the second layer, and not the cell state.

# %% [markdown]
# ## Encoder

# %%
class Encoder(nn.Module):
    def __init__(self,
                 input_dim,
                 embedding_dim,
                 hidden_dim,
                 n_layers,
                 dropout):
        """
        The encoder takes the following arguments:

        input_dim (int) -- the size/dimensionality of the one-hot vectors that will be input to the encoder.
        embedding_dim (int) -- the dimensionality of the embedding layer, converts the one-hot vectors into dense vectors with `embedding_dim` dimensions.
        hidden_dim (int) -- the dimensionality of the hidden and cell states.
        n_layers (int) -- the number of layers in the RNN.
        dropout (int) -- regularization parameter to prevent overfitting.
        """
        super().__init__()
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers
        self.embedding = nn.Embedding(input_dim, embedding_dim)
        self.lstm = nn.LSTM(embedding_dim,
                           hidden_dim,
                           n_layers,
                           dropout=dropout)
        self.dropout = nn.Dropout(dropout) # Dropout là một kỹ thuật được implement bằng class Dropout. Set một phần về 0 để tránh drop out

    def forward(self, input, src_lengths):
        # input = [input length, batch size]
        embedding = self.dropout(self.embedding(input)) # Khi qua embedding layer, mỗi từ được embed bằng vector có kích thước [1, embedding_dim] -> Xuất hiện thêm chiều từ 3
        # embedding = [input length, batch size, embedding dim]

        packed_embedded = nn.utils.rnn.pack_padded_sequence(embedding, lengths=src_lengths.cpu(), enforce_sorted=False)
        packed_outputs, (hidden, cell) = self.lstm(packed_embedded)
        # outputs = [input length, batch size, hidden dim * n directions] # n_directions đại diện cho mô hình có phải bidirection không
        # hidden = [n layers * n directions, batch size, hidden dim]
        # cell = [n layers * n directions, batch size, hidden dim]
        # outputs are always from the top hidden layer
        return hidden, cell

# %% [markdown]
# ## Decoder
#
# ### Decoder
#
# Next, we'll build our decoder, which will also be a 2-layer.
#
# The `Decoder` class does a single step of decoding, i.e., it ouputs single token per time-step. The first layer will receive a hidden and cell state from the previous time-step, $(s_{t-1}^1, c_{t-1}^1)$, and feeds it through the LSTM with the current embedded token, $y_t$, to produce a new hidden and cell state, $(s_t^1, c_t^1)$. The subsequent layers will use the hidden state from the layer below, $s_t^{l-1}$, and the previous hidden and cell states from their layer, $(s_{t-1}^l, c_{t-1}^l)$. This provides equations very similar to those in the encoder.
#
# $$
# \begin{align*}
# (s_t^1, c_t^1) = \text{DecoderLSTM}^1(d(y_t), (s_{t-1}^1, c_{t-1}^1))\\
# (s_t^2, c_t^2) = \text{DecoderLSTM}^2(s_t^1, (s_{t-1}^2, c_{t-1}^2))
# \end{align*}
# $$
#
# Remember that the initial hidden and cell states to our decoder are our context vectors, which are the final hidden and cell states of our encoder from the same layer, i.e. $(s_0^l,c_0^l)=z^l=(h_T^l,c_T^l)$.
#
# We then pass the hidden state from the top layer of the RNN, $s_t^L$, through a linear layer, $f$, to make a prediction of what the next token in the target (output) sequence should be, $\hat{y}_{t+1}$.
#
# $$\hat{y}_{t+1} = f(s_t^L)$$
#
# The arguments and initialization are similar to the `Encoder` class, except we now have an `output_dim` which is the size of the vocabulary for the output/target language. There is also the addition of the `Linear` layer, used to make the predictions from the top layer hidden state.

# %%
class Decoder(nn.Module):
    def __init__(self, output_dim, embedding_dim, hidden_dim, n_layers, dropout):
        super().__init__()
        self.output_dim = output_dim
        self.hidden_dim = hidden_dim
        self.n_layers = n_layers
        self.embedding = nn.Embedding(output_dim, embedding_dim)
        self.rnn = nn.LSTM(embedding_dim, hidden_dim, n_layers, dropout=dropout)
        self.fc_out = nn.Linear(hidden_dim, output_dim)
        self.dropout = nn.Dropout(dropout)

    def forward(self, input, hidden, cell):
        # input = [batch size]
        # hidden = [n layers * n directions, batch size, hidden dim]
        # cell = [n layers * n directions, batch size, hidden dim]
        # n directions in the decoder will both always be 1, therefore:
        # hidden = [n layers, batch size, hidden dim]
        # context = [n layers, batch size, hidden dim]
        input = input.unsqueeze(0)
        # input = [1, batch size]
        embedded = self.dropout(self.embedding(input))
        # embedded = [1, batch size, embedding dim]
        output, (hidden, cell) = self.rnn(embedded, (hidden, cell))
        # output = [seq length, batch size, hidden dim * n directions]
        # hidden = [n layers * n directions, batch size, hidden dim]
        # cell = [n layers * n directions, batch size, hidden dim]
        # seq length and n directions will always be 1 in this decoder, therefore:
        # output = [1, batch size, hidden dim]
        # hidden = [n layers, batch size, hidden dim]
        # cell = [n layers, batch size, hidden dim]
        prediction = self.fc_out(output.squeeze(0))
        # prediction = [batch size, output dim]
        return prediction, hidden, cell

# %%
example_decoder = Decoder(output_dim=len(en_vocab), embedding_dim=100, hidden_dim=100, n_layers=2, dropout=0.5)
prediction, hidden, cell = example_decoder.forward(train_data[0]['en_ids'][1].unsqueeze(0), hidden=hidden, cell=cell)
# Out:
# A module that was compiled using NumPy 1.x cannot be run in
# NumPy 2.0.2 as it may crash. To support both 1.x and 2.x
# versions of NumPy, modules must be compiled with NumPy 2.0.
# Some module may need to rebuild instead e.g. with 'pybind11>=2.12'.
#
# If you are a user of the module, the easiest solution will be to
# downgrade to 'numpy<2' or try to upgrade the affected module.
# We expect that some modules will need time to support NumPy 2.
#
# Traceback (most recent call last):  File "<frozen runpy>", line 198, in _run_module_as_main
#   File "<frozen runpy>", line 88, in _run_code
#   File "/usr/local/lib/python3.11/dist-packages/colab_kernel_launcher.py", line 37, in <module>
#     ColabKernelApp.launch_instance()
#   File "/usr/local/lib/python3.11/dist-packages/traitlets/config/application.py", line 992, in launch_instance
#     app.start()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelapp.py", line 712, in start
#     self.io_loop.start()
#   File "/usr/local/lib/python3.11/dist-packages/tornado/platform/asyncio.py", line 205, in start
#     self.asyncio_loop.run_forever()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 608, in run_forever
#     self._run_once()
#   File "/usr/lib/python3.11/asyncio/base_events.py", line 1936, in _run_once
#     handle._run()
#   File "/usr/lib/python3.11/asyncio/events.py", line 84, in _run
#     self._context.run(self._callback, *self._args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 510, in dispatch_queue
#     await self.process_one()
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 499, in process_one
#     await dispatch(*args)
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 406, in dispatch_shell
#     await result
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/kernelbase.py", line 730, in execute_request
#     reply_content = await reply_content
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/ipkernel.py", line 383, in do_execute
#     res = shell.run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/ipykernel/zmqshell.py", line 528, in run_cell
#     return super().run_cell(*args, **kwargs)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 2975, in run_cell
#     result = self._run_cell(
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3030, in _run_cell
#     return runner(coro)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/async_helpers.py", line 78, in _pseudo_sync_runner
#     coro.send(None)
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3257, in run_cell_async
#     has_raised = await self.run_ast_nodes(code_ast.body, cell_name,
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3473, in run_ast_nodes
#     if (await self.run_code(code, result,  async_=asy)):
#   File "/usr/local/lib/python3.11/dist-packages/IPython/core/interactiveshell.py", line 3553, in run_code
#     exec(code_obj, self.user_global_ns, self.user_ns)
#   File "<ipython-input-19-342f3792f397>", line 1, in <cell line: 0>
#     example_decoder = Decoder(output_dim=len(en_vocab), embedding_dim=100, hidden_dim=100, n_layers=2, dropout=0.5)
#   File "<ipython-input-18-8fd05da34772>", line 7, in __init__
#     self.embedding = nn.Embedding(output_dim, embedding_dim)
#   File "/usr/local/lib/python3.11/dist-packages/torch/nn/modules/sparse.py", line 142, in __init__
#     self.weight = Parameter(torch.empty((num_embeddings, embedding_dim), **factory_kwargs),
# /usr/local/lib/python3.11/dist-packages/torch/nn/modules/sparse.py:142: UserWarning: Failed to initialize NumPy: _ARRAY_API not found (Triggered internally at ../torch/csrc/utils/tensor_numpy.cpp:84.)
#   self.weight = Parameter(torch.empty((num_embeddings, embedding_dim), **factory_kwargs),
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-19-342f3792f397> in <cell line: 0>()
#       1 example_decoder = Decoder(output_dim=len(en_vocab), embedding_dim=100, hidden_dim=100, n_layers=2, dropout=0.5)
# ----> 2 prediction, hidden, cell = example_decoder.forward(train_data[0]['en_ids'][1].unsqueeze(0), hidden=hidden, cell=cell)
#
# NameError: name 'hidden' is not defined

# %% [markdown]
# ## Seq2seq model
# ### Seq2Seq
#
# For the final part of the implemenetation, we'll implement the Seq2Seq model. This will handle:
#
# -   Receiving the input/source sentence
# -   Using the encoder to produce the context vectors
# -   Using the decoder to produce the predicted output/target sentence
#
# The `Seq2Seq` model takes in an `Encoder`, `Decoder`\.
#
# For this implementation, we have to ensure that the number of layers and the hidden (and cell) dimensions are equal in the `Encoder` and `Decoder`. This is not always the case, we do not necessarily need the same number of layers or the same hidden dimension sizes in a sequence-to-sequence model. However, if we did something like having a different number of layers then we would need to make decisions about how this is handled. For example, if our encoder has 2 layers and our decoder only has 1, how is this handled? Do we average the two context vectors output by the decoder? Do we pass both through a linear layer? Do we only use the context vector from the highest layer? Etc.
#
# Our `forward` method takes the source sentence, target sentence and a teacher-forcing ratio. The teacher forcing ratio is used when training our model. When decoding, at each time-step we will predict what the next token in the target sequence will be from the previous tokens decoded, $\hat{y}_{t+1}=f(s_t^L)$. With probability equal to the teaching forcing ratio (`teacher_forcing_ratio`) we will use the actual ground-truth next token in the sequence as the input to the decoder during the next time-step. However, with probability `1 - teacher_forcing_ratio`, we will use the token that the model predicted as the next input to the model, even if it doesn't match the actual next token in the sequence.
#
# The first thing we do in the `forward` method is to create an `outputs` tensor that will store all of our predictions, $\hat{Y}$.
#
# We then feed the input/source sentence, `src`, into the encoder and receive out final hidden and cell states.
#
# The first input to the decoder is the start of sequence (`<sos>`) token. As our `trg` tensor already has the `<sos>` token appended (all the way back when we tokenized our English sentences) we get our $y_1$ by slicing into it. We know how long our target sentences should be (`trg_length`), so we loop that many times. The last token input into the decoder is the one **before** the `<eos>` token -- the `<eos>` token is never input into the decoder.
#
# During each iteration of the loop, we:
#
# -   pass the input, previous hidden and previous cell states ($y_t, s_{t-1}, c_{t-1}$) into the decoder
# -   receive a prediction, next hidden state and next cell state ($\hat{y}_{t+1}, s_{t}, c_{t}$) from the decoder
# -   place our prediction, $\hat{y}_{t+1}$/`output` in our tensor of predictions, $\hat{Y}$/`outputs`
# -   decide if we are going to "teacher force" or not
#     -   if we do, the next `input` is the ground-truth next token in the sequence, $y_{t+1}$/`trg[t]`
#     -   if we don't, the next `input` is the predicted next token in the sequence, $\hat{y}_{t+1}$/`top1`, which we get by doing an `argmax` over the output tensor
#
# Once we've made all of our predictions, we return our tensor full of predictions, $\hat{Y}$/`outputs`.
#
# **Note**: our decoder loop starts at 1, not 0. This means the 0th element of our `outputs` tensor remains all zeros. So our `trg` and `outputs` look something like:
#
# $$
# \begin{align*}
# \text{trg} = [<sos>, &y_1, y_2, y_3, <eos>]\\
# \text{outputs} = [0, &\hat{y}_1, \hat{y}_2, \hat{y}_3, <eos>]
# \end{align*}
# $$
#
# Later on when we calculate the loss, we cut off the first element of each tensor to get:
#
# $$
# \begin{align*}
# \text{trg} = [&y_1, y_2, y_3, <eos>]\\
# \text{outputs} = [&\hat{y}_1, \hat{y}_2, \hat{y}_3, <eos>]
# \end{align*}
# $$

# %%
class Seq2Seq(nn.Module):
    def __init__(self, encoder, decoder, device):
        super().__init__()
        self.encoder = encoder
        self.decoder = decoder
        self.device = device

    def forward(self, src, trg, src_lengths, teacher_forcing_ratio):
        """
        src = [src length, batch size]
        trg = [trg length, batch size]
        teacher_forcing_ratio is probability to use teacher forcing
        e.g. if teacher_forcing_ratio is 0.75 we use ground-truth inputs 75% of the time
        """
        batch_size = trg.shape[1]
        trg_length = trg.shape[0]
        trg_vocab_size = self.decoder.output_dim
        """
        Tensor to store decoder outputs
        """
        outputs = torch.zeros(trg_length, batch_size, trg_vocab_size).to(self.device)

        # Last hidden state of the encoder is used as the initial hidden state of the decoder
        hidden, cell = self.encoder(src, src_lengths)
        """
        hidden = [n layers * n directions, batch size, hidden dim]
        cell = [n layers * n directions, batch size, hidden dim]
        first input to the decoder is the <sos> tokens
        """
        input = trg[0, :]
        for t in range(1, trg_length):
            """
            Insert input token embedding, previous hidden and previous cell states
            Receive output tensor (predictions) and new hidden and cell states
            """
            output, hidden, cell = self.decoder(input, hidden, cell)
            """
            output = [batch size, output dim]
            hidden = [n layers, batch size, hidden dim]
            cell = [n layers, batch size, hidden dim]
            place predictions in a tensor holding predictions for each token
            """
            outputs[t] = output
            # Decide if we are going to use teacher forcing or not
            teacher_force = random.random() < teacher_forcing_ratio
            # Get the highest predicted token from our predictions
            top1 = output.argmax(1)
            """
            If teacher forcing, use actual next token as next input
            Otherwise, use predicted token
            """
            input = trg[t] if teacher_force else top1
        return outputs

# %%
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')
example_seq2seq = Seq2Seq(encoder=example_encoder, decoder=example_decoder, device=device)
outputs = example_seq2seq.forward(src=train_data[0]["en_ids"].unsqueeze(1), trg=train_data[1]["en_ids"].unsqueeze(1), teacher_forcing_ratio=0.9)

# %% [markdown]
# - Ouput có 3 chiều như sau [target_token_length, batch_size, vocab_size]. Trong khi đó, ground_truth label có dạng [target_token_length, batch_size]. Trong đoạn code bên dưới, sử dụng train_data[0]["en_ids"].unsqueeze(1) để thêm một chiều minh họa cho số batch

# %%
from torch.nn import CrossEntropyLoss
criterion = CrossEntropyLoss(ignore_index=en_vocab[pad_token])

loss = criterion(outputs, train_data[0]["en_ids"].squeeze(0).to(device))
loss # Calculate loss with reshaped tensors
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-20-99c91cea82ac> in <cell line: 0>()
#       2 criterion = CrossEntropyLoss(ignore_index=en_vocab[pad_token])
#       3
# ----> 4 loss = criterion(outputs, train_data[0]["en_ids"].squeeze(0).to(device))
#       5 loss # Calculate loss with reshaped tensors
#
# NameError: name 'outputs' is not defined

# %% [markdown]
# ## Hyperparameters

# %%
input_dim = len(de_vocab)
output_dim = len(en_vocab)
encoder_embedding_dim = 384
decoder_embedding_dim = 384
hidden_dim = 1024
n_layers = 2
encoder_dropout = 0.5
decoder_dropout = 0.3
batch_size = 64
num_epochs = 30
teacher_forcing_ratio = 0.5
learning_rate = 0.001
weight_decay = 1e-5
device = torch.device('cuda') if torch.cuda.is_available() else torch.device('cpu')

# %% [markdown]
# ## Training

# %%
from torch.utils.data import DataLoader
from torch.optim import AdamW
from torch.nn import CrossEntropyLoss
from torch.nn.utils.rnn import pad_sequence

# %%
### START YOUR CODE HERE ###


# Create your dataloader from train set to pass into model
def collate_fn(batch):
    en_batch, de_batch = [], []
    en_lengths, de_lengths = [], []
    for sample in batch:
        en_batch.append(sample['en_ids'].clone().detach())
        de_batch.append(sample['de_ids'].clone().detach())
        en_lengths.append(len(sample['en_ids']))
        de_lengths.append(len(sample['de_ids']))

    # pad_sequence expects a list of tensors and creates a padded tensor
    # batch_first=False ensures shape is [seq_len, batch_size]
    en_batch = pad_sequence(en_batch, batch_first=False, padding_value=en_vocab[pad_token])
    de_batch = pad_sequence(de_batch, batch_first=False, padding_value=de_vocab[pad_token])

    en_batch = en_batch.to(device)
    de_batch = de_batch.to(device)

    de_lengths = torch.tensor(de_lengths, dtype=torch.long, device='cpu')

    # Return dictionary matching what the model expects
    return {"en_ids": en_batch, "de_ids": de_batch, "de_lengths": de_lengths}

train_loader = DataLoader(train_data, batch_size=batch_size, shuffle=True, collate_fn=collate_fn)
valid_loader = DataLoader(valid_data, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)
test_loader = DataLoader(test_data, batch_size=batch_size, shuffle=False, collate_fn=collate_fn)


# Define model

translation_encoder = Encoder(input_dim=input_dim,
                              embedding_dim=encoder_embedding_dim,
                              hidden_dim=hidden_dim,
                              n_layers=n_layers,
                              dropout=encoder_dropout).to(device)

translation_decoder = Decoder(output_dim=output_dim,
                              embedding_dim=decoder_embedding_dim,
                              hidden_dim=hidden_dim,
                              n_layers=n_layers,
                              dropout=decoder_dropout).to(device)

translation_model = Seq2Seq(encoder=translation_encoder,
                            decoder=translation_decoder,
                            device=device).to(device)

# Initialize neural network's weights
def init_weights(m):
    if isinstance(m, nn.Embedding):
        nn.init.normal_(m.weight, mean=0, std=0.01)
    elif isinstance(m, nn.LSTM):
        for name, param in m.named_parameters():
            if 'weight' in name:
                nn.init.xavier_uniform_(param)
            elif 'bias' in name:
                nn.init.zeros_(param)
    elif isinstance(m, nn.Linear):
        nn.init.xavier_uniform_(m.weight)
        nn.init.zeros_(m.bias)
translation_model.apply(init_weights)

# Define optimizer

optimizer = AdamW(translation_model.parameters(), lr=learning_rate)
scheduler = torch.optim.lr_scheduler.ReduceLROnPlateau(optimizer, 'min', patience=2, factor=0.5)

# Define loss function (Cross-entropy)
criterion = CrossEntropyLoss(ignore_index=de_vocab[pad_token])

# %%
best_valid_loss = float('inf')
patience = 3  # For early stopping
counter = 0
model_path = '/content/drive/MyDrive/Colab Notebooks/translation_model_weights.pth'

# Define training loop
for epoch in range(num_epochs):
    total_loss = 0
    num_batches = 0
    translation_model.train()
    for batch in train_loader:
        src = batch["de_ids"].to(device)
        trg = batch["en_ids"].to(device)
        src_lenghs = batch["de_lengths"]

        optimizer.zero_grad()

        output = translation_model.forward(src=src, trg=trg, src_lengths= src_lenghs, teacher_forcing_ratio=teacher_forcing_ratio)
        output = output[1:].view(-1, output.shape[-1])
        trg = trg[1:].view(-1)
        loss = criterion(output, trg)

        loss.backward()

        torch.nn.utils.clip_grad_norm_(translation_model.parameters(), max_norm=1.0)

        optimizer.step()

        total_loss += loss.item()
        num_batches += 1


    valid_loss = 0
    num_batches_valid = 0
    translation_model.eval()
    with torch.no_grad():
        for batch in valid_loader:
            src = batch["de_ids"].to(device)
            trg = batch["en_ids"].to(device)
            src_lenghs = batch["de_lengths"]

            output = translation_model.forward(src=src, trg=trg, src_lengths= src_lenghs, teacher_forcing_ratio=0)
            output = output[1:].view(-1, output.shape[-1])
            trg = trg[1:].view(-1)
            loss = criterion(output, trg)

            valid_loss += loss.item()
            num_batches_valid += 1

    valid_loss = valid_loss / num_batches_valid
    scheduler.step(valid_loss)

    print(f"Epoch: {epoch}, Loss: {total_loss/num_batches}, Valid loss: {valid_loss}")

    # Save best model
    if valid_loss < best_valid_loss:
        best_valid_loss = valid_loss
        torch.save(translation_model.state_dict(), model_path)
        print(f"Best model saved with validation loss: {best_valid_loss:.4f}")
        counter = 0
    else:
        counter += 1
        print(f"No improvement in validation loss for {counter} epochs")

    # Early stopping
    if counter >= patience:
        print(f"Early stopping after {patience} epochs without improvement")
        break

### END YOUR CODE HERE ###
# Out:
# Epoch: 0, Loss: 4.606053141770384, Valid loss: 4.564063757658005
# Best model saved with validation loss: 4.5641
# Epoch: 1, Loss: 3.880354332503768, Valid loss: 4.122086897492409
# Best model saved with validation loss: 4.1221
# Epoch: 2, Loss: 3.444709463266549, Valid loss: 3.8175432085990906
# Best model saved with validation loss: 3.8175
# Epoch: 3, Loss: 3.0759344368779185, Valid loss: 3.6242130994796753
# Best model saved with validation loss: 3.6242
# Epoch: 4, Loss: 2.7969220193997355, Valid loss: 3.5769391506910324
# Best model saved with validation loss: 3.5769
# Epoch: 5, Loss: 2.5686176201320428, Valid loss: 3.4661826342344284
# Best model saved with validation loss: 3.4662
# Epoch: 6, Loss: 2.3667681054396774, Valid loss: 3.4540758579969406
# Best model saved with validation loss: 3.4541
# Epoch: 7, Loss: 2.1483156418485265, Valid loss: 3.45891834795475
# No improvement in validation loss for 1 epochs
# Epoch: 8, Loss: 1.9786252266509943, Valid loss: 3.50136636197567
# No improvement in validation loss for 2 epochs
# Epoch: 9, Loss: 1.7975887677217894, Valid loss: 3.5090803056955338
# No improvement in validation loss for 3 epochs
# Early stopping after 3 epochs without improvement

# %% [markdown]
# ## Evaluation

# %%
from torchtext.data.metrics import bleu_score

def calculate_bleu(model, test_loader, de_vocab, device):
    model.eval()
    all_references = []
    all_candidates = []

    with torch.no_grad():
        for batch in test_loader:
            src = batch["de_ids"].to(device)
            trg = batch["en_ids"].to(device)
            src_lengths = batch["de_lengths"]

            output = model(src, trg, src_lengths, 0)
            output = output.argmax(2)

            for i in range(src.size(1)):
                predicted_tokens = [en_vocab.get_itos()[idx] for idx in output[:, i].tolist() if idx not in [en_vocab[sos_token], en_vocab[eos_token], en_vocab[pad_token]]][1:]
                target_tokens = [en_vocab.get_itos()[idx] for idx in trg[:, i].tolist() if idx not in [en_vocab[sos_token], en_vocab[pad_token], en_vocab[pad_token]]][:-1]
                print("Predicted: ", predicted_tokens)
                print("Target:", target_tokens)
                print()

                all_references.append([target_tokens])
                all_candidates.append(predicted_tokens)

    bleu = bleu_score(all_candidates, all_references)
    return bleu

# Load the best model
translation_model.load_state_dict(torch.load(model_path))
bleu = calculate_bleu(translation_model, test_loader, de_vocab, device)
# Out:
# Predicted:  ['a', 'man', 'in', 'an', 'orange', 'shirt', 'is', 'with', '<unk>']
# Target: ['a', 'man', 'in', 'an', 'orange', 'hat', 'starring', 'at', 'something']
#
# Predicted:  ['a', '<unk>', '<unk>', 'runs', 'through', 'grass', 'next', 'to', 'a', 'white', 'fence']
# Target: ['a', '<unk>', 'terrier', 'is', 'running', 'on', 'lush', 'green', 'grass', 'in', 'front', 'of', 'a', 'white', 'fence']
#
# Predicted:  ['a', 'girl', 'in', 'a', 'karate', 'uniform', 'is', 'a', 'a', 'calf', 'with', 'a', 'racket']
# Target: ['a', 'girl', 'in', 'karate', 'uniform', '<unk>', 'a', 'stick', 'with', 'a', 'front', 'kick']
#
# Predicted:  ['five', 'people', 'in', 'in', 'orange', 'and', 'orange', 'vests', 'are', 'standing', 'in', 'the', 'snow', 'with', 'a', 'in', 'the', 'background', 'the', 'background']
# Target: ['five', 'people', 'wearing', 'winter', 'jackets', 'and', 'helmets', 'stand', 'in', 'the', 'snow', 'with', '<unk>', 'in', 'the', 'background']
#
# Predicted:  ['people', 'are', 'on', 'the', 'side', 'of', 'a', 'house']
# Target: ['people', 'are', 'fixing', 'the', 'roof', 'of', 'a', 'house']
#
# Predicted:  ['a', 'man', 'dressed', 'in', 'a', 'white', 'suit', 'is', 'being', 'held', 'by', 'a', 'woman', 'in', 'white', 'white', 'dress', 'and', 'white', 'in', 'a', 'white', 'dress', 'standing', 'outside']
# Target: ['a', 'man', 'in', 'light', 'colored', 'clothing', 'photographs', 'a', 'group', 'of', 'men', 'wearing', 'dark', 'suits', 'and', 'hats', 'standing', 'around', 'a', 'woman', 'dressed', 'in', 'a', '<unk>', 'gown']
#
# Predicted:  ['a', 'group', 'of', 'people', 'are', 'standing', 'in', 'front', 'of', 'a', '<unk>']
# Target: ['a', 'group', 'of', 'people', 'standing', 'in', 'front', 'of', 'an', '<unk>']
#
# Predicted:  ['a', 'boy', 'in', 'a', 'red', 'uniform', 'is', 'attempting', 'to', 'catch', 'a', 'ball', 'while', 'the', 'player', 'in', 'red', 'attempts', 'to', 'catch', 'him']
# Target: ['a', 'boy', 'in', 'a', 'red', 'uniform', 'is', 'attempting', 'to', '<unk>', 'getting', 'out', 'at', 'home', 'plate', 'while', 'the', 'catcher', 'in', 'the', 'blue', 'uniform', 'is', 'attempting', 'to', 'catch', 'him']
#
# Predicted:  ['a', 'guy', 'works', 'on', 'a', 'building', 'building']
# Target: ['a', 'guy', 'works', 'on', 'a', 'building']
#
# Predicted:  ['a', 'man', 'in', 'a', 'cowboy', 'vest', 'is', 'sitting', 'on', 'a', 'chair', 'holding', 'a', 'hammer']
# Target: ['a', 'man', 'in', 'a', 'vest', 'is', 'sitting', 'in', 'a', 'chair', 'and', 'holding', 'magazines']
#
# Predicted:  ['a', 'mother', 'and', 'her', 'baby', 'enjoying', 'a', 'a', 'day', 'at', 'a', 'park']
# Target: ['a', 'mother', 'and', 'her', 'young', 'song', 'enjoying', 'a', 'beautiful', 'day', 'outside']
#
# Predicted:  ['men', 'playing', 'soccer', 'game', 'with', 'one', 'man', 'in', 'the', 'air', 'while', 'the', 'other', 'in', 'the', 'air', 'his']
# Target: ['men', 'playing', 'volleyball', 'with', 'one', 'player', 'missing', 'the', 'ball', 'but', 'hands', 'still', 'in', 'the', 'air']
#
# Predicted:  ['a', 'woman', 'is', 'a', 'a', 'kitchen', 'with', 'a', 'frying', 'pan']
# Target: ['a', 'woman', 'holding', 'a', 'bowl', 'of', 'food', 'in', 'a', 'kitchen']
#
# Predicted:  ['a', 'man', 'sitting', 'at', 'a', 'table', 'with', 'a', 'laptop', 'in', 'a']
# Target: ['man', 'sitting', 'using', 'tool', 'at', 'a', 'table', 'in', 'his', 'home']
#
# Predicted:  ['three', 'people', 'sit', 'in', 'a', '<unk>']
# Target: ['three', 'people', 'sit', 'in', 'a', 'cave']
#
# Predicted:  ['a', 'girl', 'in', 'a', '<unk>', 'outfit', 'is', 'walking', 'a', 'a']
# Target: ['a', 'girl', 'in', 'a', 'jean', 'dress', 'is', 'walking', 'along', 'a', 'raised', 'balance', 'beam']
#
# Predicted:  ['a', 'woman', 'with', 'a', 'camera', 'in', 'her', 'a', 'man', 'in', 'the', 'sand', 'sand']
# Target: ['a', 'blond', 'holding', 'hands', 'with', 'a', 'guy', 'in', 'the', 'sand']
#
# Predicted:  ['a', 'woman', 'in', 'a', 'gray', 'and', 'and', 'black', 'pants', 'is', 'standing', 'in', 'a', 'store', 'store', 'in', 'a', 'store']
# Target: ['a', 'woman', 'in', 'a', 'gray', 'sweater', 'and', 'black', 'baseball', 'cap', 'is', 'standing', 'in', 'line', 'at', 'a', 'shop']
#
# Predicted:  ['the', 'person', 'in', 'the', 'pink', 'shirt', 'is', 'a', 'mountain']
# Target: ['the', 'person', 'in', 'the', 'striped', 'shirt', 'is', 'mountain', 'climbing']
#
# Predicted:  ['two', 'men', 'are', '<unk>', '<unk>', 'while', 'while', 'while', 'other', 'women', 'look', 'on']
# Target: ['two', 'men', '<unk>', 'to', 'be', '<unk>', 'while', 'women', 'look', 'on']
#
# Predicted:  ['people', 'standing', 'outside', 'of', 'a', 'building', 'building']
# Target: ['people', 'standing', 'outside', 'of', 'a', 'building']
#
# Predicted:  ['a', 'young', 'playing', 'playing', 'a', 'game', 'game', 'on', 'a', 'field']
# Target: ['a', 'teenager', 'plays', 'her', 'trumpet', 'on', 'the', 'field', 'at', 'a', 'game']
#
# Predicted:  ['a', 'woman', 'is', 'a', 'a', 'handstand', 'on', 'the', 'beach', 'on', 'a', 'beach', 'beach']
# Target: ['a', 'woman', 'does', 'a', '<unk>', 'on', 'a', 'trampoline', 'on', 'the', 'beach']
#
# Predicted:  ['a', 'man', 'is', 'standing', 'in', 'a', 'a', 'bar', 'of', 'a']
# Target: ['a', 'man', 'is', 'standing', 'by', 'a', 'group', 'of', 'video', 'games', 'in', 'a', 'bar']
#
# Predicted:  ['a', 'woman', 'is', 'a', 'a', '<unk>', 'while', 'while', 'a', 'man', 'watches']
# Target: ['a', 'woman', 'uses', 'a', 'drill', 'while', 'another', 'man', 'takes', 'her', 'picture']
#
# Predicted:  ['a', 'woman', 'in', 'a', '<unk>', 'and', 'and', 'apron', 'is', 'a', 'a', 'with', 'a', 'a', 'cup', 'a']
# Target: ['a', 'woman', 'in', 'a', 'pink', 'sweater', 'and', 'an', 'apron', 'cleaning', 'a', 'table', 'with', 'a', '<unk>']
#
# Predicted:  ['a', 'man', 'is', '<unk>', '<unk>', '<unk>', 'of', 'some', 'trees']
# Target: ['a', 'man', 'cutting', 'branches', 'of', 'trees']
#
# Predicted:  ['a', 'group', 'of', 'young', 'young', 'boys', 'wait', 'for', 'to', 'get', 'a', '<unk>']
# Target: ['group', 'of', 'asian', 'boys', 'wait', 'for', 'meat', 'to', 'cook', 'over', 'barbecue']
#
# Predicted:  ['women', 'in', 'in', 'costumes', 'are', 'playing', 'the', '<unk>', 'of', '<unk>']
# Target: ['women', 'wearing', 'traditional', 'clothing', 'are', '<unk>', 'native', 'life']
#
# Predicted:  ['a', 'man', 'is', 'his', 'arm', 'around', 'another', 'man', 'who', 'is', 'holding', 'a', 'baseball', 'his', 'right']
# Target: ['one', 'man', 'holds', 'another', 'man', "'s", 'head', 'down', 'and', 'prepares', 'to', 'punch', 'him', 'in', 'the', 'face']
#
# Predicted:  ['six', 'people', 'riding', 'riding', 'a', '<unk>', 'through', 'a', '<unk>']
# Target: ['six', 'people', 'ride', 'mountain', 'bikes', 'through', 'a', 'jungle', 'environment']
#
# Predicted:  ['two', 'blond', 'girls', 'are', 'sitting', 'on', 'a', '<unk>', 'in', 'a', 'crowded', 'plaza']
# Target: ['2', 'blond', 'girls', 'are', 'sitting', 'on', 'a', 'ledge', 'in', 'a', 'crowded', 'plaza']
#
# Predicted:  ['a', 'child', 'swims', 'in', 'the', 'water', 'water']
# Target: ['a', 'child', 'is', 'splashing', 'in', 'the', 'water']
#
# Predicted:  ['three', 'people', 'sit', 'at', 'a', 'table', 'outside', 'a', 'building', 'with', 'a', '<unk>', 'on', 'it', 'the']
# Target: ['three', 'people', 'sit', 'at', 'a', 'picnic', 'table', 'outside', 'of', 'a', 'building', 'painted', 'like', 'a', '<unk>', 'jack']
#
# Predicted:  ['three', 'boys', 'are', 'standing', 'in', 'the', 'middle', 'of', 'a', 'field', 'the', 'sun']
# Target: ['3', 'boys', 'are', 'standing', 'on', 'a', 'pier', 'in', 'their', 'bathing', 'suits']
#
# Predicted:  ['a', '<unk>', 'is', 'a', 'a', 'woman', 'at', 'a', 'woman', "'s", '<unk>', 'while', 'a', 'at', 'a', 'market']
# Target: ['an', 'employee', 'is', 'handing', 'a', 'woman', 'a', 'bag', 'while', 'she', 'is', 'browsing', 'through', 'fish', 'on', 'ice', 'at', 'a', 'street', 'market']
#
# Predicted:  ['an', 'elderly', 'woman', 'is', 'playing', 'a', 'a', 'guitar', 'a']
# Target: ['a', 'pretty', 'woman', 'plays', 'a', '<unk>']
#
# Predicted:  ['a', 'a', 'building', 'a', 'a', 'building', 'a', 'a', 'building', 'in', 'front', 'of', 'a', 'large', 'building']
# Target: ['outside', 'a', 'building', 'a', 'uniformed', 'security', 'guard', 'looks', 'at', 'the', 'camera', 'from', 'behind', 'a', 'fence']
#
# Predicted:  ['the', 'young', 'lady', 'is', 'looking', 'at', 'the']
# Target: ['the', 'young', 'lady', 'is', 'looking', 'at', 'the', 'pizza']
#
# Predicted:  ['a', 'shirtless', 'man', 'wearing', 'a', 'pants', 'is', 'on', 'a', 'steps', 'while', 'others', 'are', 'around']
# Target: ['a', 'shirtless', 'man', 'in', 'shorts', 'is', 'fishing', 'while', 'standing', 'on', 'some', 'rocks']
#
# Predicted:  ['a', 'girl', 'in', 'a', 'bathing', 'suit', 'is', 'in', 'the', 'water']
# Target: ['a', 'girl', 'wearing', 'a', 'life', 'vest', 'floats', 'in', 'water']
#
# Predicted:  ['a', 'man', 'in', 'a', 'man', 'and', 'a', 'man', 'in', 'a', 'blue', 'shirt', 'standing', 'in', 'front', 'of', 'a', 'brick', 'building']
# Target: ['a', 'man', 'in', 'uniform', 'and', 'a', 'man', 'in', 'a', 'blue', 'shirt', 'are', 'standing', 'in', 'front', 'of', 'a', 'truck']
#
# Predicted:  ['people', 'sitting', 'on', 'a', 'train']
# Target: ['people', 'sit', 'inside', 'a', 'train']
#
# Predicted:  ['a', 'boy', 'is', 'in', 'the', 'air', 'with', 'a', 'skateboard', 'in', 'the', 'forest']
# Target: ['a', 'kid', 'swings', 'with', 'his', 'feet', 'up', 'in', 'the', 'air', 'in', 'a', 'forest']
#
# Predicted:  ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'a', 'a', '<unk>']
# Target: ['a', 'man', 'in', 'a', 'red', 'shirt', 'entering', 'an', 'establishment']
#
# Predicted:  ['two', 'men', 'in', 'swim', 'trunks', 'jumping', 'off', 'the', 'air', 'on', 'a', 'snow', 'beach']
# Target: ['two', 'men', 'wearing', 'swim', 'trunks', 'jump', 'in', 'the', 'air', 'at', 'a', '<unk>', '<unk>', 'beach']
#
# Predicted:  ['a', 'small', 'child', 'is', '<unk>', 'with', 'another', 'child']
# Target: ['a', 'toddler', 'is', 'cooking', 'with', 'another', 'person']
#
# Predicted:  ['a', '<unk>', 'and', 'two', 'children', 'are', '<unk>', '<unk>', '<unk>', 'on', 'a', '<unk>', 'with', 'a', '<unk>', 'with', 'a', '<unk>', 'with', 'a', 'tree']
# Target: ['a', 'father', 'figure', 'and', 'two', 'children', 'outside', 'their', 'home', 'doing', 'yard', 'work', '<unk>', 'as', 'using', 'a', '<unk>', 'on', 'the', 'grass', 'and', 'planting', 'a', 'tree']
#
# Predicted:  ['a', 'man', 'is', 'preparing', 'food', 'food']
# Target: ['a', 'man', 'cooking', 'food', 'on', 'the', 'stove']
#
# Predicted:  ['a', 'man', 'in', 'jeans', 'is', 'playing', 'a', 'a', 'ball', 'with', 'a', 'red', 'ball']
# Target: ['a', 'man', 'in', 'jeans', 'at', 'the', 'beach', 'playing', 'with', 'a', 'red', 'ball']
#
# Predicted:  ['people', 'walk', 'on', 'a', 'sidewalk', 'next', 'to', 'a', 'parking', 'lot']
# Target: ['people', 'walking', 'down', 'sidewalk', 'next', 'to', 'a', 'line', 'of', 'stores']
#
# Predicted:  ['a', 'male', 'is', 'a', 'a', 'flip', 'while', 'the', 'rodeo', 'as', 'he', '<unk>', 'the', '<unk>']
# Target: ['a', '<unk>', 'performs', 'a', 'flip', 'while', 'being', '<unk>', 'at', 'high', 'speed']
#
# Predicted:  ['a', 'large', 'crowd', 'of', 'people', 'are', 'a', 'street', 'street']
# Target: ['a', 'large', 'group', 'of', 'people', 'fill', 'a', 'street']
#
# Predicted:  ['a', 'man', 'walking', 'on', 'a', 'rough', 'boat', 'in', 'the', 'water', 'water']
# Target: ['a', 'man', 'on', 'a', 'tag', 'line', 'going', 'into', 'the', 'water']
#
# Predicted:  ['a', 'woman', 'in', 'jeans', 'walks', 'past', 'a', 'store', 'window', 'while', 'a', 'woman', 'is', 'looking', 'her', 'right', 'as', 'she', 'walks', 'her', 'right']
# Target: ['a', 'woman', 'in', 'jeans', 'walks', 'by', 'a', 'bus', 'with', 'an', 'ad', '<unk>', 'a', 'woman', 'peering', 'over', 'her', 'sunglasses']
#
# Predicted:  ['a', 'man', 'in', 'a', 'gray', 'shirt', 'is', 'sitting', 'on', 'the', 'beach', 'with', 'a', 'ball', 'ball', 'in', 'the', 'air']
# Target: ['a', 'man', 'in', 'a', 'pink', 'shirt', 'is', 'sitting', 'in', 'the', 'grass', 'and', 'a', 'ball', 'is', 'in', 'the', 'air']
#
# Predicted:  ['a', 'climber', 'is', '<unk>', 'the', 'the', 'beach']
# Target: ['a', 'car', 'parked', 'at', 'the', 'beach']
#
# Predicted:  ['two', 'men', 'in', 'black', 'suits', 'in', 'a', 'city']
# Target: ['two', 'men', 'wearing', 'black', 'in', 'a', 'city']
#
# Predicted:  ['the', 'man', 'in', 'the', 'yellow', 'uniform', 'is', 'his', 'his', 'arm']
# Target: ['the', 'man', 'in', 'the', 'yellow', 'pants', 'is', 'raising', 'his', 'arms']
#
# Predicted:  ['two', 'men', 'wearing', 'sunglasses', 'and', 'hats', 'stand', 'in', 'a', 'body', 'of', 'water', 'water']
# Target: ['two', 'men', 'wearing', 'hats', 'and', 'using', 'walking', 'sticks', 'are', 'walking', 'near', 'a', 'body', 'of', 'water', 'during', '<unk>']
#
# Predicted:  ['a', '<unk>', 'is', 'performing', 'a', 'dance', 'at', 'a']
# Target: ['a', 'cheerleading', 'team', 'doing', 'a', 'routine', 'on', 'chairs']
#
# Predicted:  ['a', 'boy', 'playing', 'playing', 'with', 'a', '<unk>', 'while', 'a', 'young', 'girl', 'watches']
# Target: ['a', 'boy', 'is', 'playing', 'checkers', 'with', 'an', 'adult', 'shown', 'off', 'screen', 'while', 'a', 'girl', 'looks', 'on']
#
# Predicted:  ['a', 'group', 'of', 'people', 'are', 'enjoying', 'a', 'park', 'in', 'a', 'public']
# Target: ['a', 'crowd', 'of', 'people', 'out', 'for', 'some', 'fun', 'in', 'public', 'park']
#
# Predicted:  ['a', 'man', 'sits', 'on', 'a', 'bench', 'with', 'his', 'dog', 'while', 'looking', 'at', 'the', 'water', 'water']
# Target: ['a', 'man', 'sits', 'on', 'a', 'bench', 'holding', 'his', 'dog', 'and', 'looking', 'at', 'the', 'water']
#
# Predicted:  ['a', 'boy', 'and', 'his', 'son', 'are', 'playing', 'playing', 'in', 'a', 'garden']
# Target: ['a', 'boy', 'and', 'his', 'younger', 'brother', 'playing', 'together', 'at', 'the', 'playground']
#
# Predicted:  ['a', 'woman', 'in', 'blue', 'looks', 'at', 'a', 'a', 'while', 'a', 'a', 'a', 'while', 'a', 'a', 'a', 'bench', 'while', 'others', 'walk', 'by', 'a', 'bench']
# Target: ['a', 'woman', 'in', 'blue', 'looks', 'in', 'a', 'black', 'leather', 'bag', 'while', 'sitting', 'on', 'a', 'bench', 'during', 'a', 'sunny', 'afternoon', 'while', 'people', 'and', '<unk>', 'passed', 'behind', 'her']
#
# Predicted:  ['the', 'brown', 'dog', 'is', 'standing', 'on', 'the', 'sandy']
# Target: ['the', 'brown', 'dog', 'is', 'standing', 'on', 'the', 'sandy', 'beach']
#
# Predicted:  ['a', 'woman', 'sits', 'with', 'a', 'large', 'of', 'of', 'people', 'of', 'flowers']
# Target: ['a', 'woman', 'is', 'sitting', 'with', 'a', 'basket', 'of', 'cloth', 'surrounded', 'by', 'cloth']
#
# Predicted:  ['a', 'man', 'is', 'outside', 'in', 'the', 'yard']
# Target: ['a', 'man', 'is', 'grilling', 'out', 'in', 'his', 'backyard']
#
# Predicted:  ['a', 'woman', 'is', 'in', 'a', '<unk>', 'with', 'a', 'car', 'with', 'her']
# Target: ['a', 'woman', 'sings', 'in', 'a', 'club', 'with', 'a', 'guitarist', 'behind', 'her']
#
# Predicted:  ['<unk>', 'musicians', 'playing', 'on', 'a', 'stage', 'under', 'a', 'red', 'tent']
# Target: ['guitar', 'player', 'performs', 'at', 'a', 'nightclub', 'red', 'guitar']
#
# Predicted:  ['a', 'child', 'sits', 'on', 'a', '<unk>', 'chair', 'looking', 'at', 'the', 'camera']
# Target: ['a', 'child', 'sitting', 'on', 'a', 'lawn', 'chair', 'looking', 'up', 'at', 'the', 'camera']
#
# Predicted:  ['two', 'women', 'and', 'two', 'women', 'look', 'at', 'the', 'sky', 'the', 'ocean']
# Target: ['two', 'ladies', 'and', 'three', 'men', 'looking', 'at', 'the', 'ocean']
#
# Predicted:  ['a', '<unk>', '<unk>', 'on', 'a', 'stage', 'with', 'a', 'guitar', 'while', 'a', 'woman', 'in', 'a', 'black', 'suit', 'sits', 'behind', 'her']
# Target: ['a', 'female', 'performer', 'with', 'a', 'violin', 'plays', 'on', 'a', 'street', 'while', 'a', 'woman', 'with', 'a', 'blue', 'guitar', 'looks', 'on']
#
# Predicted:  ['a', 'young', 'girl', 'swimming', 'in', 'a', 'pool']
# Target: ['a', 'young', 'girl', 'swimming', 'in', 'a', 'pool']
#
# Predicted:  ['several', 'children', 'are', 'outside', 'to', 'to', 'play', 'to', 'play']
# Target: ['several', 'children', 'are', 'outdoors', 'getting', 'ready', 'to', 'play', 'tug', 'of', 'war']
#
# Predicted:  ['three', 'teenagers', 'are', 'a', 'a', 'a']
# Target: ['three', 'teenagers', 'in', 'a', 'subway', 'playing', 'around']
#
# Predicted:  ['a', 'brown', 'dog', 'runs', 'through', 'the', 'grass', 'while', 'his', 'tongue', 'out']
# Target: ['a', 'brown', 'dog', 'walks', 'in', 'the', 'grass', 'with', 'its', 'tongue', 'hanging', 'out']
#
# Predicted:  ['people', 'sitting', 'outside', 'in', 'front', 'of', 'a', 'building', 'with', 'some', 'trees']
# Target: ['people', 'sitting', 'in', 'the', 'grass', 'outside', 'a', 'building', 'taking', 'a', 'break']
#
# Predicted:  ['man', 'with', 'glasses', 'looks', 'at', 'a', 'a', 'in', 'a', 'crowd', 'while', 'people', 'people', 'are', 'standing', 'in', 'front', 'of', 'him']
# Target: ['shirtless', 'guy', 'staring', 'off', 'in', 'the', 'distance', 'while', 'three', 'woman', 'are', 'walking', 'past', 'a', 'crowd', 'sitting', 'outside', 'a', 'cafe']
#
# Predicted:  ['two', 'boys', 'are', 'looking', 'out', 'on', 'the']
# Target: ['two', 'young', 'boys', 'putting', 'fruit', 'on', 'the', 'bike']
#
# Predicted:  ['a', 'man', 'in', 'a', 'black', 't', 'shirt', 'is', 'playing', 'a', 'black', 'guitar', 'on', 'a', '<unk>']
# Target: ['a', 'man', 'in', 'a', 'black', 't', 'shirt', 'cap', 'and', 'jeans', 'is', 'playing', 'drums', 'on', 'an', 'upside', 'down', 'yellow', '<unk>']
#
# Predicted:  ['a', 'young', 'is', 'painting', 'a', 'picture', 'of', 'a', 'woman', 'on', 'a', 'a', 'wall', 'a', 'wall']
# Target: ['a', 'young', 'female', 'artists', 'paints', 'an', 'image', 'of', 'a', 'woman', 'on', 'a', 'wall']
#
# Predicted:  ['two', '<unk>', '<unk>', 'players', 'attempt', 'to', '<unk>', 'the', 'ball', 'while', 'two', 'other', 'horses']
# Target: ['two', 'female', 'members', 'of', 'team', 'usa', 'performing', 'a', 'jump', 'high', 'five', 'surrounded', 'by', 'two', 'other', 'female', 'members']
#
# Predicted:  ['a', 'man', 'is', 'cutting', 'his', 'in', 'in', 'a', 'kitchen', 'kitchen']
# Target: ['a', 'man', 'stirring', 'a', 'pot', 'of', 'liquid', 'in', 'this', 'kitchen']
#
# Predicted:  ['a', 'boy', 'is', '<unk>', 'on', 'the', 'lake', 'a', 'lake']
# Target: ['the', 'boy', 'is', '<unk>', 'on', 'the', 'lake']
#
# Predicted:  ['a', 'man', 'works', 'on', 'a', '<unk>']
# Target: ['a', 'man', 'is', 'working', 'a', 'hotdog', 'stand']
#
# Predicted:  ['a', 'large', 'group', 'of', 'people', 'and', 'and', 'and', 'and', 'sit', 'sit', 'outside']
# Target: ['a', 'large', 'group', 'of', 'people', 'of', 'various', 'ages', 'and', '<unk>', 'sit', 'outside', 'together']
#
# Predicted:  ['a', 'blond', 'woman', 'is', 'eating', 'a', 'meal', 'at', 'a', 'bar']
# Target: ['a', 'blond', 'haired', 'woman', 'is', 'pouring', 'drinks', 'at', 'a', 'bar']
#
# Predicted:  ['a', 'small', 'child', 'in', 'a', 'blue', 't', 'shirt', 'is', 'a', 'a', 'yellow', 'object']
# Target: ['a', 'small', 'child', 'wearing', 'a', 'blue', 'and', 'white', 't', 'shirt', 'happily', 'holding', 'a', 'yellow', 'plastic', '<unk>']
#
# Predicted:  ['a', 'woman', 'in', 'black', 'black', 'and', 'a', 'hair', 'is', 'talking', 'to', 'a', 'man']
# Target: ['a', 'woman', 'with', 'pink', 'hair', 'dressed', 'in', 'black', 'talks', 'to', 'a', 'man']
#
# Predicted:  ['the', 'man', 'in', 'the', '<unk>', 'is', 'is', 'preparing', 'to', 'food', 'for', 'two', 'men']
# Target: ['the', 'man', 'in', 'a', 'japanese', 'cooking', 'suit', 'is', 'preparing', 'a', 'meal', 'for', 'two', 'people']
#
# Predicted:  ['a', 'girl', 'jumps', 'up', 'to', 'the', 'rocks', 'to', 'the', 'shore']
# Target: ['a', 'girl', '<unk>', 'across', 'the', 'river', 'from', 'rock', 'to', 'rock']
#
# Predicted:  ['a', 'worker', 'with', 'a', '<unk>', 'is', 'is', 'standing', 'by', 'two', 'women']
# Target: ['a', 'male', 'worker', 'with', 'his', 'tool', 'box', 'is', 'kneeling', 'next', 'to', 'two', 'women']
#
# Predicted:  ['an', 'older', 'man', 'is', 'his', 'his', 'and', 'looking', 'at', 'his']
# Target: ['an', 'older', 'man', 'is', 'opening', 'his', 'arms', 'wide', 'and', 'looking', '<unk>']
#
# Predicted:  ['a', 'child', 'in', 'a', 'white', 'outfit', 'is', 'swinging', 'a', 'toy']
# Target: ['a', 'child', 'in', 'a', 'white', 'karate', 'outfit', 'practicing', 'a', 'move']
#
# Predicted:  ['three', 'men', 'in', 'orange', 'vests', 'vests', 'are', 'working', 'on', 'a']
# Target: ['three', 'men', 'in', 'same', 'colored', 'vests', 'are', 'in', 'the', 'outdoors']
#
# Predicted:  ['a', 'woman', 'is', 'taking', 'a', 'picture', 'of', 'a', 'man', 'in', 'a', 'black', 'shirt', 'while', 'another', 'man', 'watches']
# Target: ['a', 'woman', 'takes', 'a', 'picture', 'of', 'a', 'baby', 'wearing', 'a', 'pink', 'hat', 'while', 'a', 'man', 'carries', 'her']
#
# Predicted:  ['a', 'group', 'of', 'elderly', 'men', 'sit', 'sitting', 'on', 'chairs', 'in', '<unk>', 'chairs', 'chairs']
# Target: ['a', 'group', 'of', 'mostly', 'asian', 'children', 'sitting', 'at', '<unk>', 'in', 'blue', 'chairs']
#
# Predicted:  ['a', 'young', 'boy', 'in', 'a', 'brown', 'uniform', 'holds', 'a', '<unk>', 'his', 'face']
# Target: ['a', 'young', 'boy', 'in', 'a', 'soccer', 'uniform', 'crying', 'into', 'his', '<unk>']
#
# Predicted:  ['a', 'smiling', 'woman', 'is', 'to', 'to', 'a', 'a', 'a', '<unk>']
# Target: ['a', 'happy', 'woman', 'is', 'preparing', 'a', '<unk>', 'at', 'a', 'coffee', 'shop']
#
# Predicted:  ['a', 'construction', 'worker', 'is', '<unk>', 'construction', 'site', 'on', 'a', 'construction', 'site']
# Target: ['a', 'construction', 'worker', 'is', 'driving', 'heavy', 'equipment', 'at', 'a', 'work', 'site']
#
# Predicted:  ['a', 'woman', 'is', 'running', 'after', 'a', 'tennis', 'ball', 'to', 'to', 'hit', 'a', '<unk>']
# Target: ['a', 'woman', 'runs', 'after', 'making', 'a', 'hit', 'in', 'women', "'s", 'softball', 'the', 'catcher', '<unk>', 'to', 'her', 'feet']
#
# Predicted:  ['a', 'man', 'in', 'camouflage', 'is', 'giving', 'another', 'another', 'man', 'a', '<unk>']
# Target: ['a', 'man', 'in', 'a', 'work', 'uniform', 'passing', 'a', 'tool', 'to', 'another', 'person']
#
# Predicted:  ['a', 'group', 'of', 'people', 'are', 'riding', 'on', '<unk>', '<unk>', 'in', 'the']
# Target: ['a', 'group', 'of', 'people', 'are', 'climbing', 'in', 'cold', 'weather']
#
# Predicted:  ['a', 'climber', 'with', 'a', 'blue', 'helmet', '<unk>', '<unk>', '<unk>']
# Target: ['a', '<unk>', 'about', 'to', '<unk>', 'down', 'a', 'mountain', 'with', 'a', 'blue', 'helmet', 'on']
#
# Predicted:  ['a', 'man', 'is', 'a', 'handstand', 'on', 'a', '<unk>']
# Target: ['a', 'man', 'doing', 'handstand', 'on', 'top', 'of', 'a', 'round', 'statue']
#
# Predicted:  ['a', 'child', 'sits', 'on', 'a', '<unk>', 'chair', 'while', 'holding', 'a', '<unk>']
# Target: ['a', 'child', 'sitting', 'at', 'a', 'restaurant', 'table', 'holding', 'a', 'paper', 'mask', 'against', 'his', 'face']
#
# Predicted:  ['a', 'brown', 'dog', 'is', 'a', 'a', 'a', 'a', 'a', 'tree', 'a', 'stick']
# Target: ['a', 'brown', 'dog', '<unk>', 'into', 'a', 'lake', 'to', '<unk>', 'a', 'stick']
#
# Predicted:  ['a', 'mother', 'is', 'her', 'her', 'two', 'boys', 'in', 'a', 'white', 'boat', 'with', 'a', '<unk>', 'of', 'water']
# Target: ['a', 'mother', '<unk>', 'her', 'two', 'young', 'boys', 'to', 'fish', 'off', 'of', 'a', 'rocky', 'coast', 'into', 'very', 'blue', 'water']
#
# Predicted:  ['a', 'small', 'child', 'runs', 'alone', 'by', 'a']
# Target: ['a', 'little', 'kid', 'is', 'walking', 'next', 'to', 'red', 'banners']
#
# Predicted:  ['a', 'girl', 'is', 'on', 'a', 'playground', 'with', 'a', 'little', 'boy', 'while', 'a', 'little', 'boy', 'watches', 'behind', 'her']
# Target: ['a', 'girl', 'sits', 'on', 'a', 'decorated', 'bike', 'with', 'a', 'younger', 'boy', 'while', 'another', 'girl', 'takes', 'a', 'picture']
#
# Predicted:  ['a', 'black', 'dog', 'is', 'a', 'ball', 'into', 'the', 'water']
# Target: ['a', 'black', 'dog', 'is', '<unk>', 'a', 'ball', 'in', 'water']
#
# Predicted:  ['a', 'man', 'in', 'white', 'shorts', 'and', 'a', 'blue', 'shirt', 'is', 'a', 'a', 'yellow', '<unk>']
# Target: ['a', 'man', 'in', 'white', 'pants', 'and', 'a', 'blue', 'shirt', 'is', 'kicking', 'a', 'yellow', 'boxing', 'bag']
#
# Predicted:  ['two', 'men', 'men', 'are', 'a', 'in', 'a', 'public']
# Target: ['two', 'indian', 'men', 'participating', 'in', 'a', 'ceremony']
#
# Predicted:  ['a', 'boy', 'with', 'his', 'face', 'face', 'and', 'a', 'face', 'in', 'a', '<unk>']
# Target: ['a', 'boy', 'with', 'a', '<unk>', 'nose', 'and', 'writing', 'on', 'his', 'hands', 'is', 'standing', 'in', 'a', 'video', '<unk>', 'store']
#
# Predicted:  ['two', '<unk>', 'in', 'in', 'a', 'canoe', 'in', 'the', 'ocean', 'on', 'the', 'shore', 'the', 'shore']
# Target: ['two', 'silhouetted', 'people', 'paddle', 'a', 'canoe', 'on', 'the', 'ocean', 'during', 'sunset']
#
# Predicted:  ['people', 'standing', 'in', 'a', 'crowded', 'building', 'waiting', 'for', 'the', 'train', 'the']
# Target: ['people', 'are', 'standing', 'on', 'a', 'crowded', 'subway', 'and', 'the', 'platform', 'outside', 'is', 'visible', 'through', 'the', 'window']
#
# Predicted:  ['man', 'working', 'with', 'with', 'a', 'with', 'his', 'hand', 'his', 'hand']
# Target: ['man', 'scaling', 'wall', 'with', 'fire', 'in', 'hand']
#
# Predicted:  ['two', 'brown', 'dogs', 'run', 'through', 'the', 'snow']
# Target: ['two', 'brown', 'dogs', 'are', 'running', 'through', 'the', 'snow']
#
# Predicted:  ['a', 'a', 'band', 'playing', 'a', 'a', 'band', 'playing', 'a', 'a', 'band']
# Target: ['on', 'stage', 'photo', 'of', 'small', 'band', 'performing', 'for', 'theater', 'audience']
#
# Predicted:  ['a', 'baby', 'in', 'a', '<unk>', 'looks', 'at', 'the', 'camera', 'camera']
# Target: ['a', 'baby', 'in', 'a', 'christmas', 'outfit', 'looks', 'at', 'the', 'camera']
#
# Predicted:  ['a', 'man', 'is', 'sitting', 'next', 'to', 'a', '<unk>']
# Target: ['a', 'man', 'is', 'sitting', 'next', 'to', 'a', 'computer', 'monitor']
#
# Predicted:  ['this', 'woman', 'is', '<unk>', '<unk>', '<unk>', '<unk>', 'and', 'and', 'and', 'and']
# Target: ['this', 'lady', 'has', '<unk>', 'a', 'funny', '<unk>', 'and', 'laughing']
#
# Predicted:  ['people', 'in', 'a', 'building', 'looking', 'a', 'picture', 'of', 'a', 'fence']
# Target: ['people', 'inside', 'of', 'a', 'building', 'one', 'is', 'taking', 'a', 'photo']
#
# Predicted:  ['four', 'white', 'dogs', 'with', '<unk>', 'jumping', 'over', 'a', 'red', 'wall']
# Target: ['four', 'white', 'dogs', 'with', '<unk>', 'jump', 'over', 'a', 'red', 'wall']
#
# Predicted:  ['the', 'woman', 'in', 'the', 'blue', 'shirt', 'is', 'holding', 'a', 'baby', 'baby']
# Target: ['the', 'woman', 'with', 'the', 'blue', 'shirt', 'is', 'holding', 'a', 'baby']
#
# Predicted:  ['two', 'people', 'sit', 'on', 'a', 'green', 'and', 'boat', 'and', 'water', 'in', 'a', 'body', 'of', 'water']
# Target: ['two', 'people', 'are', 'sitting', 'fishing', 'on', 'striped', 'beach', 'chairs', 'in', 'a', 'body', 'of', 'water']
#
# Predicted:  ['an', 'old', 'woman', 'sits', 'on', 'a', 'table', 'with', '<unk>', '<unk>']
# Target: ['an', 'old', 'woman', 'working', 'at', 'a', 'loom', 'making', 'cloth']
#
# Predicted:  ['a', 'boy', 'boy', 'looking', 'at', 'the', 'others', 'while', 'standing', 'in', 'a', 'fountain']
# Target: ['a', 'boy', 'standing', 'in', 'the', 'foreground', 'looking', 'out', 'over', 'other', 'people', 'in', 'a', 'court']
#
# Predicted:  ['a', 'man', 'in', 'a', 'blue', 'jacket', 'is', 'holding', 'a', 'boy', 'on', 'his', 'shoulder', 'his', 'head']
# Target: ['a', 'man', 'in', 'a', 'blue', 'coat', 'grabbing', 'a', 'young', 'boy', "'s", 'shoulder']
#
# Predicted:  ['three', 'brown', 'dogs', 'jumping', 'into', 'the', 'white', 'in', 'the', 'dark']
# Target: ['three', 'brown', 'dogs', 'are', 'jumping', 'up', 'at', 'the', 'woman', 'wearing', 'blue']
#
# Predicted:  ['a', 'boy', 'is', 'peeking', 'out', 'the', 'window', 'of', 'a', '<unk>', '<unk>']
# Target: ['a', 'boy', 'hangs', 'out', 'of', 'a', 'passing', 'taxi', 'cab', 'window']
#
# Predicted:  ['a', 'man', 'in', 'a', 'gray', 'shirt', 'is', 'jumping', 'a', 'a', 'on', 'a', 'rock', 'in', 'the', 'lake']
# Target: ['a', 'man', 'in', 'a', 'gray', 'shirt', 'jumps', 'over', 'the', 'top', 'of', 'a', 'sand', 'dune', 'in', 'the', 'desert']
#
# Predicted:  ['a', 'child', 'in', 'a', 'yellow', 'shirt', 'is', 'jumping', 'and', 'jumping']
# Target: ['a', 'child', 'wearing', 'a', 'yellow', 'shirt', 'is', 'jumping', 'up', 'and', 'down']
#
# Predicted:  ['a', 'worker', 'in', 'a', 'yellow', 'jacket', 'is', 'to', 'be', 'by', 'a', 'building']
# Target: ['a', 'worker', 'in', 'a', 'yellow', 'jacket', 'is', '<unk>', 'up', 'high', 'to', 'work', 'on', 'a', 'building']
#
# Predicted:  ['a', 'man', 'in', 'a', 'clothing', 'is', 'with', 'two', 'men', 'men']
# Target: ['a', 'man', 'in', '<unk>', 'giving', 'an', '<unk>', 'talk', 'to', 'young', 'adults']
#
# Predicted:  ['a', 'couple', 'enjoying', 'a', 'a', 'with', 'a', 'with', 'a', '<unk>']
# Target: ['a', 'bunch', 'of', 'beer', 'pull', '<unk>', 'at', 'a', 'bar', 'with', 'christmas', 'lights', 'on', 'the', 'ceiling']
#
# Predicted:  ['a', 'man', 'is', 'fishing', 'off', 'a', 'cliff', 'on', 'the', 'ocean']
# Target: ['a', 'man', 'is', '<unk>', 'down', 'a', 'cliff', 'over', 'the', 'ocean']
#
# Predicted:  ['a', 'man', 'in', 'black', 'walking', 'in', 'the', 'snow', 'with', 'his', 'arms']
# Target: ['a', 'man', 'in', 'black', 'is', 'walking', 'to', 'his', 'truck', 'in', 'the', 'snow']
#
# Predicted:  ['a', '<unk>', 'player', 'is', 'jumping', 'to', 'catch', 'a', 'ball', 'a', 'ball']
# Target: ['a', '<unk>', 'terrier', 'leaps', 'after', 'a', 'ball']
#
# Predicted:  ['a', 'lady', 'wearing', 'a', 'blue', 'and', 'and', 'glasses', 'and', 'a', 'blue', 'shirt', 'is', 'outside', 'of', 'a', 'store']
# Target: ['a', 'female', 'police', 'officer', 'in', 'a', 'cap', 'and', 'navy', 'uniform', 'smiles', 'while', 'wearing', 'sunglasses', 'outside', 'of', 'a', 'shop']
#
# Predicted:  ['a', 'family', 'walks', 'a', 'a', 'park', 'park']
# Target: ['a', 'family', 'going', 'for', 'a', 'walk', 'in', 'a', 'park']
#
# Predicted:  ['a', 'man', 'wearing', 'a', 'green', 'hat', 'and', 'apron', 'and', 'looking', 'at', 'someone']
# Target: ['a', 'man', 'in', 'a', 'green', 'hard', 'hat', 'and', 'yellow', 'safety', 'vest', '<unk>']
#
# Predicted:  ['a', 'child', 'with', 'a', '<unk>', 'is', 'is', 'playing', 'with', 'two', 'toys', 'and', '<unk>']
# Target: ['child', 'with', 'pink', 'strings', 'on', 'head', 'dancing', 'surrounded', 'by', 'confetti', 'balloons']
#
# Predicted:  ['a', 'dog', 'with', '<unk>', '<unk>', 'is', 'to', 'to', 'a', 'waterfall']
# Target: ['a', 'dog', 'with', 'a', '<unk>', 'nose', '<unk>', 'for', 'something', 'on', 'a', 'riverbank']
#
# Predicted:  ['a', 'man', 'is', 'his', 'to', 'for', 'his', 'for', 'the']
# Target: ['a', 'man', 'prepares', 'his', 'local', 'stand', 'for', 'the', '<unk>', 'business']
#
# Predicted:  ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', '<unk>', 'meat', 'at', 'a', 'grill']
# Target: ['a', 'man', 'in', 'a', 'red', 'shirt', 'is', 'about', 'to', 'eat', 'a', '<unk>']
#
# Predicted:  ['a', 'young', 'lady', 'in', 'a', 'white', 'suit', 'is', 'holding', 'a', 'tennis', 'racket', 'racket']
# Target: ['a', 'young', 'lady', 'in', 'white', 'holding', 'a', 'tennis', 'racket']
#
# Predicted:  ['a', 'boy', 'in', 'a', 'red', 'shirt', 'is', 'digging', 'in', 'the', 'sand', 'with', 'a', 'shovel', 'shovel', 'sand']
# Target: ['a', 'boy', 'wearing', 'a', 'red', 'shirt', 'digs', 'into', 'the', 'sand', 'with', 'a', 'yellow', 'shovel']
#
# Predicted:  ['a', 'person', 'in', 'a', 'pink', 'jacket', 'is', 'sitting', 'on', 'a', 'wooden', 'bench']
# Target: ['an', 'individual', 'wearing', '<unk>', 'jacket', 'site', '<unk>', 'on', 'a', 'wooden', 'bench']
#
# Predicted:  ['a', 'man', 'in', 'a', 'white', 'shirt', 'is', 'looking', 'out', 'a', 'window', 'of', 'a', 'store']
# Target: ['a', 'man', 'wearing', 'a', 'white', 'shirt', 'is', 'looking', 'out', 'a', 'window', 'of', 'a', 'metal', 'construction']
#
# Predicted:  ['a', 'woman', 'is', 'holding', 'a', 'white', 'white']
# Target: ['a', 'woman', 'is', 'holding', 'a', 'small', 'white', 'statue']
#
# Predicted:  ['six', 'children', 'in', 't', 'shirts', 'playing', 'playing', 'in', 'shallow', 'water', 'and', 'water']
# Target: ['six', 'shirtless', 'children', 'are', 'playing', 'in', '<unk>', 'water', 'and', 'splashing', 'around']
#
# Predicted:  ['two', 'people', 'riding', 'bikes', 'are', 'riding', 'through', 'a', 'dirt', 'area']
# Target: ['two', 'people', 'riding', 'bikes', 'through', 'a', 'mountainous', '<unk>']
#
# Predicted:  ['a', 'girl', 'is', 'on', 'the', 'sidewalk', 'next', 'to', 'a', 'building']
# Target: ['a', 'girl', 'jumping', 'rope', 'on', 'a', 'sidewalk', 'near', 'a', 'parking', 'garage']
#
# Predicted:  ['a', 'man', 'wearing', 'a', 'shirt', 'shirt', 'and', 'a', 'hat']
# Target: ['a', 'man', 'wearing', 'an', 'orange', 'shirt', 'and', 'helmet']
#
# Predicted:  ['a', 'little', 'boy', 'is', 'playing', 'with', '<unk>', '<unk>', 'while', 'while', 'some', 'other', 'and', 'and', 'look', 'on']
# Target: ['a', 'small', 'boy', 'plays', 'with', 'plastic', 'blocks', 'cars', 'and', 'animals', 'with', 'an', 'adult', 'watching', 'closely']
#
# Predicted:  ['a', 'little', 'girl', 'is', 'a', 'a', '<unk>']
# Target: ['a', 'little', 'girl', 'opening', 'a', 'christmas', 'present']
#
# Predicted:  ['the', 'woman', 'in', 'blue', 'is', 'is', 'a', 'picture', 'of', 'a', 'children']
# Target: ['the', 'woman', 'in', 'blue', 'is', 'operating', 'a', 'camera', 'in', 'front', 'of', 'two', 'other', 'women']
#
# Predicted:  ['a', 'little', 'girl', 'is', 'trying', 'to', '<unk>', 'a', 'a', 'on', 'a', 'playground']
# Target: ['a', 'little', 'girl', 'tries', 'taking', 'a', 'nap', 'on', 'the', '<unk>', 'sofa']
#
# Predicted:  ['a', 'brown', 'and', 'white', 'dog', 'is', 'running', 'on', 'a', 'dirt', 'in', 'the', 'forest', 'the', 'forest', 'the', 'background']
# Target: ['a', 'brown', 'and', 'black', 'dog', 'running', 'on', 'a', 'trail', 'in', 'the', 'woods']
#
# Predicted:  ['two', 'dogs', 'play', 'on', 'a', 'tree', 'tree']
# Target: ['two', 'dogs', 'play', 'by', 'a', 'tree']
#
# Predicted:  ['a', '<unk>', 'in', 'a', 'black', 'and', 'black', 'jacket', 'is', 'looking', 'at', 'the', 'camera', 'while', 'the', 'man', 'watches', 'behind', 'him']
# Target: ['a', 'navy', 'walking', 'wearing', 'a', 'black', 'coat', 'and', 'pants', 'on', 'the', 'stairs', 'as', 'camera', '<unk>', 'on', 'the', 'dog']
#
# Predicted:  ['two', 'young', 'men', 'in', 'aprons', 'are', 'preparing', 'food', 'in', 'a', 'restaurant', 'restaurant', 'restaurant']
# Target: ['two', 'men', 'dressed', 'in', 'green', 'are', 'preparing', 'food', 'in', 'a', 'restaurant']
#
# Predicted:  ['a', 'man', 'in', 'a', 'black', 'vest', 'and', 'a', 'hat', 'is', 'walking', 'a', 'a']
# Target: ['a', 'man', 'dressed', 'in', 'black', 'leather', 'and', 'a', 'cowboy', 'hat', 'is', 'walking', 'around', 'a', 'renaissance', 'festival']
#
# Predicted:  ['a', 'dog', 'runs', 'with', 'a', 'yellow', 'toy', 'in', 'a']
# Target: ['a', 'dog', 'runs', 'outside', 'with', 'a', 'yellow', 'toy']
#
# Predicted:  ['a', 'dog', 'running', 'a', 'a', 'pink', 'coat', 'in', 'the', 'snow', 'snow']
# Target: ['a', 'dog', 'wearing', 'a', 'cover', 'runs', 'in', 'the', 'snow']
#
# Predicted:  ['a', 'family', 'is', 'playing', 'on', 'the', 'beach', 'with', 'her', 'dog']
# Target: ['a', 'family', 'is', 'playing', 'on', 'the', 'beach', 'with', 'their', 'dog']
#
# Predicted:  ['a', 'woman', 'and', 'a', 'child', 'child', 'are', 'watching', 'a', 'child', 'who', 'are', 'like', 'they', 'are', 'like', 'they', 'are', '<unk>']
# Target: ['a', 'woman', 'and', 'a', 'child', 'embrace', 'while', 'the', 'child', '<unk>', 'what', 'they', 'have', 'been', 'making']
#
# Predicted:  ['two', 'men', 'and', 'a', 'woman', 'are', 'standing', 'outside', 'outside']
# Target: ['two', 'men', 'and', 'a', 'lady', 'are', 'standing', 'outside']
#
# Predicted:  ['a', 'group', 'of', 'men', 'hold', 'a', 'net', 'to', 'to', 'the', 'water', 'a', 'boat', 'water']
# Target: ['a', 'group', 'of', 'men', 'using', 'logs', 'to', 'push', 'a', 'boat', 'out', 'of', 'the', 'water']
#
# Predicted:  ['a', 'man', 'is', 'speaking', 'to', 'a', 'while', 'a', 'a', 'a', 'a']
# Target: ['a', 'man', 'drinks', 'from', 'a', '<unk>', 'while', 'reading', 'the', 'paper']
#
# Predicted:  ['a', 'man', 'dressed', 'in', 'black', 'black', 'suit', 'is', 'playing', 'the', 'drums']
# Target: ['a', 'man', 'wearing', 'a', 'all', 'black', 'and', 'playing', 'a', 'piano']
#
# Predicted:  ['a', 'boy', 'in', 'a', 'blue', 'jersey', 'and', 'blue', 'shorts', 'is', 'playing', 'soccer', 'soccer', 'ball']
# Target: ['a', 'young', 'boy', 'wearing', 'a', 'blue', 'jersey', 'and', 'yellow', 'shorts', 'is', 'playing', 'soccer']
#
# Predicted:  ['a', 'man', 'is', 'standing', 'on', 'a', 'rock', 'holding', 'a', 'a', 'net', 'his']
# Target: ['a', 'man', 'is', 'standing', 'on', 'a', 'stone', 'structure', 'with', 'his', 'arms', 'out', 'like', 'a', 'bird']
#
# Predicted:  ['a', 'dog', 'is', 'outside', 'the', 'grass', 'on', 'the', 'grass']
# Target: ['a', 'dog', 'drinks', 'water', 'outside', 'on', 'the', 'grass']
#
# Predicted:  ['two', 'women', 'in', '<unk>', 'look', 'at', 'the', 'camera']
# Target: ['two', 'women', 'wearing', 'tank', 'tops', 'are', 'looking', 'at', 'the', 'camera']
#
# Predicted:  ['a', 'man', 'sits', 'in', 'a', '<unk>', 'chair', 'while', '<unk>', '<unk>', '<unk>']
# Target: ['a', 'man', 'is', 'sitting', 'in', 'a', 'barber', "'s", 'chair', 'getting', 'ready', 'for', 'a', '<unk>']
#
# Predicted:  ['a', 'small', 'child', 'in', 'a', 'green', 'outfit', 'playing', 'playing', 'in', 'a', 'sprinkler']
# Target: ['a', 'young', 'child', 'wearing', 'green', 'boots', 'playing', 'in', 'a', 'mud', 'puddle']
#
# Predicted:  ['a', 'man', 'is', 'cutting', 'wood', 'with', 'a', 'chainsaw']
# Target: ['a', 'man', 'using', 'a', 'chainsaw', 'to', 'cut', '<unk>']
#
# Predicted:  ['a', 'man', 'sits', 'at', 'a', 'table', 'with', 'a', 'table', 'with', 'and', 'and', 'and', 'a']
# Target: ['a', 'man', 'sitting', 'at', 'a', 'picnic', 'table', 'with', 'a', 'tray', 'and', 'partially', '<unk>', 'beer', 'in', 'front', 'of', 'him']
#
# Predicted:  ['the', 'boy', 'in', 'the', 'black', 't', 'shirt', 'and', 'blue', 'jeans', 'is', 'holding', 'a', 'blue', 'ball']
# Target: ['the', 'boy', 'wearing', 'a', 'black', 'shirt', 'and', 'blue', 'jeans', 'is', 'holding', 'a', 'red', 'baseball', 'bat']
#
# Predicted:  ['a', 'long', 'haired', 'man', 'with', 'glasses', 'beard', 'and', 'glasses', 'is', 'sitting', 'on', 'the', 'grass', 'the', 'grass']
# Target: ['a', 'dark', 'haired', 'bearded', 'man', 'in', 'glasses', 'and', 'a', 'hawaiian', 'shirt', 'is', 'sitting', 'on', 'the', 'grass']
#
# Predicted:  ['dogs', 'running', 'around', 'a', '<unk>']
# Target: ['dogs', 'run', 'at', 'a', 'dog', 'racetrack']
#
# Predicted:  ['a', '<unk>', '<unk>', 'with', 'a', '<unk>', 'climbs', 'a', 'a', 'a', 'a']
# Target: ['a', 'light', '<unk>', 'man', 'with', 'tribal', 'tattoos', 'aiming', 'a', 'spotlight', 'over', 'a', 'balcony']
#
# Predicted:  ['two', 'male', 'wrestlers', 'are', 'each', 'other', 'each', 'other']
# Target: ['two', 'german', '<unk>', '<unk>', 'at', 'each', 'other']
#
# Predicted:  ['the', 'group', 'of', 'people', 'are', 'standing', 'around', 'a', '<unk>', 'of']
# Target: ['this', 'is', 'a', 'group', 'of', 'people', 'standing', 'around', 'at', 'some', 'sort', 'of', 'event']
#
# Predicted:  ['a', 'brown', 'and', 'white', 'dog', 'is', 'a', 'toy']
# Target: ['a', 'brown', 'and', 'white', 'dog', '<unk>', 'a', 'toy']
#
# Predicted:  ['a', 'man', 'with', 'a', 'beard', 'plays', 'playing', 'a', 'instrument', 'instrument', 'with', 'people']
# Target: ['man', 'with', 'white', 'hair', 'playing', 'an', 'accordion', 'in', 'the', 'middle', 'of', 'some', 'buildings']
#
# Predicted:  ['a', 'woman', 'with', 'brown', 'hair', 'is', 'sitting', 'on', 'a', 'bench', 'outside', 'a', 'cafe', 'a', 'cafe']
# Target: ['a', 'woman', 'with', 'brown', 'hair', 'sitting', 'on', 'a', 'bench', 'outside', 'a', 'cafe']
#
# Predicted:  ['a', 'man', 'is', 'playing', 'a', 'guitar', 'next', 'to', 'a', 'bicycle']
# Target: ['a', 'man', 'next', 'to', 'a', 'bicycle', 'is', 'playing', 'a', 'pan', 'flute']
#
# Predicted:  ['two', 'children', 'are', 'a', 'a', 'and', 'one', 'is', 'a', 'rope']
# Target: ['two', 'kids', 'are', 'balancing', 'on', 'a', 'log', 'and', 'holding', 'a', 'rope']
#
# Predicted:  ['a', 'man', 'on', 'a', 'bicycle', 'is', 'a', 'wheelie', 'on', 'a', 'ramp']
# Target: ['a', 'man', 'riding', 'a', 'motorcycle', 'is', 'performing', 'a', 'trick', 'at', 'a', 'track']
#
# Predicted:  ['a', 'young', 'woman', 'with', 'a', '<unk>', 'on', 'her', 'head', 'is', 'a', 'a', 'a', 'a', 'a', 'rock']
# Target: ['a', 'young', 'woman', 'with', 'a', 'purple', 'cloth', 'hiding', 'her', 'face', 'relaxes', 'on', 'a', 'wooden', 'deck']
#
# Predicted:  ['the', 'woman', 'in', 'the', 'brown', 'shirt', 'is', 'sitting', 'on', 'a', 'stone', 'bench']
# Target: ['the', 'woman', 'in', 'the', 'brown', 'shirt', 'is', 'sitting', 'on', 'a', 'bright', 'red', 'bench']
#
# Predicted:  ['a', 'dog', 'runs', 'along', 'a', 'grassy', 'field', 'near', 'a', 'river']
# Target: ['a', 'dog', 'walks', 'on', 'a', 'log', 'across', 'a', 'small', 'river']
#
# Predicted:  ['a', 'young', 'man', 'in', 'a', 'white', 't', 'shirt', 'and', 'khaki', 'shorts', 'stands', 'on', 'a', '<unk>']
# Target: ['a', 'young', 'man', 'wearing', 'a', 'white', 't', 'shirt', 'and', 'green', 'and', 'black', 'shorts', 'standing', 'on', 'a', 'stump']
#
# Predicted:  ['people', 'people', 'are', 'standing', 'near', 'each', 'other']
# Target: ['the', 'group', 'of', 'people', 'are', 'all', 'covered', 'by', 'umbrellas']
#
# Predicted:  ['a', 'man', 'is', 'his', 'his', 'with', 'a', '<unk>', 'with', 'with', 'a', '<unk>', 'on', 'his', 'head']
# Target: ['a', 'man', '<unk>', 'with', 'a', 'giant', 'sign', 'tied', 'onto', 'his', 'bicycle']
#
# Predicted:  ['a', 'man', 'is', 'a', 'a', 'dog', 'for', 'a', 'group', 'of', 'children', 'children']
# Target: ['a', 'man', 'is', 'throwing', 'a', 'log', 'into', 'a', 'waterway', 'while', 'two', 'dogs', 'watch']
#
# Predicted:  ['several', 'group', 'of', 'people', 'are', 'in', 'in', 'a', 'circle', 'fountain', 'in', 'the', 'water']
# Target: ['group', 'of', '<unk>', 'playing', 'instruments', 'under', 'a', 'tent', 'by', 'the', 'water']
#
# Predicted:  ['a', 'view', 'of', 'a', 'busy', 'street', 'in', 'a', 'city']
# Target: ['a', 'view', 'of', 'a', 'crowded', 'city', 'street']
#
# Predicted:  ['a', 'blond', 'woman', 'holds', 'a', 'white', 'white', 'animal', 'on', 'a', 'sunny', 'day', 'day']
# Target: ['a', 'young', 'blond', 'woman', 'holds', 'a', 'white', 'rope', 'on', 'a', 'sunny', 'day']
#
# Predicted:  ['two', 'people', 'in', 'blue', 'shirts', 'are', 'standing', 'in', 'a', '<unk>', 'with', 'with', '<unk>']
# Target: ['two', 'people', 'in', 'blue', 'shirts', 'are', 'outside', 'with', 'a', '<unk>']
#
# Predicted:  ['a', 'black', 'dog', 'jumping', 'into', 'a', 'swimming', 'pool', 'water']
# Target: ['a', 'black', 'dog', '<unk>', 'up', 'into', 'a', 'pool']
#
# Predicted:  ['a', 'cowboy', 'riding', 'a', 'bucking', 'horse', 'in', 'a', 'competition']
# Target: ['a', 'cowboy', 'riding', 'on', 'the', 'back', 'of', 'a', 'bronco', 'in', 'a', 'competition']
#
# Predicted:  ['a', 'group', 'of', '<unk>', 'cyclists', 'are', 'on', 'on', 'tracks']
# Target: ['a', 'railroad', 'work', 'crew', 'performs', 'maintenance', 'on', 'railroad', 'tracks']
#
# Predicted:  ['a', 'worker', 'in', 'an', 'orange', 'vest', 'is', 'working', 'a', 'a', 'shovel']
# Target: ['a', 'worker', 'in', 'an', 'orange', 'vest', 'is', 'using', 'a', 'shovel']
#
# Predicted:  ['two', 'construction', 'workers', 'are', 'working', 'on', 'a', 'construction', 'site']
# Target: ['two', 'construction', 'workers', 'have', 'a', 'discussion', 'while', 'on', 'the', 'work', 'site']
#
# Predicted:  ['three', 'men', 'are', 'walking']
# Target: ['three', 'men', 'are', 'walking', 'up', 'hill']
#
# Predicted:  ['an', 'asian', 'woman', 'in', 'a', '<unk>', 'and', '<unk>', 'poses', 'poses', 'with', 'a', 'bridge', 'on', 'a', 'bridge']
# Target: ['an', 'asian', 'woman', 'in', 'a', 'floral', 'wedding', 'dress', 'poses', 'on', 'a', 'bridge', 'close', 'to', 'her', 'bridesmaids']
#
# Predicted:  ['a', 'young', 'man', 'is', 'his', 'his', 'hands', 'in', 'his', 'kitchen']
# Target: ['a', 'young', 'man', '<unk>', 'his', 'guitar', 'in', 'the', 'kitchen']
#
# Predicted:  ['three', 'boys', 'playing', 'with', 'with', '<unk>', 'and', '<unk>']
# Target: ['three', 'boys', 'are', 'playing', 'with', '<unk>', 'and', 'buckets', 'of', 'water']
#
# Predicted:  ['three', 'workers', 'are', 'cleaning', 'debris', 'on', 'the', 'sidewalk', 'the', 'sidewalk']
# Target: ['three', 'construction', 'workers', 'are', '<unk>', 'pavement']
#
# Predicted:  ['people', 'in', 'a', 'boat', 'are', 'standing', 'by', 'a']
# Target: ['people', '<unk>', 'in', 'at', 'forest', 'next', 'to', 'canoes']
#
# Predicted:  ['a', 'couple', 'is', 'outdoors', 'in', 'a', 'church']
# Target: ['a', 'choir', 'group', 'is', 'gathered', 'together', 'in', 'a', 'church']
#
# Predicted:  ['a', 'group', 'of', 'young', 'boys', 'jumping', 'into', 'the', 'air', 'while', 'they', 'are', 'and', 'and', 'a', 'for', 'the']
# Target: ['a', 'group', 'of', 'young', 'teenagers', 'are', 'jumping', 'at', 'night', 'making', 'funny', 'poses', 'for', 'the', 'camera']
#
# Predicted:  ['two', 'men', 'are', 'kayaking', 'in', 'a', 'blue', 'blue', 'kayak', 'while', 'a', '<unk>', 'and', 'a', 'in', 'the', 'background']
# Target: ['two', 'guys', 'are', 'kayaking', 'one', 'orange', 'one', 'blue', 'down', 'a', 'creek']
#
# Predicted:  ['two', 'workers', 'are', 'cleaning', 'a', 'on', 'a', 'building']
# Target: ['two', 'workers', 'spread', 'cement', 'onto', 'a', 'brick', 'building']
#
# Predicted:  ['a', 'lady', 'in', 'a', '<unk>', 'and', 'and', 'blue', 'shirt', 'is', 'on', 'her', 'head', 'with', 'her', 'her', 'head', 'her', 'head']
# Target: ['a', 'lady', 'wearing', 'a', '<unk>', 'sweater', 'and', 'jeans', 'is', 'sitting', 'with', 'hands', 'on', 'her', 'left', 'knee']
#
# Predicted:  ['two', '<unk>', 'wrestlers', 'are', 'a', 'a', 'for', 'a', 'for', 'a', 'event']
# Target: ['two', 'performers', 'putting', 'on', 'a', '<unk>', 'fight', 'for', 'an', 'audience', 'that', 'is', 'watching', 'attentively']
#
# Predicted:  ['a', 'male', 'vendor', 'is', 'at', 'the', 'airport']
# Target: ['a', '<unk>', 'relaxes', 'and', 'waits', 'at', 'an', 'airport']
#
# Predicted:  ['a', 'man', 'in', 'a', 'yellow', 'jacket', 'is', 'a', 'a', 'a', 'a', 'a', 'small', 'boy', 'at', 'the']
# Target: ['a', 'man', 'in', 'a', 'yellow', 'coat', '<unk>', 'a', 'fire', 'a', 'boy', 'in', 'a', '<unk>', 'watches']
#
# Predicted:  ['a', 'man', 'and', 'a', 'boy', 'on', 'a', 'rock']
# Target: ['a', 'man', 'and', 'a', 'boy', 'on', 'a', 'rocky', 'beach']
#
# Predicted:  ['a', 'woman', 'on', 'a', 'boat', '<unk>', 'the', 'water', 'with', 'a', '<unk>', '<unk>', 'in', 'the', 'water']
# Target: ['a', 'woman', 'on', 'a', 'boat', 'named', '<unk>', '<unk>', '<unk>', 'black', '<unk>', 'into', 'the', 'water']
#
# Predicted:  ['a', 'boy', 'sits', 'on', 'a', 'rock', 'and', 'looking', 'at']
# Target: ['a', 'boy', 'sitting', 'on', 'and', 'looking', 'out', 'from', 'a', 'microscope']
#
# Predicted:  ['a', 'smiling', 'girl', 'girl', 'in', 'pink', 'pink', 'dress', 'is', 'outside']
# Target: ['a', 'young', 'barefoot', 'girl', 'in', 'a', 'pink', 'dress', 'is', 'jumping', 'outside']
#
# Predicted:  ['lots', 'of', 'people', 'sitting', 'at', 'a', 'table', 'in', 'a']
# Target: ['many', 'people', 'are', 'sitting', 'around', 'a', 'tent', 'outside']
#
# Predicted:  ['a', 'teenager', 'in', 'a', 'black', 't', 'shirt', '<unk>', '<unk>', '<unk>', '<unk>', 'and', 'playing', 'a', 'keyboard', 'and', 'a', 'guitar', 'a', 'guitar']
# Target: ['a', 'youth', 'with', 'a', 'black', 'shirt', 'that', 'says', 'asian', '<unk>', '<unk>', 'plays', 'a', 'drum', 'while', 'sitting']
#
# Predicted:  ['a', 'man', 'is', 'selling', 'something', 'from', 'the', 'ocean', 'of', 'a', 'large', 'mountain', 'with', 'a', 'large', 'mountain', 'the', 'background']
# Target: ['a', 'man', 'selling', 'items', 'near', 'the', 'roadside', 'to', 'the', 'great', 'mountain', 'of', 'canyon']
#
# Predicted:  ['the', 'girl', 'in', 'the', 'is', 'is', 'the', 'girl', 'girl', 'girl', 'the', 'girl', 'in', 'the', 'blue', 'dress', 'watches']
# Target: ['the', 'girl', 'in', 'yellow', 'is', 'laughing', 'at', 'the', 'girl', 'wearing', 'orange', 'whilst', 'being', 'watched', 'by', 'the', 'girl', 'in', 'blue']
#
# Predicted:  ['a', 'dog', 'jumps', 'over', 'a', 'hurdle']
# Target: ['a', 'dog', 'jumps', 'over', 'an', 'obstacle', 'outside']
#
# Predicted:  ['dog', 'wearing', 'black', 'pants', 'and', '<unk>', '<unk>', '<unk>']
# Target: ['dog', 'with', 'black', 'collar', 'rolling', 'in', 'dirt', 'and', '<unk>', 'leaves']
#
# Predicted:  ['two', 'brown', 'dogs', 'play', 'tug', 'of', 'war']
# Target: ['two', 'brown', 'dogs', 'playing', 'in', 'a', 'rough', '<unk>']
#
# Predicted:  ['a', 'man', 'with', 'a', 'beard', 'and', 'a', 'beard', 'is', 'holding', 'a', '<unk>', '<unk>']
# ...
#
# Predicted:  ['the', 'red', 'car', 'is', 'parked', 'in', 'the', 'in', 'front', 'of', 'the', 'background']
# Target: ['the', 'red', 'car', 'is', 'ahead', 'of', 'the', 'two', 'cars', 'in', 'the', 'background']
#
# Predicted:  ['a', 'football', 'player', 'is', 'attempting', 'to', 'throw', 'a', 'bull', 'while', 'a', '<unk>', '<unk>', 'a', '<unk>', '<unk>', '<unk>', '<unk>', '<unk>', 'his', '<unk>']
# Target: ['a', 'large', 'bull', '<unk>', 'a', 'man', '<unk>', 'away', 'in', 'a', 'rodeo', 'with', 'his', '<unk>', 'while', 'a', 'rodeo', 'clown', 'runs', 'to', 'help']
#
# Predicted:  ['a', 'man', 'is', 'walking', 'down', 'a', 'yellow', 'kayak', 'a', 'white', 'kayak']
# Target: ['a', 'shirtless', 'man', 'walks', 'toward', 'a', 'yellow', 'kayak']
#
# Predicted:  ['a', 'boy', 'and', 'his', 'pet', '<unk>', 'at', 'a', '<unk>']
# Target: ['a', 'boy', 'at', 'a', 'gun', 'range', '<unk>', 'and', '<unk>']
#
# Predicted:  ['two', '<unk>', 'playing', 'playing', 'volleyball', 'in', 'the', 'sand', 'beach']
# Target: ['two', 'teams', 'of', 'boys', 'playing', 'football', 'in', 'the', 'sand']
#
# Predicted:  ['a', 'child', 'child', 'in', 'blue', 'and', 'white', 'child', 'on', 'a', 'wooden', 'platform', 'next', 'to', 'a', 'large', 'bridge']
# Target: ['a', 'child', 'in', 'blue', 'and', 'a', 'child', 'in', 'white', 'stand', 'on', 'a', 'short', 'concrete', 'wall', 'by', 'a', 'stream']
#
# Predicted:  ['a', 'woman', 'is', 'a', 'a', '<unk>', 'on', 'a', '<unk>']
# Target: ['a', 'woman', 'draws', 'a', 'floral', 'design', 'on', 'a', 'clay', 'pot']
#
# Predicted:  ['people', 'walk', 'down', 'a', 'crowded', 'street', 'in', 'an', 'asian', 'city']
# Target: ['people', 'are', 'walking', 'down', 'a', 'busy', 'street', 'in', 'a', 'foreign', 'country']
#
# Predicted:  ['a', '<unk>', 'pitcher', 'is', 'throwing', 'a', 'ball', 'ball', 'a', 'ball', 'a', 'ball']
# Target: ['a', 'right', 'handed', 'pitcher', 'for', 'the', '<unk>', 'is', 'throwing', 'a', 'pitch']
#
# Predicted:  ['two', 'men', 'one', 'in', 'black', 'and', 'one', 'in', 'black', 'and', 'black', 'playing', 'playing', 'playing', 'the']
# Target: ['two', 'men', 'one', 'in', 'black', 'and', 'white', 'and', 'one', 'in', 'red', 'are', 'playing', 'beach', 'volleyball']
#
# Predicted:  ['a', 'man', 'is', 'standing', 'in', 'a', 'boat', 'and', 'some', '<unk>']
# Target: ['a', 'man', 'is', 'standing', 'in', 'a', 'boat', 'holding', 'some', '<unk>']
#
# Predicted:  ['a', 'surfer', 'in', 'midair', 'doing', 'a', 'trick', 'off', 'the', 'wave', 'to', 'his', 'wave', 'wave']
# Target: ['a', 'surfer', 'who', 'fell', 'off', 'his', 'surfboard', 'in', 'the', 'ocean', 'while', 'trying', 'to', 'ride', 'a', 'wave']
#
# Predicted:  ['a', '<unk>', 'is', 'is', 'a', 'a', 'a', 'a', 'a']
# Target: ['a', '<unk>', 'preparing', 'a', 'sample', 'in', 'the', 'lab']
#
# Predicted:  ['<unk>', 'collie', 'jumps', 'in', 'the', 'air', 'to', 'catch', 'the', 'ball', 'his', 'opponent']
# Target: ['soccer', 'players', 'are', 'jumping', 'in', 'the', 'air', 'to', 'hit', 'the', 'ball', 'with', 'their', 'heads']
#
# Predicted:  ['two', 'boys', 'are', 'playing', 'soccer', 'soccer', 'ball', 'soccer']
# Target: ['two', 'boys', 'play', 'soccer', 'against', 'each', 'other']
#
# Predicted:  ['an', 'elderly', 'person', 'is', 'a', 'street', 'with', 'a', 'umbrella', 'in', 'the', 'rain', 'rain']
# Target: ['an', 'elderly', 'person', 'is', 'crossing', 'a', 'street', 'with', 'an', 'umbrella', 'in', 'their', 'hands']
#
# Predicted:  ['a', 'group', 'of', 'four', 'people', 'are', 'walking', 'on', 'a', '<unk>', 'of', '<unk>']
# Target: ['a', 'group', 'of', 'runners', 'are', 'running', 'towards', 'two', 'identical', '<unk>']
#
# Predicted:  ['a', 'skateboarder', 'is', 'a', 'a', 'ramp', 'doing', 'a', 'a', 'trick', 'to', 'jump', 'a', 'ramp']
# Target: ['a', 'skateboarder', 'rides', 'up', 'a', 'concrete', 'wall', 'nearly', 'falling', 'off', 'as', 'he', 'tries', 'a', 'trick']
#
# Predicted:  ['people', 'playing', 'a', 'game', 'game', 'in', 'the', 'pool', 'the']
# Target: ['people', 'playing', 'a', 'game', 'in', 'the', 'pool']
#
# Predicted:  ['a', 'guy', 'is', 'kissing', 'another', 'man']
# Target: ['a', 'guy', 'give', 'a', 'kiss', 'to', 'a', 'guy', 'also']
#
# Predicted:  ['a', 'man', 'is', 'a', 'a', 'young', 'boy', 'at', 'a', 'small', 'table', 'the', 'library']
# Target: ['a', 'man', 'signs', 'an', '<unk>', 'in', 'a', 'young', 'boy', "'s", 'book']
#
# Predicted:  ['a', 'young', 'man', 'in', 'a', 'blue', 'shirt', 'is', 'a', 'a', 'parking', 'lot', 'on', 'a', 'busy']
# Target: ['a', 'young', 'man', 'in', 'a', 'blue', 'shirt', 'grinds', 'a', 'rail', 'on', 'a', 'skateboard', 'in', 'an', 'urban', 'area']
#
# Predicted:  ['an', 'asian', 'man', 'is', 'sitting', 'on', 'the', 'street', 'with', 'with', '<unk>']
# Target: ['an', 'asian', 'man', 'sits', 'on', 'the', 'tracks', 'with', 'crates', 'of', '<unk>']
#
# Predicted:  ['a', '<unk>', '<unk>', 'in', 'in', '<unk>', 'uniform', 'is', '<unk>', 'with', 'his', '<unk>', 'as', 'several', 'people', 'people', 'sit', 'on', 'the', 'the', 'background', 'the', 'background', 'the', 'background']
# Target: ['a', 'british', 'gentleman', 'dressed', 'in', 'full', 'military', 'uniform', 'waving', 'his', 'hat', 'with', 'a', 'background', 'of', 'people', 'sitting', 'back', 'and', 'looking', 'out', 'onto', 'the', 'waterway']
#
# Predicted:  ['two', 'people', 'riders', 'are', 'riding', 'on', 'a', 'track']
# Target: ['two', 'cars', 'are', 'driving', 'on', 'a', 'racetrack']
#
# Predicted:  ['a', 'man', 'in', 'a', 'black', 'and', 'white', 'shirt', 'and', 'black', 'bandanna', 'is', 'preparing', 'to', 'throw', 'his']
# Target: ['a', 'man', 'in', 'a', 'black', 'and', 'white', 'jersey', 'is', 'holding', 'yellow', 'ski', 'poles', 'and', 'preparing', 'to', 'take', 'off']
#
# Predicted:  ['two', 'people', 'are', 'on', 'a', 'bench', 'and', 'a', 'baby']
# Target: ['two', 'people', 'are', 'laying', 'down', 'and', 'kissing', 'on', 'a', 'grassy', 'lawn']
#
# Predicted:  ['a', 'very', 'happy', 'child', 'with', 'a', '<unk>', 'is', 'eating', 'a', 'red', '<unk>']
# Target: ['a', 'very', 'young', 'child', 'in', 'a', 'denim', 'baseball', 'cap', 'eats', 'a', 'green', 'apple']
#
# Predicted:  ['the', 'football', 'players', 'are', 'running', 'after', 'the', 'ball', 'the', 'ball']
# Target: ['the', 'football', 'players', 'are', 'running', 'to', 'get', 'the', 'ball']
#
# Predicted:  ['a', 'man', 'wearing', 'a', 'black', 'hat', 'and', 'black', 'shirt', 'and', 'black', 'shirt', 'is', 'playing', 'a', 'guitar', 'on', 'a', 'stage', 'with', 'a', 'guitar', 'and', 'a', 'guitar', 'and', 'a', 'background', 'the', 'background']
# Target: ['a', 'man', 'in', 'a', 'black', 'jacket', 'and', 'checkered', 'hat', 'wearing', 'black', 'and', 'white', 'striped', 'pants', 'plays', 'an', 'electric', 'guitar', 'on', 'a', 'stage', 'with', 'a', 'singer', 'and', 'another', 'guitar', 'player', 'in']
#
# Predicted:  ['a', 'man', 'jumps', 'off', 'a', 'a', 'jump', 'over', 'a', 'large']
# Target: ['a', 'man', 'is', 'leaping', 'over', 'a', 'barrier', 'away', 'from', 'a', 'bull']
#
# Predicted:  ['a', 'woman', 'in', 'a', 'blue', 'shirt', 'and', 'blue', 'shorts', 'is', 'playing', 'tennis', 'tennis', 'tennis']
# Target: ['a', 'woman', 'in', 'a', 'blue', 'shirt', 'and', 'white', 'shorts', 'playing', 'tennis']
#
# Predicted:  ['a', 'man', 'is', 'playing', 'a', '<unk>', 'in', 'a', 'concert']
# Target: ['a', 'man', 'is', 'playing', 'an', '<unk>', 'in', 'a', 'concert']
#
# Predicted:  ['a', 'man', 'is', 'carrying', 'a', 'large', '<unk>', 'that', 'says', '<unk>', 'a', 'a', 'a', 'a']
# Target: ['a', 'man', 'is', 'carrying', 'a', 'large', 'load', 'of', 'metal', 'beams', 'on', 'his', 'shoulder', 'through', 'a', '<unk>']
#
# Predicted:  ['woman', 'with', 'a', 'tennis', 'racket', 'to', 'to', 'catch', 'a', 'ball', 'ball']
# Target: ['woman', 'with', 'camera', 'is', 'throwing', 'a', 'frisbee', 'for', 'her', 'brown', 'dog', 'to', 'catch']
#
# Predicted:  ['a', 'is', 'a', 'man', 'and', 'a', 'woman', 'in', 'a', 'woman', '<unk>', 'a', 'a', 'a', 'a', '<unk>']
# Target: ['there', 'is', 'an', '<unk>', 'of', 'a', 'male', 'and', 'female', 'observing', 'a', '<unk>', 'or', 'other', 'large', 'burning', 'wooden', 'object']
#
# Predicted:  ['two', 'girls', 'are', 'their', 'hands', 'in', 'a', 'crowd', 'while', 'people', 'look', 'on']
# Target: ['two', 'girls', '<unk>', 'their', 'hands', 'in', 'a', 'fountain', 'as', 'people', 'walk', 'by']
#
# Predicted:  ['an', '<unk>', 'child', 'child', 'with', 'a', 'hair', 'is', 'with', 'his', 'hands', 'in', 'in', 'the', 'air']
# Target: ['a', 'wet', 'smiling', 'child', 'without', 'a', 'shirt', 'poses', 'with', 'arms', 'raised']
#
# Predicted:  ['two', 'men', 'one', 'in', 'white', 'and', 'one', 'in', 'blue']
# Target: ['two', 'men', 'one', 'wearing', 'white', 'and', 'the', 'other', 'wearing', 'blue', 'are', 'wrestling']
#
# Predicted:  ['a', 'woman', 'in', 'a', 'red', 'bikini', 'is', 'jumping', 'to', 'catch', 'a', 'ball', 'in', 'the', 'ball', 'on', 'a', 'beach', 'a', 'game']
# Target: ['a', 'woman', 'in', 'a', 'red', 'bikini', 'jumping', 'to', 'hit', 'a', 'ball', 'while', 'playing', 'volleyball', 'at', 'a', 'beach']
#
# Predicted:  ['<unk>', 'in', 'orange', 'scrubs', '<unk>', 'a', 'young', 'boy', 'in', 'her', 'hair']
# Target: ['orange', 'striped', '<unk>', 'biting', 'blond', 'girl', 'on', 'the', 'nose']
#
# Predicted:  ['a', 'woman', 'in', 'a', 'yellow', 'shirt', 'is', '<unk>', 'from', 'a', 'large', '<unk>']
# Target: ['a', 'woman', 'wearing', 'a', 'yellow', 'apron', 'is', 'taking', 'the', '<unk>', 'off', 'of', 'a', 'large', 'pot']
#
# Predicted:  ['two', 'children', 'are', 'a', 'a', 'a', 'a', 'a', 'a', 'rock']
# Target: ['two', 'children', 'cross', 'a', 'small', '<unk>', 'using', 'a', 'stone', 'bridge']
#
# Predicted:  ['two', '<unk>', 'women', 'are', 'riding', 'on', 'a', '<unk>', 'on', 'a', 'busy', 'sidewalk', 'in', 'a', '<unk>', '<unk>', '<unk>']
# Target: ['two', 'african', 'american', 'females', 'ride', 'on', 'a', 'moped', 'down', 'a', 'city', 'street', 'that', 'appears', 'to', 'be', 'in', 'a', 'well', '<unk>', 'area', 'of', 'a', 'large', 'city', 'area']
#
# Predicted:  ['two', 'boys', 'are', 'in', 'front', 'of', 'a', '<unk>']
# Target: ['two', 'boys', 'in', 'front', 'of', 'a', 'soda', 'machine']
#
# Predicted:  ['bikers', 'in', 'black', 'bicycle', 'down', 'a', 'dirt', 'road', 'on', 'a', 'paved']
# Target: ['bicycle', 'rider', 'wearing', 'black', 'riding', 'down', 'a', 'dirt', 'trail', 'in', 'a', 'mountain', 'bike']
#
# Predicted:  ['a', 'woman', 'with', '<unk>', '<unk>', 'her', 'cellphone', 'while', 'leaning', 'against', 'a', 'painting', 'a', 'building']
# Target: ['a', 'lady', 'with', 'tattoos', 'is', 'taking', 'a', 'picture', 'of', 'a', 'painting', 'with', 'her', '<unk>']
#
# Predicted:  ['a', 'woman', 'dressed', 'in', 'black', 'and', 'white', 'outfit', 'rides', 'a', 'red', 'horse', 'in', 'front', 'of', 'trees', 'in', 'the', 'background', 'the', 'background', 'background', 'the', 'background']
# Target: ['a', 'woman', 'in', 'a', 'mostly', 'black', 'outfit', 'and', 'white', 'helmet', 'riding', 'a', 'bike', 'with', 'blurred', 'trees', 'in', 'the', 'background']
#
# Predicted:  ['a', 'team', 'of', 'four', 'men', 'are', 'racing', 'in', 'the', 'while', 'while', 'onlookers', 'watch', 'them', 'and', 'watch']
# Target: ['a', 'team', 'of', 'cyclists', '<unk>', 'a', 'bend', 'while', 'nearby', 'spectators', 'cheer', 'and', 'take', 'photographs']
#
# Predicted:  ['four', 'soccer', 'players', 'in', 'black', 'uniforms', 'are', 'the', 'the', 'the', 'team', 'in', 'black', 'and', 'white', 'uniforms', 'the', 'background']
# Target: ['four', 'football', 'players', 'in', 'black', 'are', 'tackling', 'the', 'opposing', 'team', "'s", 'player', 'shown', 'in', 'white', 'while', 'it', 'is', 'raining']
#
# Predicted:  ['a', '<unk>', 'prepares', 'to', 'keep', 'to', 'keep', 'while', 'two', '<unk>', 'while', 'two', 'opponents']
# Target: ['a', 'runner', '<unk>', 'for', '<unk>', 'while', 'being', '<unk>', 'down', 'by', 'two', '<unk>']
#
# Predicted:  ['the', 'basketball', 'player', 'in', 'the', 'white', 'uniform', '<unk>', 'the', 'the', 'the', 'the', 'team', 'in', 'the', 'blue', 'team', 'in', 'white']
# Target: ['the', 'basketball', 'player', 'in', 'the', 'white', 'uniform', 'with', 'the', 'number', '<unk>', 'on', 'it', 'is', '<unk>', 'the', 'player', 'in', 'the', 'black', 'uniform', 'with', 'the', 'number', '10', 'on', 'it']
#
# Predicted:  ['a', 'man', 'is', 'outside', 'reading', 'his', 'cellphone']
# Target: ['a', 'man', 'is', 'talking', 'on', 'a', 'cellphone', 'outside']
#
# Predicted:  ['<unk>', 'players', '<unk>', 'a', 'a', 'game', 'of', 'the', '<unk>', 'team']
# Target: ['professional', 'baseball', 'players', 'during', 'the', 'all', 'star', 'game', 'watch', 'an', 'opponent', 'at', 'bat']
#
# Predicted:  ['a', '<unk>', 'biker', 'is', 'through', 'a', 'dirt', 'through', 'a', 'dirt']
# Target: ['dirt', 'biker', 'makes', 'a', '<unk>', 'turn', 'in', 'a', 'forest', 'during', 'the', 'fall']
#
# Predicted:  ['three', 'basketball', 'players', 'players', 'in', 'a', 'ball', 'in', 'a', 'game', 'of', 'the', 'ball', 'in', 'a', 'soccer', 'game', 'a', 'team', 'in', 'white']
# Target: ['3', 'basketball', 'players', '<unk>', 'for', 'the', 'ball', 'and', 'one', 'in', 'red', 'jersey', 'trying', 'to', 'take', 'ball', 'from', 'guy', 'in', 'white', 'jersey']
#
# Predicted:  ['a', 'boy', 'is', 'to', 'to', 'catch', 'his', 'while', 'he', 'spins', 'in', 'the', 'air']
# Target: ['a', 'boy', 'grabs', 'his', 'leg', 'as', 'he', 'jumps', 'in', 'the', 'air']
#
# Predicted:  ['two', 'children', 'in', 'striped', 'shirts', 'and', 'black', 'pants', 'pants', 'are', 'blowing', 'bubbles', 'in', 'a', 'tree']
# Target: ['two', 'children', 'wearing', 'striped', 'sweaters', 'and', 'black', 'pants', '<unk>', 'outdoors', 'near', 'a', 'play', 'set']
#
# Predicted:  ['a', 'man', 'wearing', 'sunglasses', 'is', 'riding', 'a', 'bicycle', 'a', 'road']
# Target: ['a', 'man', 'wearing', 'sunglasses', 'is', 'riding', 'a', 'scooter']
#
# Predicted:  ['a', 'young', 'boy', 'in', 'a', 'karate', 'uniform', 'is', 'a', 'a', 'bat', 'off', 'another', 'another', 'another', 'in', 'front', 'of', 'him']
# Target: ['a', 'small', 'boy', 'wearing', 'baseball', '<unk>', 'holds', 'a', 'bat', 'behind', 'his', 'head', 'with', 'a', 'baseball', 'mounted', 'in', 'front', 'of', 'him']
#
# Predicted:  ['six', 'men', 'sit', 'on', 'a', '<unk>', '<unk>', 'with', '<unk>']
# Target: ['six', 'men', 'sit', 'in', 'a', 'field', 'of', 'crops', 'containing', 'wooden', 'crates']
#
# Predicted:  ['a', 'brown', 'dog', 'is', 'a', 'a', 'a', 'large', 'a', 'a']
# Target: ['a', 'brown', 'dog', 'picks', 'up', 'a', '<unk>', 'from', 'a', 'stone', 'surface']
#
# Predicted:  ['this', 'is', 'a', 'man', 'in', 'a', 'a', 'a', 'a', 'a', 'brown', 'horse', 'his', 'head']
# Target: ['this', 'is', 'a', 'man', 'dressed', 'in', 'yellow', 'holding', 'the', '<unk>', 'of', 'a', 'brown', 'horse']
#
# Predicted:  ['a', 'man', 'in', 'a', 'white', 'shirt', 'and', 'a', 'hat', 'is', 'a', 'a', 'a']
# Target: ['a', 'man', 'in', 'a', 'white', 'shirt', 'and', 'apron', 'cuts', 'up', 'a', 'bird']
#
# Predicted:  ['an', 'indian', 'woman', 'is', 'buying', 'food', 'in', 'a', 'outdoor']
# Target: ['a', 'hispanic', 'woman', 'is', 'using', 'a', 'outdoors', '<unk>', 'to', 'cook']
#
# Predicted:  ['crowds', 'of', 'people', 'are', 'walking', 'down', 'a', 'street', 'street', 'with', 'onlookers', 'watch', 'them']
# Target: ['marathon', 'runners', 'are', 'racing', 'on', 'a', 'city', 'street', 'with', 'other', 'people', 'standing', 'around']
#
# Predicted:  ['asian', 'woman', 'is', 'a', 'a', '<unk>', '<unk>']
# Target: ['asian', 'woman', 'wearing', 'a', '<unk>', 'while', 'riding', 'a', 'bike']
#
# Predicted:  ['a', 'bunch', 'of', 'children', 'are', 'playing', 'on', 'benches', 'while', 'playing', 'instruments', 'the', 'background']
# Target: ['some', 'children', 'are', 'outside', 'playing', 'in', 'the', 'dirt', 'where', 'two', 'trees', 'are']
#
# Predicted:  ['an', 'older', 'man', 'is', 'playing', 'a', 'game']
# Target: ['an', 'older', 'man', 'is', 'playing', 'a', 'video', 'arcade', 'game']
#
# Predicted:  ['a', 'girl', 'on', 'a', 'rock', 'with', 'a', 'river', 'in', 'the', 'background', 'the', 'background', 'the', 'background', 'background']
# Target: ['a', 'girl', 'at', 'the', 'shore', 'of', 'a', 'beach', 'with', 'a', 'mountain', 'in', 'the', 'distance']

# %%
print(f"BLEU score: {bleu}")
# Out:
# BLEU score: 0.23337350351272038

# %% [markdown]
# # Overview on Attention
# **Attention** is, to some extent, motivated by how we pay visual attention to different regions of an image or correlate words in one sentence. Human visual attention allows us to focus on a certain region with “high resolution” (i.e. look at the pointy ear in the yellow box) while perceiving the surrounding image in “low resolution” (i.e. now how about the snowy background and the outfit?), and then adjust the focal point or do the inference accordingly. Given a small patch of an image, pixels in the rest provide clues what should be displayed there. We expect to see a pointy ear in the yellow box because we have seen a dog’s nose, another pointy ear on the right, and Shiba’]'s mystery eyes (stuff in the red boxes). However, the sweater and blanket at the bottom would not be as helpful as those doggy features.
# ![](https://lilianweng.github.io/posts/2018-06-24-attention/shiba-example-attention.png)
#
# Similarly, we can explain the relationship between words in one sentence or close context. When we see “eating”, we expect to encounter a food word very soon. The color term describes the food, but probably not so much with “eating” directly.
# ![](https://lilianweng.github.io/posts/2018-06-24-attention/sentence-example-attention.png)

# %% [markdown]
# ## Attention
#
# ### Attention demonstration
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ### Attention score
# $$
# Attention(Q, K, V) = \sigma\left(\frac{QK^\top}{\sqrt{d_k}}V\right)
# $$
#
# where: $\sigma(\cdot)$ is the softmax function

# %% [markdown]
# ### Multi-head attention score
# $$
# MultiHead(Q, K, V)=Concat(\text{head}_1, ...,\text{head}_h)W^O
# $$
# where $\text{head}_i = Attention(QW_i^Q, KW_i^K, VW_i^V)$

# %% [markdown]
# ### Illustration on attention mechanism
# ![](https://lilianweng.github.io/posts/2018-06-24-attention/xu2015-fig6b.png)
# ![](https://lilianweng.github.io/posts/2018-06-24-attention/cheng2016-fig1.png)

# %% [markdown]
# ## Positional encoding
#
# ![](https://aiml.com/wp-content/uploads/2023/09/example_of_positional_encoding_in_transformers.png)

# %% [markdown]
# ## Read more on Attention mechanism
# https://classic.d2l.ai/chapter_attention-mechanisms/index.html
